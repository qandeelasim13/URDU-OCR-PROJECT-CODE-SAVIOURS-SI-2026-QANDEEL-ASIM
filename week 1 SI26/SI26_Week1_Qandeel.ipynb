# %% [markdown]
# # SI'26 – Week 1 (v2): Urdu OCR Dataset Collection — Scaled to 1,500-2,000+ Images
# **Author: Qandeel Asim**
# **Student ID: 2023-BS-AI-037**
#
# ---
#
# ## What changed from the original Week 1
# Your original notebook built **246 images** from six sources, using small hand-typed
# text lists (50 sentences, 8 paragraphs, 12 phrases). That's the main reason the model
# struggled on unseen images — not enough data or variety to learn from.
#
# This version keeps the **exact same six sources, folder structure, and CSV format** —
# nothing about the pipeline shape changes — but replaces the small hand-typed text
# lists with a large pool of **real Urdu sentences pulled live from Urdu Wikipedia**,
# and renders them with **three different Urdu fonts** instead of one. Everything else
# (augmentation logic, books/signboards rendering, newspaper OCR, validation, splitting,
# stats) is unchanged.
#
# | # | Source | What changed |
# |---|--------|---------------|
# | 1 | UTRSet-Real | `N_SAMPLES` raised 60 → 400 |
# | 2 | Synthetic | 50 hardcoded sentences → ~700 real sentences from Wikipedia, 3 fonts instead of 1 |
# | 3 | Augmented | `augments_per_image` raised 2 → 3 |
# | 4 | Books | 8 hardcoded paragraphs → ~150 real paragraphs from Wikipedia |
# | 5 | Signboards | 12 hardcoded phrases → ~150 real short phrases from Wikipedia (+ your original 12 kept) |
# | 6 | Newspaper (manual+OCR) | unchanged — still optional/manual |
#
# **New:** a final section mounts Google Drive and copies the whole `data/` folder there
# automatically, since your Week 3/4/5 notebooks look for `labels.csv` on Drive.
#
# ### Target size
# Set below.

# %%
TARGET_SYNTHETIC   = 700   # plain synthetic sentence images
TARGET_BOOK_PARAS  = 150   # book-page-style paragraph images
TARGET_SIGNBOARDS  = 150   # signboard-style short-phrase images
UTRSET_N_SAMPLES   = 400   # UTRSet-Real samples (was 60)
AUGMENTS_PER_IMAGE = 3     # augmented variants per synthetic image (was 2)

print("Rough expected total (before validation/dedup):")
print(f"  UTRSet-Real : ~{UTRSET_N_SAMPLES}")
print(f"  Synthetic   : ~{TARGET_SYNTHETIC}")
print(f"  Augmented   : ~{TARGET_SYNTHETIC * AUGMENTS_PER_IMAGE}")
print(f"  Books       : ~{TARGET_BOOK_PARAS}")
print(f"  Signboards  : ~{TARGET_SIGNBOARDS + 12}")
# Out:
# Rough expected total (before validation/dedup):
#   UTRSet-Real : ~400
#   Synthetic   : ~700
#   Augmented   : ~2100
#   Books       : ~150
#   Signboards  : ~162

# %% [markdown]
# ## 0. Setup — Install & Import

# %%
# Install all required libraries
# !pip install Pillow arabic-reshaper python-bidi gdown matplotlib easyocr datasets -q
print("Installed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 10.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.2/978.2 kB 49.2 MB/s eta 0:00:00
# Installed.

# %%
# Standard library imports
import csv
import os
import random
import shutil
import textwrap
import zipfile
from pathlib import Path

# Image processing
from PIL import Image, ImageDraw, ImageFont, ImageFilter, ImageEnhance

# Urdu text rendering (shaping + right-to-left order)
import arabic_reshaper
from bidi.algorithm import get_display

# Visualization
import matplotlib.pyplot as plt

# Fix random seed so results are reproducible
random.seed(42)
print("Imports complete.")
# Out:
# Imports complete.

# %% [markdown]
# ## 1. Folder Structure
#
# Same six category folders and CSV files as the original notebook.

# %%
# Category folders
FOLDERS = [
    'data/raw/newspaper',
    'data/raw/books',
    'data/raw/signboards',
    'data/raw/synthetic',
    'data/raw/augmented',
    'data/raw/other',
]

LABELS_CSV = 'data/labels.csv'   # master label file
TRAIN_CSV  = 'data/train.csv'    # 80% split
TEST_CSV   = 'data/test.csv'     # 20% split

for folder in FOLDERS:
    os.makedirs(folder, exist_ok=True)
    print(f"  Created: {folder}")

print("\nFolder structure ready.")
# Out:
#   Created: data/raw/newspaper
#   Created: data/raw/books
#   Created: data/raw/signboards
#   Created: data/raw/synthetic
#   Created: data/raw/augmented
#   Created: data/raw/other
#
# Folder structure ready.

# %% [markdown]
# ## 2. Helper Functions
#
# ### 2a. labels.csv writer
# Unchanged from the original — merges new rows with existing ones so re-running any
# source cell never creates duplicates.

# %%
def append_to_labels_csv(new_rows, labels_csv=LABELS_CSV):
    """
    Append new_rows to labels_csv, preserving any rows already present.
    Each row must be a dict with keys: image, text, source, split.
    """
    existing_rows = []
    if os.path.exists(labels_csv):
        with open(labels_csv, 'r', encoding='utf-8') as f:
            existing_rows = list(csv.DictReader(f))

    # Avoid duplicate rows if a cell is re-run
    existing_images = {r['image'] for r in existing_rows}
    new_rows = [r for r in new_rows if r['image'] not in existing_images]

    all_rows = existing_rows + new_rows

    os.makedirs(os.path.dirname(labels_csv), exist_ok=True)
    with open(labels_csv, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['image', 'text', 'source', 'split'])
        writer.writeheader()
        writer.writerows(all_rows)

    print(f"  labels.csv: {len(all_rows)} total entries (+{len(new_rows)} new).")
    return all_rows

# %% [markdown]
# ### 2b. Image quality validator
#
# Unchanged.

# %%
def is_valid_image(path):
    """
    Returns True only if the file:
      - exists on disk
      - can be opened by Pillow without error
      - is not a completely blank (all-white or all-black) image
    """
    if not os.path.exists(path):
        return False
    try:
        img = Image.open(path).convert('L')   # convert to grayscale
        pixels = list(img.getdata())
        unique = set(pixels)
        if len(unique) <= 2:                   # blank image -- only 1 or 2 pixel values
            return False
        return True
    except Exception:
        return False

# %% [markdown]
# ### 2c. NEW — Real Urdu Sentence Pool (from Urdu Wikipedia)
#
# This is the key new piece. Instead of a small hardcoded list, this pulls **real
# sentences from Urdu Wikipedia** (`wikimedia/wikipedia`, config `20231101.ur` — an
# official, regularly-updated Hugging Face mirror of ~200,000 real Urdu articles),
# streamed live so nothing large gets downloaded upfront.
#
# One pool is fetched once here, then Sections 4, 6, and 7 each draw a different-length
# slice from it (short phrases for signboards, medium sentences for plain synthetic
# images, longer paragraphs for book pages) — so every source still gets appropriately
# different-looking text, like in your original notebook, just at much larger scale.
#
# If Wikipedia can't be reached for any reason, this falls back to repeating your
# original hardcoded sentence lists so the notebook still runs end-to-end.

# %%
import re

_urdu_range = re.compile(r'[\u0600-\u06FF]')

def _is_mostly_urdu(text, threshold=0.6):
    letters = [c for c in text if c.isalpha()]
    if not letters:
        return False
    urdu_chars = sum(1 for c in letters if _urdu_range.match(c))
    return (urdu_chars / len(letters)) >= threshold


def fetch_urdu_sentence_pool(target_count=1200, min_len=8, max_len=250):
    """
    Streams Urdu Wikipedia and collects clean, deduplicated sentences of varying
    lengths (short phrases through long paragraph-length sentences), so later
    sections can each draw the length range they need from one shared pool.
    """
    sentences = []
    seen = set()

    try:
        from datasets import load_dataset
        wiki = load_dataset("wikimedia/wikipedia", "20231101.ur", split="train", streaming=True)

        for article in wiki:
            text = article["text"]
            parts = re.split(r'[۔\.\!\?\n]', text)
            for part in parts:
                part = part.strip()
                if not (min_len <= len(part) <= max_len):
                    continue
                if not _is_mostly_urdu(part):
                    continue
                if part in seen:
                    continue
                seen.add(part)
                sentences.append(part)
                if len(sentences) >= target_count:
                    break
            if len(sentences) >= target_count:
                break

        print(f"Fetched {len(sentences)} real sentences from Urdu Wikipedia.")
    except Exception as e:
        print(f"Wikipedia fetch failed ({e}). Falling back to a small built-in sentence list.")
        fallback = [
            "پاکستان زندہ باد", "محنت کامیابی کی کنجی ہے", "علم انسان کو روشنی دیتا ہے",
            "وقت کی قدر کرنی چاہیے", "صحت سب سے بڑی نعمت ہے", "دوستی ایک قیمتی رشتہ ہے",
            "تعلیم ہر انسان کا حق ہے", "سائنس نے دنیا کو بدل دیا ہے",
            "پھل اور سبزیاں صحت کے لیے ضروری ہیں", "کتابیں انسان کی بہترین دوست ہوتی ہیں",
        ]
        # repeat the fallback list (with slight numbering) until target reached
        while len(sentences) < min(target_count, 500):
            sentences.extend(fallback)
        sentences = sentences[:target_count]

    return sentences


# Fetch one big pool (covers signboard-length through book-paragraph-length text)
URDU_SENTENCE_POOL = fetch_urdu_sentence_pool(target_count=1200, min_len=8, max_len=250)
print(f"Pool ready: {len(URDU_SENTENCE_POOL)} sentences.")
# Out:
# README.md:   0%|          | 0.00/131k [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetched 1200 real sentences from Urdu Wikipedia.
# Pool ready: 1200 sentences.

# %% [markdown]
# ## 3. Source 1 — UTRSet-Real (Public Research Dataset)
#
# **UTRSet-Real** is a printed Urdu text-line dataset published for OCR research. We
# download it once, then copy a larger subset of samples into `data/raw/other/`
# (**raised from 60 to 400** — same download/parsing logic as before, it just now takes
# more lines from the same ground-truth file).

# %%
# ── Configuration ──────────────────────────────────────────────────────────
GDRIVE_FILE_ID = "1mABkzaWe1hLikXCaM5nmLsBCWtxvDE7T"
DOWNLOAD_DIR   = "utrset_real_download"
ZIP_PATH       = os.path.join(DOWNLOAD_DIR, "utrset_real.zip")
EXTRACT_DIR    = os.path.join(DOWNLOAD_DIR, "extracted")
UTRSET_OUT_DIR = "data/raw/other"
N_SAMPLES      = UTRSET_N_SAMPLES   # was 60 -- now configurable at the top of the notebook

# %%
def download_utrset():
    """Download UTRSet-Real ZIP from Google Drive (skips if already downloaded)."""
    os.makedirs(DOWNLOAD_DIR, exist_ok=True)
    if os.path.exists(ZIP_PATH):
        print(f"Already downloaded: {ZIP_PATH}")
        return

    print("Downloading UTRSet-Real from Google Drive (may take a few minutes)...")
    import gdown
    gdown.download(id=GDRIVE_FILE_ID, output=ZIP_PATH, quiet=False)

    # Google Drive sometimes returns an HTML warning page instead of the real file
    if not os.path.exists(ZIP_PATH) or os.path.getsize(ZIP_PATH) < 1024:
        raise RuntimeError(
            "Download failed or returned an HTML warning page.\n"
            "Open the link manually in your browser and download it:\n"
            f"  https://drive.google.com/file/d/{GDRIVE_FILE_ID}/view"
        )


def extract_utrset():
    """Extract the downloaded ZIP (skips if already extracted)."""
    if os.path.exists(EXTRACT_DIR) and os.listdir(EXTRACT_DIR):
        print(f"Already extracted: {EXTRACT_DIR}")
        return
    os.makedirs(EXTRACT_DIR, exist_ok=True)
    print("Extracting ZIP...")
    with zipfile.ZipFile(ZIP_PATH, "r") as zf:
        zf.extractall(EXTRACT_DIR)
    print("Extraction complete.")


def find_gt_file(root):
    """Walk the extracted folder tree and return any ground-truth text files found."""
    candidates = []
    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            if fname.lower() in ("gt.txt", "ground_truth.txt", "labels.txt"):
                candidates.append(os.path.join(dirpath, fname))
    return candidates


def find_images(root):
    """Return all PNG/JPG/JPEG paths under root."""
    images = []
    for dirpath, _, filenames in os.walk(root):
        for fname in filenames:
            if fname.lower().endswith((".png", ".jpg", ".jpeg")):
                images.append(os.path.join(dirpath, fname))
    return images

# %%
def collect_utrset_samples():
    """
    Full pipeline: download -> extract -> parse gt.txt -> copy N_SAMPLES pairs.
    Returns a list of row dicts for labels.csv.
    """
    download_utrset()
    extract_utrset()

    gt_files = find_gt_file(EXTRACT_DIR)
    images   = find_images(EXTRACT_DIR)
    print(f"Found {len(gt_files)} ground-truth file(s), {len(images)} image(s) in archive.")

    os.makedirs(UTRSET_OUT_DIR, exist_ok=True)
    new_rows = []

    if not gt_files:
        print("No ground-truth file found -- skipping UTRSet-Real.")
        return new_rows

    gt_path = gt_files[0]
    print(f"Parsing ground truth: {gt_path}")
    with open(gt_path, "r", encoding="utf-8") as f:
        lines = [l.strip() for l in f if l.strip()]

    gt_dir = os.path.dirname(gt_path)
    for line in lines:
        if len(new_rows) >= N_SAMPLES:
            break

        # gt.txt format: "<img_relative_path>\t<text>" or "<img_relative_path> <text>"
        if "\t" in line:
            img_rel, text = line.split("\t", 1)
        elif " " in line:
            img_rel, text = line.split(" ", 1)
        else:
            continue

        src = os.path.join(gt_dir, img_rel)
        if not os.path.exists(src):
            continue

        ext      = os.path.splitext(src)[1]
        dst_name = f"utrset_{len(new_rows)+1:03d}{ext}"
        dst      = os.path.join(UTRSET_OUT_DIR, dst_name)
        shutil.copy2(src, dst)

        if is_valid_image(dst):
            new_rows.append({
                'image': dst, 'text': text.strip(),
                'source': 'utrset_real', 'split': ''
            })

    print(f"Copied {len(new_rows)} valid UTRSet-Real samples -> {UTRSET_OUT_DIR}")
    return new_rows

# %%
try:
    utrset_rows = collect_utrset_samples()
    append_to_labels_csv(utrset_rows)
except Exception as e:
    print(f"UTRSet-Real source failed/unavailable ({e}) -- continuing with other sources.")
    utrset_rows = []
# Out:
# Downloading UTRSet-Real from Google Drive (may take a few minutes)...
# Downloading...
# From (original): https://drive.google.com/uc?id=1mABkzaWe1hLikXCaM5nmLsBCWtxvDE7T
# From (redirected): https://drive.google.com/uc?id=1mABkzaWe1hLikXCaM5nmLsBCWtxvDE7T&confirm=t&uuid=f7908dce-f27b-4740-8120-2f4547ef90ca
# To: /content/utrset_real_download/utrset_real.zip
# 100%|██████████| 212M/212M [00:05<00:00, 40.1MB/s]
# Extracting ZIP...
# Extraction complete.
# Found 2 ground-truth file(s), 22322 image(s) in archive.
# Parsing ground truth: utrset_real_download/extracted/UTRSet-Real/train/gt.txt
# Copied 400 valid UTRSet-Real samples -> data/raw/other
#   labels.csv: 400 total entries (+400 new).

# %% [markdown]
# ## 4. Source 2 — Synthetic Urdu Images (Now From Real Wikipedia Sentences)
#
# Same rendering technique as your original notebook (`arabic_reshaper` + `python-bidi`
# for correct joined, right-to-left Urdu shapes), but drawing from **~700 real
# sentences** instead of 50 hardcoded ones, and cycling across **three fonts** instead
# of one for real stylistic variety.

# %%
SYNTHETIC_TEXTS = [s for s in URDU_SENTENCE_POOL if 15 <= len(s) <= 90][:TARGET_SYNTHETIC]
print(f"Using {len(SYNTHETIC_TEXTS)} sentences for plain synthetic images.")
# Out:
# Using 604 sentences for plain synthetic images.

# %% [markdown]
# ### Download three Urdu fonts (was one)
#
# Each has a fallback source if the primary link fails.

# %%
FONT_SOURCES = {
    "NotoNastaliqUrdu": [
        "https://raw.githubusercontent.com/google/fonts/main/ofl/notonastaliqurdu/NotoNastaliqUrdu%5Bwght%5D.ttf",
        "https://raw.githubusercontent.com/notofonts/noto-fonts/main/unhinted/otf/NotoNastaliqUrdu/NotoNastaliqUrdu-Regular.otf",
    ],
    "NotoNaskhArabic": [
        "https://raw.githubusercontent.com/google/fonts/main/ofl/notonaskharabic/NotoNaskhArabic%5Bwght%5D.ttf",
    ],
    "NotoSansArabic": [
        "https://raw.githubusercontent.com/google/fonts/main/ofl/notosansarabic/NotoSansArabic%5Bwght%5D.ttf",
    ],
}

import urllib.request

FONT_PATHS = {}
for font_name, urls in FONT_SOURCES.items():
    for url in urls:
        ext = ".otf" if url.endswith(".otf") else ".ttf"
        local_path = f"{font_name}{ext}"
        try:
            if not os.path.exists(local_path):
                urllib.request.urlretrieve(url, local_path)
            FONT_PATHS[font_name] = local_path
            print(f"[OK] {font_name} -> {local_path}")
            break
        except Exception as e:
            print(f"  ...source failed for {font_name}: {e}")

if not FONT_PATHS:
    raise RuntimeError("No fonts could be downloaded. Check your Colab internet connection and rerun this cell.")

print(f"\n{len(FONT_PATHS)} font(s) ready: {list(FONT_PATHS.keys())}")

# Build small/medium/large sizes for every downloaded font (was just one font before)
FONT_MAP = {}
for font_name, path in FONT_PATHS.items():
    FONT_MAP[f"{font_name}_small"]  = ImageFont.truetype(path, 28)
    FONT_MAP[f"{font_name}_medium"] = ImageFont.truetype(path, 36)
    FONT_MAP[f"{font_name}_large"]  = ImageFont.truetype(path, 48)

# Keep the original names working too (used by books/signboards below),
# pointing at whichever font downloaded first as the "default" family
_default_family = list(FONT_PATHS.keys())[0]
font_small  = FONT_MAP[f"{_default_family}_small"]
font_medium = FONT_MAP[f"{_default_family}_medium"]
font_large  = FONT_MAP[f"{_default_family}_large"]

print("Font size variants ready:", list(FONT_MAP.keys()))
# Out:
# [OK] NotoNastaliqUrdu -> NotoNastaliqUrdu.ttf
# [OK] NotoNaskhArabic -> NotoNaskhArabic.ttf
#   ...source failed for NotoSansArabic: HTTP Error 404: Not Found
#
# 2 font(s) ready: ['NotoNastaliqUrdu', 'NotoNaskhArabic']
# Font size variants ready: ['NotoNastaliqUrdu_small', 'NotoNastaliqUrdu_medium', 'NotoNastaliqUrdu_large', 'NotoNaskhArabic_small', 'NotoNaskhArabic_medium', 'NotoNaskhArabic_large']

# %% [markdown]
# ### Visual styles (now also cycling through fonts)

# %%
# Visual style configurations for synthetic images
# Each style dict defines: background color, text color, font-size key, padding
STYLES = []
_bg_fg_pad_options = [
    {"bg": (255, 255, 255), "fg": (0,   0,   0),   "pad": 20},  # white
    {"bg": (255, 251, 230), "fg": (30,  30,  30),  "pad": 24},  # cream
    {"bg": (240, 240, 240), "fg": (10,  10,  80),  "pad": 30},  # light gray, blue text
    {"bg": (255, 255, 255), "fg": (0,   0,   0),   "pad": 14},  # white, small (signboard)
]
_size_options = ["small", "medium", "large"]

for font_name in FONT_MAP:
    pass  # placeholder, real combos built below

for font_family in FONT_PATHS:
    for size in _size_options:
        for bg_fg_pad in _bg_fg_pad_options:
            STYLES.append({**bg_fg_pad, "font_key": f"{font_family}_{size}"})

print(f"Total style combinations available: {len(STYLES)} (font x size x background)")


def render_urdu_image(text, style):
    """
    Render a single Urdu text string into a PIL Image using the given style dict.
    Returns the PIL Image object.
    """
    font_obj   = FONT_MAP[style["font_key"]]
    pad        = style["pad"]
    bg_color   = style["bg"]
    text_color = style["fg"]

    # Reshape Urdu characters and apply RTL direction
    reshaped  = arabic_reshaper.reshape(text)
    bidi_text = get_display(reshaped)

    # Measure text size on a throwaway canvas
    dummy = ImageDraw.Draw(Image.new("RGB", (10, 10)))
    bbox  = dummy.textbbox((0, 0), bidi_text, font=font_obj)
    w     = bbox[2] - bbox[0]
    h     = bbox[3] - bbox[1]

    # Create actual image with padding
    img  = Image.new("RGB", (w + pad * 2, h + pad * 2), color=bg_color)
    draw = ImageDraw.Draw(img)
    draw.text((pad - bbox[0], pad - bbox[1]), bidi_text, fill=text_color, font=font_obj)
    return img
# Out:
# Total style combinations available: 24 (font x size x background)

# %%
def generate_synthetic_images():
    """
    Render all SYNTHETIC_TEXTS, cycling through all STYLES (font x size x background),
    and save to data/raw/synthetic/. Returns a list of label row dicts.
    """
    rows  = []
    count = 0

    for i, text in enumerate(SYNTHETIC_TEXTS):
        style     = STYLES[i % len(STYLES)]
        try:
            img = render_urdu_image(text, style)
        except Exception:
            continue  # skip any text a given font genuinely can't render
        save_path = f"data/raw/synthetic/urdu_{i+1:04d}.png"
        img.save(save_path)
        rows.append({
            'image': save_path, 'text': text,
            'source': 'synthetic', 'split': ''
        })
        count += 1

    print(f"Generated {count} synthetic images -> data/raw/synthetic/")
    return rows

synthetic_rows = generate_synthetic_images()
append_to_labels_csv(synthetic_rows)
# Out:
# Generated 604 synthetic images -> data/raw/synthetic/
#   labels.csv: 1004 total entries (+604 new).
# [{'image': 'data/raw/other/utrset_001.jpg',
#   'text': 'اندراج و تحریر شرعاً صرف مستحب اور پسندیدہ ہے وہ واجب نہیں کہ کسی شرعی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_002.jpg',
#   'text': 'اور ہندوستان کی مسلم ریاستوں میں اس پر کم و بیش عمل درآمد بھی ہے، جہاں تک جبری',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_003.jpg',
#   'text': 'بلکہ اس کے نزدیک وہ پسندیدہ اور مستحسن بھی ہے، عملی پہلوکے لحاظ سے اسلامی سلطنتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_004.jpg',
#   'text': 'جہاں تک پہلی صورت کاتعلق ہے، شریعت اسلامیہ کی رو سے اس پر اعتراض جائز نہیں،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_005.jpg',
#   'text': 'ہے، اس لیے اس کولازمی طورپر جاری کردیاجائے، اس کانام جبر ی اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_006.jpg',
#   'text': 'مقدمات سے نجات مل سکتی ہے، نکاح کے ثبوت اورک دین مہر کے تعین میں سہولت ہوتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_007.jpg',
#   'text': 'دوسرا پہلو یہ ہے کہ چونکہ اس اندراج میں بہت سی مصلحتیں ہیں، اس سے بڑی حدتک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_008.jpg',
#   'text': 'جس قدر لوگ اس پر عمل کریں اتنا ہی فائدہ ہے، اس کانام اختیاری اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_009.jpg',
#   'text': 'ایک تویہ کہ اس قسم کااندراج مفید ونافع ہے، اوراس کا رواج دینا مناسب ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_010.jpg',
#   'text': 'کے لیے غیر ضروری تسلیم کرتے ہوئے اس حیثیت سے یہ مسئلہ زیر بحث آسکتاہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_011.jpg',
#   'text': 'اسلامی حکم کے خلاف ہوگا، ہاں نکاح وطلاق کے اندراج کوصحت نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_012.jpg',
#   'text': 'جو نکاح وطلاق کی اس حیثیت پر اثر انداز ہو، قبول نہیں کیاجاسکتا، کیونکہ وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_013.jpg',
#   'text': 'نہیں ہوئی، ناجائز اور قابل انکار نہیں قرار دی جاسکتی، اس لیے کوئی ایسا قانون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_014.jpg',
#   'text': 'اورکوئی طلاق صرف اس وجہ سے کہ وہ لکھی نہیں گئی یا سرکاری رجسٹر میں درج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_015.jpg',
#   'text': 'نکاح صرف اس وجہ سے وہ لکھا نہیں گیا یا سرکاری رجسٹرمیں درج نہیں ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_016.jpg',
#   'text': 'زبانی الفاظ طلاق (بشرائط مقررہ ومعتبرہ) و قوع طلاق کے لیے کافی ہیں، کوئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_017.jpg',
#   'text': 'نہیں، مذہبی طورپر زبانی ایجاب و قبول (بشرائط مقررہ و معتبرہ) نکاح کے لیے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_018.jpg',
#   'text': 'احکام کی بناء پر نکاح وطلاق کی صحت کے لیے کتاب اور رجسٹر میں اندراج کی ضرورت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_019.jpg',
#   'text': 'اس وقت مسئلہ یہ تھا کہ نکاح وطلاق کا اندراج سرکاری طورپر ایک رجسٹرمیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_020.jpg',
#   'text': 'اس لیے اس سے ان کے خیالات کااندازہ کیاجاسکتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_021.jpg',
#   'text': 'میں قابل قبول نہیں سمجھی گئی توپھر مولاناکفایت اللہ اور مولاناقطب الدین کی تائید سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_022.jpg',
#   'text': 'فرنگی محلی وغیرہ تھے، اس کمیٹی نے جو رپورٹ تیار کی وہ یوپی کی مجلس قانون ساز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_023.jpg',
#   'text': 'کے ساتھ مولاناکفایت اللہ دہلوی،مولوی نعیم الدین مرادآبادی اور مولانا قطب الدین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_024.jpg',
#   'text': 'الہ آباد ہائی کورٹ)تھے، اس کے ممبروں میں ڈاکٹر شفاعت احمدخاں کے علاوہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_025.jpg',
#   'text': 'کو رجسٹرڈ کرنے کے لیے ایک قانون بناناتھا، اس کمیٹی کے صدر سرشاہ سلیمان (جج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_026.jpg',
#   'text': 'تھا، اس کامقصد مسلمانوں کونکاح وطلاق کے معاملات پر غور اور نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_027.jpg',
#   'text': 'الہ آباد یونیورسٹی) کی تحریک سے ایک کمیٹی بنائی گئی تھی، جس کانام ”مسلم میرج سب کمیٹی“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_028.jpg',
#   'text': 'میں یوپی کی مجلس قانون ساز میں ڈاکٹرشفاعت احمدخاں (پروفیسر تاریخ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_029.jpg',
#   'text': 'میں بڑی ہمدردی سے دلچسپی لی، جیسا کہ حسبِ ذیل تفصیلات سے اندازہ ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_030.jpg',
#   'text': 'انھوں نے قرآن مجید، حدیث اور فقہ کے اپنے گہرے مطالعہ سے ان کو حل کرنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_031.jpg',
#   'text': 'اور وراثت کے مسائل میں بہت سے سوالات پیداہوتے رہے اس سلسلہ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_032.jpg',
#   'text': 'تو متعین کردیا ہے مگر جیسا کہ پہلے بھی کہا گیاہے، ہندوستان میں ان کے نکاح،طلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_033.jpg',
#   'text': 'غیر مسلم حاکم کافیصلہ جائز نہیں ہوسکتاہے اور نہ ایسے مسلمان حاکموں سے اس کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_034.jpg',
#   'text': 'اس مشکل اس لیے حل نہیں کرسکتی ہیں کہ ان مسائل میں شرع اسلامی کے رو سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_035.jpg',
#   'text': 'جائیں جو آنریری منصف کوحاصل ہیں، تاکہ وہ اپنے اختیارات سے ایسی مشکلوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_036.jpg',
#   'text': 'مشکل یک آسان صورت یہ ہے کہ قاضیوں کوان معاملات کے لیے وہ اختیارات دیئے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_037.jpg',
#   'text': 'رجسٹری آفس بھی نئی ذمہ داریوں سے محفوظ رہیں گے(۲) اگر بالفعل یہ ممکن نہ ہو تواس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_038.jpg',
#   'text': 'ساری مشکلات دور ہوجائیں گی، عدالتیں بھی بہت سی دقتوں سے محفوظ ہوجائیں گی،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_039.jpg',
#   'text': 'قائم کردیاجائے جس کوان معاملات میں فیصلہ کرنے کاپورااختیار ہو، اس طرح تو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_040.jpg',
#   'text': 'نظام میں لاکر پورے صوبہ میں مسلمانوں کے نکاح وطلاق کے لیے ایک علیحدہ محکمہئ قضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_041.jpg',
#   'text': 'کیں کہ (۱) مسلمانوں کے ان مسائل کے لیے قاضی مقرر کیے جائیں اوران کوایک مرکزی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_042.jpg',
#   'text': 'دونوں کے لیے مصیبت کاباعث ہوتے ہیں، مسلمان لڑکیاں مظلوم بنی رہتی ہیں، اس مصیبت کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_043.jpg',
#   'text': 'وجہ سے مقدمے دائر ہوجاتے ہیں، ایسی صورت میں یہ مقدمات، خاندانوں اور عدالتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_044.jpg',
#   'text': 'مختلف صورتوں،خلع، خیار اور تفریق کے مسائل، ولی ہونے کے باہمی فرق و مراتب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_045.jpg',
#   'text': 'ہے کہ ترک وراثت، رضاعت، رشتوں کے حلال و حرام ہونے، عدت اطلاق کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_046.jpg',
#   'text': 'اس لحاظ سے بے انصافی ہوتی ہے کہ ایسے لوگ بھی ان کا نکاح پڑھا دیتے ہیں جو ممکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_047.jpg',
#   'text': 'اور تحصیلوں میں قاضیوں اور نائب قاضیوں کاتقرر کرے تو تمام مشکلات کا حل ہوجاتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_048.jpg',
#   'text': 'اور یہ قاضی القضاۃ مسلمانوں کی رضامندی اور گورنمنٹ یک منظوری سے اضلاع',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_049.jpg',
#   'text': 'اگر صوبہ کے مسلمان ایک قاضی القضاۃ کا انتخاب کریں اور گورنمنٹ اس ک منظورکرے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_050.jpg',
#   'text': 'قوت حاصل ہونے کے لیے ضروری ہے کہ حکومت اس انتخاب کوقبول کرے، اس بناء پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_051.jpg',
#   'text': 'اپنی رضامندی سے ایک قاضی کاانتخاب کریں اوراس قاضی کوتنقیدکی طاقت اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_052.jpg',
#   'text': 'منظور کرنا تقریباً ناممکن ہے، اس بناء پر اگر کوئی صورت ممکن ہے تووہ یہ ہے کہ مسلمان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_053.jpg',
#   'text': 'مسلم حکومت کیلیے خاص طورسے مسلمانوں کی خاطر ایک مستقل مسلمان والی کے تصور کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_054.jpg',
#   'text': 'مختلف مذہبوں اور قوموں کی ایسی مخلوط آبادی ہے، جس کا لحاظ کرکے یہاں کی غیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_055.jpg',
#   'text': 'قضا کے لیے تینوں مذکورہئ بالاشکلوں میں ایک شکل اختیارکرنی پڑے گی، ہندوستان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_056.jpg',
#   'text': 'میں مسلمانوں کے ان شرعی معاملات کے نظم،نسق، ترتیب، ان احکام کے احیاء اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_057.jpg',
#   'text': 'مندی سے قاضی کاانتخاب کریں، یہ تینوں شکلیں فقہ کی کتابوں میں مذکور ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_058.jpg',
#   'text': 'کردے، یہ مسلمان والی پھر قاضی مقرر کرے (۳) یہ بھی ممکن نہ ہو تو مسلمان اپنی باہمی رضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_059.jpg',
#   'text': 'ہوسکے توغیر مسلم حکومت سے مطالبہ کیاجائے کہ وہی ان پر ایک مسلمان والی مقرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_060.jpg',
#   'text': 'انتخاب کریں اور وہ قاضیوں کا تقرر کرے جو نکاح وطلاق کے مسئلے کو طے کریں (۲)یہ نہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_061.jpg',
#   'text': 'ہیں، (۱) اگر ممکن ہو تومسلمان خود اپنی طرف سے متفق اور متحد ہوکر ایک.... والی کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_062.jpg',
#   'text': 'ہو، ایسے معاملات کے نظم ونسق و ترتیب واجماء کے لیے حسب ذیل تین شکلیں تجویز کی جاسکتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_063.jpg',
#   'text': 'قانون کوجواصل میں غیر واجب ہو، واجب قرار دے، لیکن جہاں غیر مسلم حکومت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_064.jpg',
#   'text': 'صرف اما مسلمین کو پہونچتا ہے کہ وہ مسلمانوں کی مصلحتوں کی بناء پر اپنے زمانہ میں کسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_065.jpg',
#   'text': 'اختیار کے بغیر کسی تبرع اور استجاب کو واجب میں نہیں بدلا جاسکتا، یہ شرعی اختیار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_066.jpg',
#   'text': 'مہدی صاحب(بھوپال)(۳) حضرت شریف فکری بھپوال،(۴) مولینافضل الرحمن صاحب باقیؔ(کلکتہ)(۵) حضرت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_067.jpg',
#   'text': 'فرمائی ہے انکی خدمت میں ہدیہئ تشکر وامتنان پیش ہے۔ امیدکہ دیگر معاونین بھی اولین فرصت میں توجہ فرمائینگے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_068.jpg',
#   'text': ':۔  نیرنگ کی پسندیدہ خدمات کے اعتراف میں جن حضرات نے توجہ والتفات فرماکر مخصوص معاونت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_069.jpg',
#   'text': 'شکریہئ التفات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_070.jpg',
#   'text': 'رہگیااورہمیشہ کے لئے ایک سکوت، سکوتِ مرگ عاری ہوگیا۔اورحسن صباخت ور آغوش،آغوشِ فنامیں روپوش یہ تھا”ڈاخ کاخواب“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_071.jpg',
#   'text': 'سامنے یہ کچھ ہوااوراس نے دیکہا۔ وہ آگے بڑہناچاہتاتھاکہ دوخواصوں نے بڑہ کر ایک چادر بیاٹرس پر ڈالدی۔ وہ دیکہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_072.jpg',
#   'text': 'پر بوسہ یدتاہے جن پر آج سے پہلے ڈانٹے کی جرائت نہوئی اوراسکے لب اُنہیں کبہی بھی”زحمت وصل نہ دے سکے۔ مگر آہ کہ آج اوراسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_073.jpg',
#   'text': 'بڑہتاہے۔ کہ”عشق“ کی ستم ظریفی میں اضافہ ہوتاہے اور”دیوتا“اسکی محبوبہ کے قوس گوں لبوں پر اُن مرمرین گلاب کی پتیوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_074.jpg',
#   'text': 'اور بے پناہ تیر اسکے۔ دل میں پیوست کردیتاہے دانٹے اس غیر متوقع،دلخراش اورناقابل دیدنظارے کی تاب نہ لاکر آگے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_075.jpg',
#   'text': 'موت کی دستبروسے مجبور ہوکر اس سے جداہوتی ہے۔ اورحسین غالب بے جان رہی ہے، ادھر عشق دیوتااپنا تیرزہریلا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_076.jpg',
#   'text': 'اُس نے دیکہاکہ:۔ وہ ایک تالاردلکشامیں اپنی حسین ومحبوب بیوی بیاٹرس کے ساتھ بیٹھاہے۔ ’بیاٹرس اسی وقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_077.jpg',
#   'text': '”زندہ“رہ سکا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_078.jpg',
#   'text': 'کے ذریعہ کی ہے جو تقریباً انیس سال کی طویل کاوش کانتیجہ ہے۔ اورغالباً داسی، کوشش وعمل کی مصروفیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_079.jpg',
#   'text': '”محبوبہ“ کی جدائی کے کچھ عرصہ بعد”روزیٹی“ نے ایک خواب دیکہا:۔ جس کی تشریح اسکی جنبشِ قلم نے اس تصویر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_080.jpg',
#   'text': 'جداکردیا۔اور وہ حیران وپریشان اس ”بے نیازی“ کاناقابلِ فہم مظاہرہ کرتاتنہاوبیکس رہگیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_081.jpg',
#   'text': 'کچھ ہی عرصہ بعدآبادگھربرباد ہوگیا۔یعنی”روزیٹی“ کی محبوب وجمیل بیوی“ کو”پنجہئ اجل“ نے ہمیشہ کیلئے اُس سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_082.jpg',
#   'text': 'حسین نقش ونگار کونمایاں کیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_083.jpg',
#   'text': 'دونوں ایک دوسرے کے والہ و شیداہوگئے۔ روز یٹنی نے اُسکے ’اعتراف جمال‘ کی سندمیں اکثر تصاویرمین اسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_084.jpg',
#   'text': 'یہاں تک وسعت اختیار کی کہ اس کو حسینہ سے ایک ”گہراقلبی تعلق“ہوگیا۔ محبت کے پینگ بڑہے اورایسے بڑہے کہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_085.jpg',
#   'text': 'سے ایک دوست مصوّر کے ذریعہ ایک خوش جمال حسینہ سے روزبیٹی کی ملاقات ہوگئی۔رسمی تعارف حدودنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_086.jpg',
#   'text': 'کی تصویریں بولتی تصویریں کہلائی جاتی ہیں اور اپنے عہدکاکامیاب ومقبول مصوّر ہوا۔حسن اتفاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_087.jpg',
#   'text': 'ملّاصاحب کی شادی کے حالات کی دلکش تفصیلات جوخودجناب موصوف نے انداز مخصوص میں تحریر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_088.jpg',
#   'text': 'شادی۔  طابع وناشر۔ عالمگیر بکڈپولاہور۔قیمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_089.jpg',
#   'text': 'شایقین ادب کیلئے اس کتاب کامطالعہ دلچسپی کاباعث ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_090.jpg',
#   'text': 'کتابت طباعت نفیس ہے۔ملّاصاحب کے تعارف کی کوشش کرنااُنکی توہین کے مرادف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_091.jpg',
#   'text': 'ضیاء الملک ملّا رموزیؔ کے اُن مزاحیہ مضامین کامجموعہ ہے جوموقت الشیوع رسائل میں شائع ہوچکے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_092.jpg',
#   'text': 'ضخامت ص۲٤٠ ۔قیمت عصر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_093.jpg',
#   'text': 'طابع وناشر:۔ عالمگیب بکڈپو۔لاہورسائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_094.jpg',
#   'text': 'صبح لطافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_095.jpg',
#   'text': 'اہل ذوق کلام برق سے محظوظ ہوں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_096.jpg',
#   'text': 'بعدازاں مصنف کافارسی دیباچہ اورغزلیات کاانتخاب ہے کاغذکتابت طباعت عمدہ ہے۔ سرورق آرت پیپر کاہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_097.jpg',
#   'text': 'قیمت ۲ ۱/-ضخامت دوسو صفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_098.jpg',
#   'text': 'ناشر:۔ارمغاں بکڈپو،دہلی۔ سائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_099.jpg',
#   'text': 'کتابیں۔ شرارؔ برقی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_100.jpg',
#   'text': 'یہ رسالہ مستقل خریداروں کومفت ملتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_101.jpg',
#   'text': 'خداکرے مولاناواحدی صاحب کی مساعی حسنہ کامیاب ترین ثابت ہوں:',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_102.jpg',
#   'text': 'مضامین نثرونظم جوڈیڑھ سوصفحات پر مشتمل ہیں اپنی مخصوص شانِ متانت کے ساتھ شایع ہواہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_103.jpg',
#   'text': 'حاصل کیجاتی ہے۔ امسال بھی حسب سابق سیرتِ نبی اکرم صلعم کے متعددعنواناتِ مفیدہ کے ماتحت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_104.jpg',
#   'text': 'ضامن ہیں۔”رسول نمبر“ کی ابتدانظام المشایخ سے ہوئی اوراس اجتہادی عمل صالحہ میں ہر سال کامیابی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_105.jpg',
#   'text': 'متین روش اورمستقل سلامت ردی قابل ذکر ہے جوانداز وطرز ابتداسے اختیارکیاہے بدستوراسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_106.jpg',
#   'text': 'دہلی کے قدیم ترین رسالہ نظام المشایخ، کی اہم ترین خصوصیات میں اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_107.jpg',
#   'text': 'نظام المشایخ”رسول نمبر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_108.jpg',
#   'text': 'میں ہدیہ تبریک پیش کرتے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_109.jpg',
#   'text': 'ملک کے ہرپڑہے لکہے مردعورت کواس رسالہ کی معاونت کرناچاہئے۔ ہم لائق مدیر کی خدمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_110.jpg',
#   'text': 'مدیردمالک مولوی کی ادالعزمی اور حب رسول کاثبوت ہے۔ اس رسالہ کی علیحدہ قیمت ۲ ۱ رہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_111.jpg',
#   'text': 'کی ضخامت ایک روپیہ سالانہ چندہ میں خریداروں کومفت دیدیتامولوی عبدالحمیدخاں صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_112.jpg',
#   'text': 'صلعلم کی سیرتِ پاک پر مسلم اورمعتدغیر مسلم اہلِ قلم کے مفیدمضامین تقریباً ڈیرھ سوصفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_113.jpg',
#   'text': 'ونعتیہ نظموں کامتبرک مجموعہ ہے(اگرچہ اکثرنظمیں مطبوعہ ہیں،سرورق بلاک کارنگین ہے۔ سردرِ کائنات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_114.jpg',
#   'text': 'میں نہایت شان وعظت سے شائع ہواہے۔ جوتقریباً ڈیڑسوصفحات کے منتخب اورمقدس مضامین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_115.jpg',
#   'text': 'مذہبی رسالہ”مولوی“ کا”رسول نمبر“ حسب معمول عیدمیلادالنی صلعم کی تقریب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_116.jpg',
#   'text': 'مولویؔ ”رسول نمبر“۔دہلی کے سب سے سَستے اورہندوستان کے سب سے زیادہ کثیرالاشاعت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_117.jpg',
#   'text': '”نیرنگِ نظر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_118.jpg',
#   'text': 'قریب میں محاسن ومعائب پر ہرپہلوسے روشنی ڈالیں گے۔کہ اس عامیانہ ہڑبونگ کی قلعی کُہلے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_119.jpg',
#   'text': 'کامطمح نظر بھی یھی ہو۔بہرحال تفصیلات کیلئے سردست ہم اپنی رائے محفوظ رکہتے ہیں اورمستقل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_120.jpg',
#   'text': 'آزادخیال مولف کی حیثیت سے اپنی تالیف کی تدوین میں متین ثابت ہو۔ اورغالباً ڈاکٹر صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_121.jpg',
#   'text': 'فرض ہوتاہے کہ وہ”معمل“ میں ٹیہکرکسی مذہب وملّت سے متاثر نہو اور”سانٹیفک“ اصول سے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_122.jpg',
#   'text': 'رکہکر آزادانہ طورپر کسی خاص ”مذہبیت“ کی رعایت کئے بغیر تاریخ کومکمل کرے۔ کامیاب مورّخ کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_123.jpg',
#   'text': 'کے مطالعہ کی غرض سے ہے۔ اوراس لحاظ سے ایک مورّخ کافرض ہے کہ وہ فلسفہ- تاریخ کوسامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_124.jpg',
#   'text': 'ہیں کہ ڈاکٹر صاحب نے کسی خاص مذہب کیلئے یہ تاریخ مرتب نہیں کی ہے بلکہ ”ہندوستانی طلباء“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_125.jpg',
#   'text': 'ابھی بالاستیعاب نہیں پڑہاہے۔تاہم اسوقت عام غلط فہمی پہیلی ہوئی دیکہکریہ کہناضروری سمجہتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_126.jpg',
#   'text': 'مضر ہے۔ الزام یہ ہے کہ مسلمان بادشاہوں کااحترام ملحوظ نہیں رکہاگیاوغیرہ۔ ہم نے اس تاریخ کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_127.jpg',
#   'text': 'گذر کر ’ذات‘ پر بھی حملے شروع کردیئے ہیں۔ اوربتایاجارہاہے کہ یہ تاریخ مسلمان طلباء کیلئے نہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_128.jpg',
#   'text': 'کاشروع ہوئی ہے۔ ایک خاص طبقہ نے اس تاریخ کی تخریب شروع کرکے ڈاکٹر صاحب کی قابلیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_129.jpg',
#   'text': 'سلسلہ میں نہیں ہوئی۔ لیکن اب کچھ مدّت سے جب سے کہ یوپی کونسل کے مسئلہ انتخاب کی سلسلہ جنبانی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_130.jpg',
#   'text': '”تاریخِ ہند“ مرتب کی تھی۔ جس کی اشاعت کوبھی عرصہ ہوا۔ جب سے اب تک کوئی قابل ذکر رائے زنی اس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_131.jpg',
#   'text': '(فیلوالہ آبادیونیورسٹی) نے طلباء اسکول کے لئے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_132.jpg',
#   'text': 'یوپی کے مشہورفاضل مورّخ ڈاکٹر شفاعت احمدخانصاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_133.jpg',
#   'text': 'ڈاکٹر شفاعت احمدخاں کی ”تاریخ ہند',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_134.jpg',
#   'text': 'خواہ ہیں اور ارکین پریس و”نیرنگ“ احتیاط کے لئے متنبہ ہوچکے ہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_135.jpg',
#   'text': 'ہے۔اور ناظرین نیرنگ کے ’ذوق‘ کی اہانت ہے۔ اس لئے ہم اپنے معاونیں کرام سے خصوصاً عذر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_136.jpg',
#   'text': 'امرنہیں کیونکہ عموماً رسائل میں تصاویر کی اشاعت کامعیار بہی ہے۔لیکن نیرنگ کی روایات کے ضرور منافی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_137.jpg',
#   'text': 'کیا۔ اور اچہی خاصی تصاویر میں بے جوڑ چمک اورغیر متین بچپن نمایاں ہوگیا۔گوعام لحاظ سے یہ چنداں ناگوار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_138.jpg',
#   'text': 'غلط فہمی ہوئی۔ اور منیجرصاحب نے اس خیال سے کہ پرچہ وقت پرشائع کرسکیں دوبارہ صحیح طباعت سے گریز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_139.jpg',
#   'text': 'جوان ہوکر روزیٹیؔ نے فن مصوّری میں کمال حاصل کیا۔ ڈانٹے سے اکتساب کانتیجہ یہ تھاکہ ”روزیٹی ڈاناٹے“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_140.jpg',
#   'text': 'والہئ وشیداہوکر رہیگا۔ڈانٹے کی واجدانی شاعی کے اثرات اسکے دل پر نقش ہوکر رہ گئے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_141.jpg',
#   'text': 'ورشحاتِ لطیف نے روزیٹی کے قلب کوابتدائی عمر سے متاثر کرناشروع کیا۔اوروہ حسن فطرت کاپرستار اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_142.jpg',
#   'text': 'کی داستانیں اُس کے کانوں میں پڑیں۔جسکالازمی نتیجہ یہ تھاکہ وہ بھی شاعراعظم کے کمالات سے متکیف ہوااوراس کے خیالات جمیل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_143.jpg',
#   'text': 'ہوش سنبہال کر رویٹیؔ نے اپنے باپ کی زبان سے دن رات ڈانٹےؔ کے وجدآفریں اشعار سُنے اورتعریف وتوصیف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_144.jpg',
#   'text': 'باعث اُس نے اپنے بیٹے کانام”ڈانٹے جبرئیل روزیٹی“رکہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_145.jpg',
#   'text': 'روزمیٹیؔ کے باپ کومشہور ومعروف شاعراطالیہ ڈانٹے کے کمالات سے انتہائی شغف تھا۔اوراسی عقیدت کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_146.jpg',
#   'text': 'تہا۔مگر والدین ترک سکونت کرکے انگلستان آگئے تھے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_147.jpg',
#   'text': 'روزیٹیؔ ڈانٹے-- نوجوان اورکامیاب مصوّر انگلستان میں ۸۲۸۱ء میں پیداہوا۔اُسکاآبائی وطن اٹلی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_148.jpg',
#   'text': '(سرِورق کی تصویرکے ساتھ)',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_149.jpg',
#   'text': 'ڈانٹے کاخواب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_150.jpg',
#   'text': '(۶)ساریان:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_151.jpg',
#   'text': '(۵)نورِ ہدایت:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_152.jpg',
#   'text': '(۴)غزال:۔ " " " " " " " " " " قیمت۱۰',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_153.jpg',
#   'text': '(۳) بقائے دوام:۔ مصنفہ مسٹرایم اسلم لاہور طابع ناشر:۔ نسیم بکبڑ پوبار و دخانہ لاہور قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_154.jpg',
#   'text': '(۲)چینی اور جاپانی افسانے!۔ " " " " " " " " " " قیمت ۹',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_155.jpg',
#   'text': '(۱) قدیم افسانے (پہلاحصّہ)۔ طابع وناشر:۔انجمن امدادباہمی مکتبہ ابراہیّہ حیدرآباڈکن۔ قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_156.jpg',
#   'text': 'میں سے خصوصاً مندرجہ ذیل قابل ذکر ہیں:۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_157.jpg',
#   'text': 'رسیدکتب:۔ متعددکتب جوبغرض ریویوموصول ہوئی ہیں اُن پر آئندہ بالترتیب تبصرہ کیاجائیگاجن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_158.jpg',
#   'text': 'اہل نظر کودیکہناچاہیئے۔کاغذ کتاب طباعت اورضخامت”صبح لطافت“ کی مانندہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_159.jpg',
#   'text': 'معاشری پہلوؤں پر کامیاب روشنی ڈالی گئی ہے۔ بہ حیثیتِ مجموعی”ملّاصاحب کی شادی، قابل دیدہے۔ اورہر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_160.jpg',
#   'text': 'ہیں۔تفصیلاتِ تقریب پر جومباحث اس کتاب میں درج ہیں دلچسپ ہونیکے ساتھ ہی مفیداورسبق آموزہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_161.jpg',
#   'text': 'وبلند مقصد کی جس ناپاک اور گندہ طرز تحریر کے ذریے سے پامای کی گیی ہے وہ حردرجہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_162.jpg',
#   'text': 'حوادث سے کی جائے۔ لیکن افسوس ہے کہ گلکتہ یھی کے تماشاگا ہوں میں اس شریف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_163.jpg',
#   'text': 'ڈراما کا مقصد ہے، کہ مہیست اجتماعی کی اصلاح شخصی  واقعات اور روز مرہ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_164.jpg',
#   'text': 'قوّلوں کو کیا نثبت ہے؟',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_165.jpg',
#   'text': 'پڑھ کر شریف فن اور کون ہو سکتا ہے، لیکن اب امیر خسرو سے بہار وخیراباد کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_166.jpg',
#   'text': 'وہ فن ہے ، حالانکہ خودجماعت کا رتبہ فن کی حیثیت سے ہونا چاہیے تھا۔ موسیقی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_167.jpg',
#   'text': 'اصل یہ ہے کہ فن کامرتبہ اس جماعت سے کیا جارہا ہے، جبکے ہاتھ  میں اسوقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_168.jpg',
#   'text': 'افسانہ نگاری کے کاہل نامنہ ہیں ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_169.jpg',
#   'text': 'ہمرانی، حریری، زمخشری، اور سیوطی ، جن کا شمار اکابر علما میں ہے ، انکے مقامات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_170.jpg',
#   'text': 'ڈراما نویسی یا افسانہ نگاری آج فنون ادبیہ کی پست ترین سطح ہے۔ لیکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_171.jpg',
#   'text': 'ان کا تقوے کسی کو نہیں معلوم ، تا ہم وہ فن غنا کے ماہرین میں تھے ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_172.jpg',
#   'text': 'کوئی چیز عیب گیری کی مستحق نہ تھی۔ امام ملک اور حضرت عمربن عبد الغریزکا تقدس اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_173.jpg',
#   'text': 'سمجھے جاتے ہیں ، حالانکہ اس مد میں جبکہ قوم کے نام توے  مشتعل تھے۔ ان میں سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_174.jpg',
#   'text': 'ہے۔ شاعری کے سوا فنون لطیفہ کے تمام اقسام آج کل خالاف وقار وستانت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_175.jpg',
#   'text': 'بزا تہ دنیا میں کوئی شے خیر محض یا شر محض نہیں، اس کا موقع استعمال خیریا شرہوتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_176.jpg',
#   'text': '( ۲ ) مولانا سید سلیمان ندوی ناظم دارالمصنفین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_177.jpg',
#   'text': 'ارو بارونق عالیشان قصروایوان کو چھوڑ کے نہرم کھنڈروں اور عبرتناک ویرانوں  کی سیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_178.jpg',
#   'text': 'اس میں شک نہیں کہ ایک اثر پزیر دل حسرت و اندوہ کے واقعات کوزیادہ پسند کرتا ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_179.jpg',
#   'text': 'ہے کہ بجاے کا میڈمی کے حضرت "ناظر" نے اس ڈراما کا خاتمہ ٹریجڈی پر کیا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_180.jpg',
#   'text': 'لاٹ لٹریچرایک لطف   الان کے ساتھ گرانبار اور وقبق ہوگیا ہے ۔ اسی کا ایک نمونہ یہ بھی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_181.jpg',
#   'text': 'خوشی کی بات ہے کہ اس سے کسی قسم کی بدمزگی پیدا ہونے کے بجاے ڈرا ماکا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_182.jpg',
#   'text': 'اظہار کرتے وقت کی مقاموں پر وہ اپنے اصلی عالم فلسفہ میں واپس چلے گئے ہیں۔ مگر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_183.jpg',
#   'text': 'میں لائے ہیں ، جس میں علت و سبب پرغور کرنا جرم ہے۔ اسی وجہ سے جذبات کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_184.jpg',
#   'text': 'مگروہ اسے اس تصنیف میں اپنے عالم اسباب سے زبردستی کھینچ کرکے حسن و عشق کی دنیا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_185.jpg',
#   'text': 'لٹریچرمیں نظریات وقیق کا عادی ہے، اور ہرسلہ پراستدلال عنوان سے غور کرتا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_186.jpg',
#   'text': 'مصنف یعنی جناب "ناظر" کا مذاق بہت گہرا مالما نہ ہے ۔ ان کا دماغ ڈیپ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_187.jpg',
#   'text': 'حصہ اس مذاق سے اثنا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_188.jpg',
#   'text': 'نوجوان کے قلم سے کمل ہو کر اس پبلک کے سامنے پیش ہوتا ہے ، جس کا بہت ہی محدود',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_189.jpg',
#   'text': 'یہ اردو میں ایک نیا ڈر اما ہے، جو ایک فلسفیانہ دماغ والے فاضل وقابل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_190.jpg',
#   'text': '(۱) مولانا مولوی عبدالحلیم سحاب  شرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_191.jpg',
#   'text': 'تقریظات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_192.jpg',
#   'text': 'ہیں- اور اب تک من حیث المجموع انھوں نے اس حق کے استعمال میں ایسی نجیع غلطیاں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_193.jpg',
#   'text': "یا نہ دیا جائے ، اور دیاجائے توکسی حد تک ' والدین اس حق کو کس طرح استعمال کرتے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_194.jpg',
#   'text': 'اہم ترین مسائل میں سے ہے ۔ حق آنخاب ، مناکحت میں بالکل فریقین کو دیا جائے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_195.jpg',
#   'text': "انھوں نے موضوع تصنیف قرار دیا ہے' اس میں شک نہیں  کہ ہماری موجودہ سو سائٹی کے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_196.jpg',
#   'text': 'ادبی حیثیت کی تقیص کرتے ہیں ۔ ان اجزا میں جزواعظم  مسٹر بسیٹی ہیں- جس مسلے کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_197.jpg',
#   'text': 'بھی آج کل کی ناٹک کمپنی اسے اسٹیج پراجیکٹ کرسکے ایسے اجزا کو دخل دیا جو اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_198.jpg',
#   'text': 'انھوں نے ڈراما لکھتے وقت اس بات کوپیش نظر رکھکر کہ یہ ایسا ہوکہ کوئی کمپنی اور وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_199.jpg',
#   'text': "میرے نزدیک وہ یوسف کی تخلیق میں بہت زیادہ کامیاب ہوے ہیں' لیکن",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_200.jpg',
#   'text': 'نگاری کی حیثیت سے ایک تصنیف لطیف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_201.jpg',
#   'text': '" زدوپشیماں" ادبی حیثیت سے، اورنیز(میں انھیں کا لفظ استعمال کرتا ہوں) کیرمکیڑ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_202.jpg',
#   'text': "میں خوش ہوں کہ 'ناظر' نے اس طرف توجہ کی ۔ اور وہ ایک بڑی حد تک کامیاب بھی ہوئے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_203.jpg',
#   'text': 'بلکہ مے میشودازصحبت ناداں بدنام',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_204.jpg',
#   'text': 'سے کہ بدنام کنداہل خدود اغلط اسٹ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_205.jpg',
#   'text': 'میں نہیں لیتے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_206.jpg',
#   'text': 'صحیح مذاق غاٹرنظر رکھنے والوں سے اس کا گلۂ قریم ہے کہ وہ اسے اپنے ہاتھوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_207.jpg',
#   'text': "زیادہ اور کوئی کیا واقف ہوگا کہ یہ فن' نا اہل ہاتھوں میں پڑکرذلیل ہوا ہے ۔ اور",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_208.jpg',
#   'text': 'کی نگاہ میں بتذل قرار دیتے ہی۔ بہت کچھ عزرخواہی کے بہے میں ذکر کیا ہے۔ ان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_209.jpg',
#   'text': "نظر آتے ہیں ۔ کیونکہ اپنے دیباچے میں انھوں نے اس میدان میں آنے کا ' جسے وہ پبلک",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_210.jpg',
#   'text': 'سجاد حیدر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_211.jpg',
#   'text': 'لکھنؤ - ۲۸ مئی ۱۹۱۷',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_212.jpg',
#   'text': 'اور کہیں نہیں ہوسکتی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_213.jpg',
#   'text': 'اس میں شک نہیں کہ "زود پشیماں" کی ٹریجڈی ہواے ہماری سوسائٹی کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_214.jpg',
#   'text': 'دلچسپ اورنہایت موثرروشنی ڈالتا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_215.jpg',
#   'text': '"زود پشیماں" ان سائل کے تاریک وغیرمنکشف پہلووں میں سے ایک پہلوپرنہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_216.jpg',
#   'text': 'کے والدین کے سررہیں ۔ میری راے  میں: مسائل نہایت غور طلب ہیں ، اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_217.jpg',
#   'text': 'کے مصارف اوراز ویا دنسل کے علاوہ باقی تمام ذمہ داریاں ، نوجوان میں بیوی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_218.jpg',
#   'text': 'دست نگر رہتے ہیں ، آیا یہ جائز بھی ہے کہ حق انتخاب تونوجوان کو دیہ  جائے اور ازدواج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_219.jpg',
#   'text': 'کے نظام میں ، جس میں عمرطبیعی کے ایک طویل حصے تک مرد بھی، اپنے والدین کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_220.jpg',
#   'text': 'ہیں توڈالنے کی کوشش کرتے بھی ہیں یانہیں ۔ اور سب سے بڑھکریہ کہ ہماری سوسائٹی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_221.jpg',
#   'text': 'رفاقت یا دام الحیات کے تمام لوازمات پرایک دورہیں نظرڈال سکتے ہیں؛ اور اگرڈ ال سکتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_222.jpg',
#   'text': 'کی ہیں جیسی کہ نواب با قرحسین سے سرزد ہوئیں، اور آیا دو نوجون ، سودا زده دل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_223.jpg',
#   'text': 'اگر میں مذہبی ذہنیت کاانسان ہوتاتوشاید میں بھی اس منظرکودیکھ کر دعائیں پڑھنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_224.jpg',
#   'text': 'نظر ڈالی-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_225.jpg',
#   'text': 'میں نے دروازہ بندکرلیااورکمرے میں واپس چلاآیا۔ ایک بار پھر میں نے مکرجیؔ پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_226.jpg',
#   'text': 'پیچھے ہوگئے۔ جب وہ روانہ ہواتومیں نے دیکھاکہ وہ بڑی قوت کے ساتھ قدم اٹھارہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_227.jpg',
#   'text': 'کا ایک اور جوڑاباہر دہلیز پر اس کا منتظرتھا۔ وہ مستعدی و سرعت سے اسکے آگے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_228.jpg',
#   'text': 'اس نے گرمجوشی سے میرا ہاتھ دبایااورکمرے کادروازہ کھول دیا۔ مستعدوہوشیارمحافظین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_229.jpg',
#   'text': 'ملنے اور سوالات کرنے کی اجازت مرحمت فرمائیں“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_230.jpg',
#   'text': 'آئیں کہ وہ مکرجیؔ کے قریبی اعزاء ہیں تواس صورت میں بھی آپ میرے آدمیوں کوان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_231.jpg',
#   'text': 'زیادہ ہوں توآپ ایک بار صرف یاک ہی کو آنے دیں۔ اگرکچھ لوگ یہ دعویٰ لے کر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_232.jpg',
#   'text': 'تحقیق حال کے لئے آئیں توآپ ان کوآنے کی اجازت دیدیں لیکن اگر وہ ایک سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_233.jpg',
#   'text': 'آنے والوں میں سے کوئی آدمی ٹیلیفون پر بات کرلے گا۔ اگر کچھ لوگ بذات خود مکرجیؔ کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_234.jpg',
#   'text': 'کرے توآپ جواب نہ دیں۔ میرے ان دو موجودہ آدمیوں میں سے کوئی شخص یا ان کی جگہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_235.jpg',
#   'text': '”ایک بات اور عرض کرنی ہے۔ اگر کوئی شخص ٹیلیفون پر مکرجیؔ کی حالت دریافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_236.jpg',
#   'text': 'دروازہ کھولنے کے لئے اس نے ہاتھ بڑھایا----- اور رک گیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_237.jpg',
#   'text': 'سے اسی چیز کو بیان کردیاتھا جس کومیں خودمحسوس کرچکاتھا لیکن الفاظ میں ادا نہ کرسکاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_238.jpg',
#   'text': '”میں نے بے اختیار”ہوں“کہہ کر اس کی تائیدکردی۔ بات یہ ہے کہ اس نے بڑی خوبی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_239.jpg',
#   'text': 'کہ--- کہ جنم کانظارہ کروں!“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_240.jpg',
#   'text': 'ایک خوف محسوس ہورہاہے۔ میں نہیں چاہتاکہ دوسرا حملہ مجھ پر ہو----- میں نہیں چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_241.jpg',
#   'text': 'نظرڈالتاہوں اور زندگی میں پہلی مرتبہ مجھے----- جلال جیسے آہنی انسان کو-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_242.jpg',
#   'text': 'نے اپنی آنکھوں کوملااورپھر دیکھا۔اس کے بعدمیں نے ڈاکٹر اشوک کواپنے پاس بلاکر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_243.jpg',
#   'text': 'ادھر بدلنے سے کسی طرح بھی اس ننھے سے شرارے میں کوئی تبدیلی رونمانہ ہوئی۔ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_244.jpg',
#   'text': 'سب سے پہلے مجھے یہ خیال ہواکہ یہ کمرے کی روشنی کاتاثر ہے لیکن روشنی کوادھر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_245.jpg',
#   'text': 'کی مانندروشن نظر آتی تھی!',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_246.jpg',
#   'text': 'لیکن اس کے اندر فاسفورس کی سی کوئی چمک وار شے موجودتھی جوکہ ایک ننھے سے قمقمے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_247.jpg',
#   'text': 'کاایک سفید ذرہ میری نگاہ کی زدمیں آگیا----- یہ محض ایک سادہ سفید ذرہئ خون تھا---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_248.jpg',
#   'text': 'ایک ناقابل یقین چیز موجودہے۔میں نے پلیٹ کوخواہ مخواہ ادھر ادھر حرکت دی تو خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_249.jpg',
#   'text': 'میں شیشے کی چوتھی پلیٹ دیکھ رہاتھا جبکہ مجھے یہ محسوس ہواکہ میری نظر کے سامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_250.jpg',
#   'text': 'ہوا بریک ہٹ جائے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_251.jpg',
#   'text': 'چیز معلوم کرسکوں گابلکہ مقصدصرف یہ تھاکہ میرے دماغ کے ایک دوسرے حصّے پر لگا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_252.jpg',
#   'text': 'کے چند دھبے لیے اور ان کامطالعہ کرنے لگا۔ ایسا کرنے سے مجھے یہ توقع نہ تھی کہ کوئی نئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_253.jpg',
#   'text': 'پر زیادہ آزادی سے سوچنے کی اہلیت پیداہوجاتی ہے۔ لہٰذا میں نے مکرجیؔ کے خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_254.jpg',
#   'text': 'ہے۔ میں نے دیکھاہے کہ خوردبینی کام میں مصروف رہنے کے دوران میرے اندر مسایل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_255.jpg',
#   'text': 'ضروری ہے لیکن اس کی کنجی میرے پاس نہیں اور قفل کاسوراخ بھی مجھے نظر نہیں آرہا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_256.jpg',
#   'text': 'میں کسی بھیانک خواب میں ایک ایسے دروازے کے باہر کھڑاہواہوں جس کوکھولنا اشد',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_257.jpg',
#   'text': 'تھا۔ یہ پورامعاملہ مجھے پریشان کئے ہوئے تھااور مجھے ایسا محسوس ہورہاتھا گویا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_258.jpg',
#   'text': 'کرکچھ ایسا لڑکھڑاگیاتھاکہ دوسروں کے سامنے اس کااعتراف کرنے کودل نہ چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_259.jpg',
#   'text': 'چہرے اورآنکھوں میں ”شیطانی اشتیاق“ اور”شیطانی مسرت“ کی تبدیلیاں دیکھ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_260.jpg',
#   'text': 'موجودتھاکہ جانچ کے مزید نتائج سے بھی کچھ ثابت نہ ہوگا۔ اس کے علاوہ میں مکرجیؔ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_261.jpg',
#   'text': 'واپس آنے کاحکم ملاہو۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_262.jpg',
#   'text': 'معلوم ہوتی تھیں جس کواپنے محبوب وپسندیدہ جہنم سے ایک طویل جلاوطنی کے بعداچانک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_263.jpg',
#   'text': 'یہ مسرت دیوانگی آمیزنہ تھی۔ یہ شیطانی مسرت تھی۔ یہ نگاہیں اس شیطان کی مسرور نگاہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_264.jpg',
#   'text': 'شعور حاصل ہورہاہو--- ان آنکھوں میں ایک ناپاک مسرت کوندرہی تھی---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_265.jpg',
#   'text': 'تین آدمیوں کی قریبی موجودگی کااحساس کر رہاہو--- جیسے اس کوپورے کمرے کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_266.jpg',
#   'text': 'اچانک مکرجیؔ کی آنکھوں میں نگاہوں کے مرکوز ہونے کی کیفیت پیداہوئی جیسے وہ ہم',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_267.jpg',
#   'text': '--- ٹھیک اسی طرح جیسے میں نے کیاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_268.jpg',
#   'text': 'نے دیکھاکہ کمارؔ نے رخ بدل کر اپنے پیچھے کی طرف نظر ڈالی اور کمرے میں ادھر ادھر دیکھا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_269.jpg',
#   'text': 'آلوددلکشی و محویت کے ساتھ مکرجیؔ کے چہرے پر جمی ہوئی تھیں --- اسی وقت میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_270.jpg',
#   'text': 'ڈاکٹرکمارؔاور نرس شیلاؔ مریض کی چارپائی کی دوسری طرف تھے۔ان کی آنکھیں خوف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_271.jpg',
#   'text': 'دروازے پر جماہواتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_272.jpg',
#   'text': 'بیٹھاہواسامنے کلیسا کی چھت کی فصیلوں کوتک رہاتھا۔دوسراآدمی مستعدی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_273.jpg',
#   'text': 'لیکن وہاں کوئی چیز موجودنہ تھی۔جلالؔ کاایک آدمی کھڑکی کے گوشے کی تاریکی میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_274.jpg',
#   'text': 'سی ہیبت ناک شے میری طرف دبے پاؤں رینگتی آرہی ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_275.jpg',
#   'text': 'مڑ کر اپنے شانے کے اوپر سے یاک نظر ڈالی یہ معلوم کرنے کے لیے کہ پشت کیطرف سے کون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_276.jpg',
#   'text': 'کہاجاسکتاہے اور یہ کیفیت اس حدتک ”شیطانی“ محسوس ہوتی تھی کہ بے اختیار میں نے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_277.jpg',
#   'text': 'نظر آتاتھالیکن اب اس کی نظروں میں ایک ایسی کیفیت تھی جس کوایک ”شیطانی اشتیاق“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_278.jpg',
#   'text': 'بھی وہ میرے جسم کے اس پار اور خوداپنے جسم کے اندر کی طرف بہ یک وقت دیکھتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_279.jpg',
#   'text': 'لگتا۔ مکرمیؔ کے چہرے کاعالم تبدیل ہوگیاتھا۔دہشت و نفرت غائب ہوچکی تھی۔ اب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_280.jpg',
#   'text': 'یاشاید اس کی وجہ یہ ہوکہ اس کومجھ پر حملہ کرنے کاموقع حاصل نہ تھا۔ میں مکرجی کیطرف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_281.jpg',
# ...
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0506.png',
#   'text': 'مہا بھارت دنیا کی طویل ترین نظم سمجھی جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0507.png',
#   'text': 'چھٹی صدی ق م سے تیسری صدی ق م تک مہا جن پد کے عروج کا دور ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0508.png',
#   'text': 'قدیم بودھ گرنتھوں انگُتّر نکائے وغیرہ میں ان سولہ ریاستوں کا کثرت سے تذکرہ ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0509.png',
#   'text': 'وادی سندھ کی تہذیب کے خاتمہ کے بعد اسی عہد میں پہلی بار ہندوستان میں بڑے بڑے شہر بسائے گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0510.png',
#   'text': 'وجی مہا جن پد کے تخت اقتدار پر لچھوی سب سے معروف قبیلہ گذرا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0511.png',
#   'text': 'سیاہ قلعی دار شمالی برتنوں کی ثقافت کا زمانہ بھی یہی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0512.png',
#   'text': '500 یا 400 ق م یعنی گوتم بدھ کے عہد تک مذکورہ سولہ مہا جن پد چار بڑی ریاستوں میں ضم ہو گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0513.png',
#   'text': 'یہ چار ریاستیں تھیں: وَتس، اَوَنتی، کوشل اور مگدھ',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0514.png',
#   'text': 'گوتم بدھ کے حالات زندگی انھی چار ریاستوں کے گرد گھومتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0515.png',
#   'text': 'مگدھ کا دور اول',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0516.png',
#   'text': 'ابتدا میں راجگیر پایۂ تخت رہا لیکن بعد میں پاٹلی پتر (موجودہ پٹنہ) منتقل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0517.png',
#   'text': 'جین اور بودھ گرنتھوں میں مگدھ کی اس قدیم سلطنت کا بارہا ذکر آیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0518.png',
#   'text': 'نیز راماین، مہا بھارت اور پرانوں میں بھی اس کا مذکور ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0519.png',
#   'text': 'جین مت اور بدھ مت کے فروغ میں سلطنت مگدھ کا خاصا اہم کردار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0520.png',
#   'text': 'مگدھ کے دائرۂ اقتدار میں بعض جمہوری برادریاں مثلاً راج کمار برادری وغیرہ بھی شامل تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0521.png',
#   'text': 'سلطنت کا نظم و انصرام عاملہ، عدلیہ اور فوج کے شعبوں میں منقسم تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0522.png',
#   'text': 'انگ کا علاقہ اب مشرقی بہار اور مغربی بنگال میں پڑتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0523.png',
#   'text': 'یہی دور ہے جس میں گوتم بدھ نے اپنی زندگی کا بیشتر حصہ مگدھ سلطنت میں گذارا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0524.png',
#   'text': 'ہریک خانوادہ کے بعد شی شو ناگ خانوادہ تخت سلطنت پر متمکن ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0525.png',
#   'text': '345 ق م میں آخری شی شو ناگ بادشاہ کالا شوک مہا پدم نند کے ہاتھوں مارا گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0526.png',
#   'text': 'مہا پدم نند نو نندوں میں سے پہلا تھا اور اس کے بعد اسی کے آٹھ بیٹے نند کہلائے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0527.png',
#   'text': 'نند سلطنت اور سکندر کی مہم',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0528.png',
#   'text': 'نند سلطنت کی سرحدیں بنگال سے پنجاب تک اور جنوب میں وندھیاچل تک پھیلی ہوئی تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0529.png',
#   'text': 'یہ نند سلطنت کے عروج کا زمانہ تھا اور اس کی ثروت اور دولت مندی کے چرچے ہر طرف تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0530.png',
#   'text': 'چنانچہ سکندر کو پنجاب اور سندھ کے میدانوں سے واپس لوٹنا پڑا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0531.png',
#   'text': 'بر صغير سے سکندر اعظم کے جانے کے بعد نند سلطنت کی بساط الٹ گئی اور موريا دور کا آغاز ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0532.png',
#   'text': 'برصغیر کی تاریخ میں پہلی بار ایسی عظیم الشان اور مستحکم سلطنت قائم ہوئی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0533.png',
#   'text': 'اس جنگ میں فتح پانے کے بعد دریائے سندھ کا مغربی خطہ بھی اس کی حکومت میں شامل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0534.png',
#   'text': 'چندر گپت کے بعد اس کا بیٹا بندو سار 297 ق م کے آس پاس تخت سلطنت پر بیٹھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0535.png',
#   'text': 'البتہ کلنگ کا علاقہ (موجودہ اوڈیشا) اس کے دائرۂ اقتدار سے باہر رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0536.png',
#   'text': 'شاید اس کی وجہ یہ تھی کہ جنوب سے کلنگ کے تجارتی روابط مضبوط تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0537.png',
#   'text': 'بندو سار کے بعد سلطنت کی باگ ڈور اشوک کے ہاتھوں میں آئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0538.png',
#   'text': 'اشوک نے 232 ق م میں اپنی وفات تک تقریباً 37 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0539.png',
#   'text': 'اس منظر نے اشوک کے وجود کو اندر سے ہلا ڈالا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0540.png',
#   'text': 'بالآخر اس نے زور و تشدد کی راہ ترک کر دی اور بدھ مت قبول کرنے کا اعلان کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0541.png',
#   'text': 'اشوک کے عہد حکومت میں بدھ مت سارے ہندوستان میں پھیل چکا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0542.png',
#   'text': 'اس دوران میں اور اس کے بعد بھی يونانيوں اور کشانوں کا اثر برقرار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0543.png',
#   'text': 'اس کا دارالخلافہ قنوج تھا جس کے کھنڈر آج بھی شمالی بھارت میں پائےجاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0544.png',
#   'text': 'جنگ کلنگ کے بعد تقریباً نصف صدی تک سلطنت میں ہر طرف امن و امان کا راج رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0545.png',
#   'text': 'یہ عوام کی فلاح و بہبود، سماجی ہم آہنگی، مذہبی تبدیلی اور علوم و فنون کی ترقی کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0546.png',
#   'text': 'ارتھ شاستر اور اشوک کے کتبے موریا دور کے احوال و وقائع کے اولین مآخذ ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0547.png',
#   'text': 'اثریات کی رو سے یہ سیاہ قلعی دار شمالی برتنوں کی تہذیب کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0548.png',
#   'text': 'موریا سلطنت کی بنیادیں اپنے عہد کی ترقی یافتہ معیشت اور ہنر مند سماج پر استوار تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0549.png',
#   'text': 'یہ فولاد چین اور عرب تک جاتا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0550.png',
#   'text': 'تیسری صدی ق م سے چوتھی صدی عیسوی تک کا زمانہ سنگم عہد کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0551.png',
#   'text': 'یہ تینوں شاہی خانوادے تمل اکام کے تاجوران ثلاثہ کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0552.png',
#   'text': 'ان کے مسائل کا بچشم خود مشاہدہ کیا اور ان کے درد و کرب کو محسوس کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0553.png',
#   'text': 'ان کا دھرم مختلف اور پیشے جدا جدا تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0554.png',
#   'text': 'ان میں کاشت کار بھی تھے، دست کار بھی تھے، دکان دار، تاجر اور پروہت بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0555.png',
#   'text': 'ان میں عورتیں بھی تھیں اور شاہزادے بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0556.png',
#   'text': 'تقریباً 300 ق م سے 200 عیسوی تک پَتو پاٹّو، ایٹو توگئی اور پَتی نَینکل کنکّو لکھے جاتے رہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0557.png',
#   'text': 'پَتو پاٹّو اوسط لمبائی کی دس نظموں کا مجموعہ ہے اور سنگم ادب کا حصہ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0558.png',
#   'text': 'نیز تمل زبان کے گرامر کی قدیم ترین کتاب تولکا پیئم بھی اسی دوران میں تصنیف کی گئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0559.png',
#   'text': 'سیلاپتی کارم کو ایلانگو ادیگل نے لکھا جو ایک غیر مذہبی رزمیہ ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0560.png',
#   'text': 'اس ظلم پر کن نکی کا جذبۂ انتقام بیدار ہوتا ہے اور سلطنت سے بدلہ لینے کی ٹھان لیتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0561.png',
#   'text': 'سیتَلئی ساتّنار نے منی میکالئی تصنیف کی جو دراصل سیلاپتی کارم ہی کا تسلسل ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0562.png',
#   'text': 'اس میں کوولن کی بیٹی مادھوی کی کہانی نظم کی گئی ہے جو بودھ بھکشونی بن جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0563.png',
#   'text': 'کلاسیکی اور اوائل قرون وسطی کے ادوار (200 ق م تا 1200ء)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0564.png',
#   'text': 'تیسری صدی عیسوی سے چھٹی صدی عیسوی کا درمیانی عرصہ ہندوستان کا کلاسیکی دور کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0565.png',
#   'text': 'یہ عہد موریہ سلطنت کے زوال سے شروع ہو کر گپت سلطنت کے زوال تک جاری رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0566.png',
#   'text': 'اس دور کو مزید مختلف ذیلی ادوار میں تقسیم کیا گیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0567.png',
#   'text': 'یہی وہ دور ہے جس میں شونگ اور ساتواہن سلطنتوں کو عروج حاصل ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0568.png',
#   'text': 'چوتھی صدی عیسوی سے چھٹی صدی عیسوی تک گپت سلطنت قائم رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0569.png',
#   'text': 'گپت سلطنت کا یہ دور ہندومت کی تاریخ کا عہد زریں سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0570.png',
#   'text': 'ابتدائی کلاسیکی دور (تقریباً 200 ق م تا تقریباً 320 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0571.png',
#   'text': 'شونگ مگدھ سے اٹھے اور برصغیر ہند کے مشرقی اور وسطی علاقوں تک اپنی سلطنت قائم کر لی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0572.png',
#   'text': 'ان کا عہد سلطنت تقریباً 187 ق م سے 78 ق م تک رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0573.png',
#   'text': 'پشیہ متر شونگ نے 36 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0574.png',
#   'text': 'بعد ازاں اس کا بیٹا اگنی متر اس کا جانشین ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0575.png',
#   'text': 'کل دس شونگ بادشاہ گذرے ہیں لیکن اگنی متر کی وفات کے بعد سلطنت کا شیرازہ تیزی سے بکھرنے لگا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0576.png',
#   'text': 'شونگ سلطنت اپنے دور حکمرانی میں بیرونی اور اندرونی دونوں طاقتوں سے نبرد آزما رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0577.png',
#   'text': 'اس نے سلطنت کو پھلنے پھولنے اور اقتدار حاصل کرنے میں خاصی مدد کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0578.png',
#   'text': 'ساتواہن سلاطین اصلاً دکنی تھے، اسی بنا پر وہ "آندھرا سلاطین" بھی کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0579.png',
#   'text': 'ساتواہن سلاطین ہندومت اور بدھ مت کے بڑے سرپرست اور مربی گذرے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0580.png',
#   'text': 'ساتواہن ان اولین ہندوستانی ریاستوں میں سے ہے جنھوں نے اپنے سکوں پر سلاطین کی شبیہ بنائی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0581.png',
#   'text': 'بالخصوص مغربی شترپوں سے ان کی کشمکش طویل عرصہ تک جاری رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0582.png',
#   'text': 'ہندوستان کی تجارت اور سیاحت',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0583.png',
#   'text': 'کیرالا کی مسالوں کی تجارت قدیم دنیا کے تاجروں کو کھینچ کھینچ کر ہندوستان لا رہی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0584.png',
#   'text': 'پہلی صدی عیسوی کے آس پاس توما رسول بحری راستے سے ہندوستان پہنچا اور موزریز ساحل پر اترا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0585.png',
#   'text': 'یہاں پہنچ کر توما نے سات گرجا گھروں کی بنیاد رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0586.png',
#   'text': 'ہندوستان کی سیاحت کرنے والے چینیوں میں فاہیان، یی جنگ، سونگ یون اور ہیون سانگ قابل ذکر ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0587.png',
#   'text': 'روم و یونان نے شاہراہ بخور اور ہند رومی شاہراہوں کے ذریعہ اپنی تجارت جاری رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0588.png',
#   'text': 'کُجُل کڈفِسیس کشان سلطنت کا پہلا فرماں روا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0589.png',
#   'text': 'شہنشاہ کنشک بدھ مت کا بڑا مربی تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0590.png',
#   'text': 'اس کے باوصف بدھ مت کے استحکام میں کشانیوں کے غیر معمولی کردار کو فراموش نہیں جا سکتا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0591.png',
#   'text': 'مورخ ونسنٹ اسمتھ کنشک کے متعلق لکھتا ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0592.png',
#   'text': 'اس عہد میں گندھارا اور متھرا کے فنون بھی بہار دکھانے لگے تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0593.png',
#   'text': 'ان میں نئے شگوفے کھلے، نئے غنچے چٹخے، نئے رجحان سامنے آئے اور یہ فنون اپنی جوبن پر آگئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0594.png',
#   'text': 'ہیو جارج رالنسن رقم طراز ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0595.png',
#   'text': 'تیسری صدی عیسوی تک پہنچتے پہنچتے کشانوں کی سلطنت بکھرنے لگی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0596.png',
#   'text': 'ان کا آخری قابل ذکر بادشاہ واسو دیو اول تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0597.png',
#   'text': 'کلاسیکی دور (320 عیسوی - 650 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0598.png',
#   'text': 'انھی وجوہ سے گپت عہد کو ہندوستانی ثقافت کی تاریخ کا اہم ترین موڑ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0599.png',
#   'text': 'اس عہد میں علوم و فنون اور سیاسی انتظام و انصرام نے نئی چوٹیاں سر کیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0600.png',
#   'text': 'یہی وجہ ہے کہ تاریخ کے چہرے پر اس عہد کو گپت سلطنت کا بوسۂ امن قرار دیا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  ...]

# %% [markdown]
# ## 5. Source 3 — Data Augmentation
#
# Same logic as the original notebook. `augments_per_image` raised from 2 to 3, so this
# now multiplies the (much bigger) synthetic set instead of just the original 50.

# %%
def augment_image(img):
    """
    Apply one random augmentation (rotation, blur, or brightness change).
    Returns (augmented_image, augmentation_type_string).
    """
    aug_type = random.choice(["rotation", "blur", "brightness"])

    if aug_type == "rotation":
        angle = random.uniform(-5, 5)
        aug_img = img.rotate(angle, expand=True, fillcolor=(255, 255, 255))
    elif aug_type == "blur":
        aug_img = img.filter(ImageFilter.GaussianBlur(radius=random.uniform(0.5, 1.5)))
    else:  # brightness
        enhancer = ImageEnhance.Brightness(img)
        aug_img = enhancer.enhance(random.uniform(0.7, 1.3))

    return aug_img, aug_type

# %%
def generate_augmented_images(source_rows, augments_per_image=2):
    """
    For each image in source_rows, create `augments_per_image` augmented variants.
    Saves them to data/raw/augmented/ and returns label row dicts.
    """
    rows  = []
    count = 0

    for row in source_rows:
        src_path = row['image']
        if not is_valid_image(src_path):
            continue

        img = Image.open(src_path)

        for j in range(augments_per_image):
            aug_img, aug_type = augment_image(img)
            save_path = (
                f"data/raw/augmented/"
                f"{Path(src_path).stem}_aug{j+1}_{aug_type}.png"
            )
            aug_img.save(save_path)
            rows.append({
                'image': save_path, 'text': row['text'],
                'source': f'augmented_{aug_type}', 'split': ''
            })
            count += 1

    print(f"Generated {count} augmented images -> data/raw/augmented/")
    return rows

# Augment the synthetic images (AUGMENTS_PER_IMAGE variants each -- was fixed at 2)
aug_rows = generate_augmented_images(synthetic_rows, augments_per_image=AUGMENTS_PER_IMAGE)
append_to_labels_csv(aug_rows)
# Out:
# Generated 1812 augmented images -> data/raw/augmented/
#   labels.csv: 2816 total entries (+1812 new).
# [{'image': 'data/raw/other/utrset_001.jpg',
#   'text': 'اندراج و تحریر شرعاً صرف مستحب اور پسندیدہ ہے وہ واجب نہیں کہ کسی شرعی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_002.jpg',
#   'text': 'اور ہندوستان کی مسلم ریاستوں میں اس پر کم و بیش عمل درآمد بھی ہے، جہاں تک جبری',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_003.jpg',
#   'text': 'بلکہ اس کے نزدیک وہ پسندیدہ اور مستحسن بھی ہے، عملی پہلوکے لحاظ سے اسلامی سلطنتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_004.jpg',
#   'text': 'جہاں تک پہلی صورت کاتعلق ہے، شریعت اسلامیہ کی رو سے اس پر اعتراض جائز نہیں،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_005.jpg',
#   'text': 'ہے، اس لیے اس کولازمی طورپر جاری کردیاجائے، اس کانام جبر ی اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_006.jpg',
#   'text': 'مقدمات سے نجات مل سکتی ہے، نکاح کے ثبوت اورک دین مہر کے تعین میں سہولت ہوتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_007.jpg',
#   'text': 'دوسرا پہلو یہ ہے کہ چونکہ اس اندراج میں بہت سی مصلحتیں ہیں، اس سے بڑی حدتک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_008.jpg',
#   'text': 'جس قدر لوگ اس پر عمل کریں اتنا ہی فائدہ ہے، اس کانام اختیاری اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_009.jpg',
#   'text': 'ایک تویہ کہ اس قسم کااندراج مفید ونافع ہے، اوراس کا رواج دینا مناسب ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_010.jpg',
#   'text': 'کے لیے غیر ضروری تسلیم کرتے ہوئے اس حیثیت سے یہ مسئلہ زیر بحث آسکتاہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_011.jpg',
#   'text': 'اسلامی حکم کے خلاف ہوگا، ہاں نکاح وطلاق کے اندراج کوصحت نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_012.jpg',
#   'text': 'جو نکاح وطلاق کی اس حیثیت پر اثر انداز ہو، قبول نہیں کیاجاسکتا، کیونکہ وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_013.jpg',
#   'text': 'نہیں ہوئی، ناجائز اور قابل انکار نہیں قرار دی جاسکتی، اس لیے کوئی ایسا قانون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_014.jpg',
#   'text': 'اورکوئی طلاق صرف اس وجہ سے کہ وہ لکھی نہیں گئی یا سرکاری رجسٹر میں درج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_015.jpg',
#   'text': 'نکاح صرف اس وجہ سے وہ لکھا نہیں گیا یا سرکاری رجسٹرمیں درج نہیں ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_016.jpg',
#   'text': 'زبانی الفاظ طلاق (بشرائط مقررہ ومعتبرہ) و قوع طلاق کے لیے کافی ہیں، کوئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_017.jpg',
#   'text': 'نہیں، مذہبی طورپر زبانی ایجاب و قبول (بشرائط مقررہ و معتبرہ) نکاح کے لیے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_018.jpg',
#   'text': 'احکام کی بناء پر نکاح وطلاق کی صحت کے لیے کتاب اور رجسٹر میں اندراج کی ضرورت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_019.jpg',
#   'text': 'اس وقت مسئلہ یہ تھا کہ نکاح وطلاق کا اندراج سرکاری طورپر ایک رجسٹرمیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_020.jpg',
#   'text': 'اس لیے اس سے ان کے خیالات کااندازہ کیاجاسکتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_021.jpg',
#   'text': 'میں قابل قبول نہیں سمجھی گئی توپھر مولاناکفایت اللہ اور مولاناقطب الدین کی تائید سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_022.jpg',
#   'text': 'فرنگی محلی وغیرہ تھے، اس کمیٹی نے جو رپورٹ تیار کی وہ یوپی کی مجلس قانون ساز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_023.jpg',
#   'text': 'کے ساتھ مولاناکفایت اللہ دہلوی،مولوی نعیم الدین مرادآبادی اور مولانا قطب الدین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_024.jpg',
#   'text': 'الہ آباد ہائی کورٹ)تھے، اس کے ممبروں میں ڈاکٹر شفاعت احمدخاں کے علاوہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_025.jpg',
#   'text': 'کو رجسٹرڈ کرنے کے لیے ایک قانون بناناتھا، اس کمیٹی کے صدر سرشاہ سلیمان (جج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_026.jpg',
#   'text': 'تھا، اس کامقصد مسلمانوں کونکاح وطلاق کے معاملات پر غور اور نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_027.jpg',
#   'text': 'الہ آباد یونیورسٹی) کی تحریک سے ایک کمیٹی بنائی گئی تھی، جس کانام ”مسلم میرج سب کمیٹی“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_028.jpg',
#   'text': 'میں یوپی کی مجلس قانون ساز میں ڈاکٹرشفاعت احمدخاں (پروفیسر تاریخ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_029.jpg',
#   'text': 'میں بڑی ہمدردی سے دلچسپی لی، جیسا کہ حسبِ ذیل تفصیلات سے اندازہ ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_030.jpg',
#   'text': 'انھوں نے قرآن مجید، حدیث اور فقہ کے اپنے گہرے مطالعہ سے ان کو حل کرنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_031.jpg',
#   'text': 'اور وراثت کے مسائل میں بہت سے سوالات پیداہوتے رہے اس سلسلہ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_032.jpg',
#   'text': 'تو متعین کردیا ہے مگر جیسا کہ پہلے بھی کہا گیاہے، ہندوستان میں ان کے نکاح،طلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_033.jpg',
#   'text': 'غیر مسلم حاکم کافیصلہ جائز نہیں ہوسکتاہے اور نہ ایسے مسلمان حاکموں سے اس کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_034.jpg',
#   'text': 'اس مشکل اس لیے حل نہیں کرسکتی ہیں کہ ان مسائل میں شرع اسلامی کے رو سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_035.jpg',
#   'text': 'جائیں جو آنریری منصف کوحاصل ہیں، تاکہ وہ اپنے اختیارات سے ایسی مشکلوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_036.jpg',
#   'text': 'مشکل یک آسان صورت یہ ہے کہ قاضیوں کوان معاملات کے لیے وہ اختیارات دیئے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_037.jpg',
#   'text': 'رجسٹری آفس بھی نئی ذمہ داریوں سے محفوظ رہیں گے(۲) اگر بالفعل یہ ممکن نہ ہو تواس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_038.jpg',
#   'text': 'ساری مشکلات دور ہوجائیں گی، عدالتیں بھی بہت سی دقتوں سے محفوظ ہوجائیں گی،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_039.jpg',
#   'text': 'قائم کردیاجائے جس کوان معاملات میں فیصلہ کرنے کاپورااختیار ہو، اس طرح تو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_040.jpg',
#   'text': 'نظام میں لاکر پورے صوبہ میں مسلمانوں کے نکاح وطلاق کے لیے ایک علیحدہ محکمہئ قضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_041.jpg',
#   'text': 'کیں کہ (۱) مسلمانوں کے ان مسائل کے لیے قاضی مقرر کیے جائیں اوران کوایک مرکزی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_042.jpg',
#   'text': 'دونوں کے لیے مصیبت کاباعث ہوتے ہیں، مسلمان لڑکیاں مظلوم بنی رہتی ہیں، اس مصیبت کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_043.jpg',
#   'text': 'وجہ سے مقدمے دائر ہوجاتے ہیں، ایسی صورت میں یہ مقدمات، خاندانوں اور عدالتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_044.jpg',
#   'text': 'مختلف صورتوں،خلع، خیار اور تفریق کے مسائل، ولی ہونے کے باہمی فرق و مراتب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_045.jpg',
#   'text': 'ہے کہ ترک وراثت، رضاعت، رشتوں کے حلال و حرام ہونے، عدت اطلاق کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_046.jpg',
#   'text': 'اس لحاظ سے بے انصافی ہوتی ہے کہ ایسے لوگ بھی ان کا نکاح پڑھا دیتے ہیں جو ممکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_047.jpg',
#   'text': 'اور تحصیلوں میں قاضیوں اور نائب قاضیوں کاتقرر کرے تو تمام مشکلات کا حل ہوجاتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_048.jpg',
#   'text': 'اور یہ قاضی القضاۃ مسلمانوں کی رضامندی اور گورنمنٹ یک منظوری سے اضلاع',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_049.jpg',
#   'text': 'اگر صوبہ کے مسلمان ایک قاضی القضاۃ کا انتخاب کریں اور گورنمنٹ اس ک منظورکرے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_050.jpg',
#   'text': 'قوت حاصل ہونے کے لیے ضروری ہے کہ حکومت اس انتخاب کوقبول کرے، اس بناء پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_051.jpg',
#   'text': 'اپنی رضامندی سے ایک قاضی کاانتخاب کریں اوراس قاضی کوتنقیدکی طاقت اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_052.jpg',
#   'text': 'منظور کرنا تقریباً ناممکن ہے، اس بناء پر اگر کوئی صورت ممکن ہے تووہ یہ ہے کہ مسلمان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_053.jpg',
#   'text': 'مسلم حکومت کیلیے خاص طورسے مسلمانوں کی خاطر ایک مستقل مسلمان والی کے تصور کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_054.jpg',
#   'text': 'مختلف مذہبوں اور قوموں کی ایسی مخلوط آبادی ہے، جس کا لحاظ کرکے یہاں کی غیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_055.jpg',
#   'text': 'قضا کے لیے تینوں مذکورہئ بالاشکلوں میں ایک شکل اختیارکرنی پڑے گی، ہندوستان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_056.jpg',
#   'text': 'میں مسلمانوں کے ان شرعی معاملات کے نظم،نسق، ترتیب، ان احکام کے احیاء اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_057.jpg',
#   'text': 'مندی سے قاضی کاانتخاب کریں، یہ تینوں شکلیں فقہ کی کتابوں میں مذکور ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_058.jpg',
#   'text': 'کردے، یہ مسلمان والی پھر قاضی مقرر کرے (۳) یہ بھی ممکن نہ ہو تو مسلمان اپنی باہمی رضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_059.jpg',
#   'text': 'ہوسکے توغیر مسلم حکومت سے مطالبہ کیاجائے کہ وہی ان پر ایک مسلمان والی مقرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_060.jpg',
#   'text': 'انتخاب کریں اور وہ قاضیوں کا تقرر کرے جو نکاح وطلاق کے مسئلے کو طے کریں (۲)یہ نہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_061.jpg',
#   'text': 'ہیں، (۱) اگر ممکن ہو تومسلمان خود اپنی طرف سے متفق اور متحد ہوکر ایک.... والی کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_062.jpg',
#   'text': 'ہو، ایسے معاملات کے نظم ونسق و ترتیب واجماء کے لیے حسب ذیل تین شکلیں تجویز کی جاسکتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_063.jpg',
#   'text': 'قانون کوجواصل میں غیر واجب ہو، واجب قرار دے، لیکن جہاں غیر مسلم حکومت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_064.jpg',
#   'text': 'صرف اما مسلمین کو پہونچتا ہے کہ وہ مسلمانوں کی مصلحتوں کی بناء پر اپنے زمانہ میں کسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_065.jpg',
#   'text': 'اختیار کے بغیر کسی تبرع اور استجاب کو واجب میں نہیں بدلا جاسکتا، یہ شرعی اختیار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_066.jpg',
#   'text': 'مہدی صاحب(بھوپال)(۳) حضرت شریف فکری بھپوال،(۴) مولینافضل الرحمن صاحب باقیؔ(کلکتہ)(۵) حضرت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_067.jpg',
#   'text': 'فرمائی ہے انکی خدمت میں ہدیہئ تشکر وامتنان پیش ہے۔ امیدکہ دیگر معاونین بھی اولین فرصت میں توجہ فرمائینگے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_068.jpg',
#   'text': ':۔  نیرنگ کی پسندیدہ خدمات کے اعتراف میں جن حضرات نے توجہ والتفات فرماکر مخصوص معاونت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_069.jpg',
#   'text': 'شکریہئ التفات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_070.jpg',
#   'text': 'رہگیااورہمیشہ کے لئے ایک سکوت، سکوتِ مرگ عاری ہوگیا۔اورحسن صباخت ور آغوش،آغوشِ فنامیں روپوش یہ تھا”ڈاخ کاخواب“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_071.jpg',
#   'text': 'سامنے یہ کچھ ہوااوراس نے دیکہا۔ وہ آگے بڑہناچاہتاتھاکہ دوخواصوں نے بڑہ کر ایک چادر بیاٹرس پر ڈالدی۔ وہ دیکہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_072.jpg',
#   'text': 'پر بوسہ یدتاہے جن پر آج سے پہلے ڈانٹے کی جرائت نہوئی اوراسکے لب اُنہیں کبہی بھی”زحمت وصل نہ دے سکے۔ مگر آہ کہ آج اوراسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_073.jpg',
#   'text': 'بڑہتاہے۔ کہ”عشق“ کی ستم ظریفی میں اضافہ ہوتاہے اور”دیوتا“اسکی محبوبہ کے قوس گوں لبوں پر اُن مرمرین گلاب کی پتیوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_074.jpg',
#   'text': 'اور بے پناہ تیر اسکے۔ دل میں پیوست کردیتاہے دانٹے اس غیر متوقع،دلخراش اورناقابل دیدنظارے کی تاب نہ لاکر آگے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_075.jpg',
#   'text': 'موت کی دستبروسے مجبور ہوکر اس سے جداہوتی ہے۔ اورحسین غالب بے جان رہی ہے، ادھر عشق دیوتااپنا تیرزہریلا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_076.jpg',
#   'text': 'اُس نے دیکہاکہ:۔ وہ ایک تالاردلکشامیں اپنی حسین ومحبوب بیوی بیاٹرس کے ساتھ بیٹھاہے۔ ’بیاٹرس اسی وقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_077.jpg',
#   'text': '”زندہ“رہ سکا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_078.jpg',
#   'text': 'کے ذریعہ کی ہے جو تقریباً انیس سال کی طویل کاوش کانتیجہ ہے۔ اورغالباً داسی، کوشش وعمل کی مصروفیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_079.jpg',
#   'text': '”محبوبہ“ کی جدائی کے کچھ عرصہ بعد”روزیٹی“ نے ایک خواب دیکہا:۔ جس کی تشریح اسکی جنبشِ قلم نے اس تصویر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_080.jpg',
#   'text': 'جداکردیا۔اور وہ حیران وپریشان اس ”بے نیازی“ کاناقابلِ فہم مظاہرہ کرتاتنہاوبیکس رہگیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_081.jpg',
#   'text': 'کچھ ہی عرصہ بعدآبادگھربرباد ہوگیا۔یعنی”روزیٹی“ کی محبوب وجمیل بیوی“ کو”پنجہئ اجل“ نے ہمیشہ کیلئے اُس سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_082.jpg',
#   'text': 'حسین نقش ونگار کونمایاں کیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_083.jpg',
#   'text': 'دونوں ایک دوسرے کے والہ و شیداہوگئے۔ روز یٹنی نے اُسکے ’اعتراف جمال‘ کی سندمیں اکثر تصاویرمین اسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_084.jpg',
#   'text': 'یہاں تک وسعت اختیار کی کہ اس کو حسینہ سے ایک ”گہراقلبی تعلق“ہوگیا۔ محبت کے پینگ بڑہے اورایسے بڑہے کہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_085.jpg',
#   'text': 'سے ایک دوست مصوّر کے ذریعہ ایک خوش جمال حسینہ سے روزبیٹی کی ملاقات ہوگئی۔رسمی تعارف حدودنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_086.jpg',
#   'text': 'کی تصویریں بولتی تصویریں کہلائی جاتی ہیں اور اپنے عہدکاکامیاب ومقبول مصوّر ہوا۔حسن اتفاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_087.jpg',
#   'text': 'ملّاصاحب کی شادی کے حالات کی دلکش تفصیلات جوخودجناب موصوف نے انداز مخصوص میں تحریر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_088.jpg',
#   'text': 'شادی۔  طابع وناشر۔ عالمگیر بکڈپولاہور۔قیمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_089.jpg',
#   'text': 'شایقین ادب کیلئے اس کتاب کامطالعہ دلچسپی کاباعث ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_090.jpg',
#   'text': 'کتابت طباعت نفیس ہے۔ملّاصاحب کے تعارف کی کوشش کرنااُنکی توہین کے مرادف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_091.jpg',
#   'text': 'ضیاء الملک ملّا رموزیؔ کے اُن مزاحیہ مضامین کامجموعہ ہے جوموقت الشیوع رسائل میں شائع ہوچکے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_092.jpg',
#   'text': 'ضخامت ص۲٤٠ ۔قیمت عصر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_093.jpg',
#   'text': 'طابع وناشر:۔ عالمگیب بکڈپو۔لاہورسائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_094.jpg',
#   'text': 'صبح لطافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_095.jpg',
#   'text': 'اہل ذوق کلام برق سے محظوظ ہوں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_096.jpg',
#   'text': 'بعدازاں مصنف کافارسی دیباچہ اورغزلیات کاانتخاب ہے کاغذکتابت طباعت عمدہ ہے۔ سرورق آرت پیپر کاہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_097.jpg',
#   'text': 'قیمت ۲ ۱/-ضخامت دوسو صفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_098.jpg',
#   'text': 'ناشر:۔ارمغاں بکڈپو،دہلی۔ سائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_099.jpg',
#   'text': 'کتابیں۔ شرارؔ برقی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_100.jpg',
#   'text': 'یہ رسالہ مستقل خریداروں کومفت ملتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_101.jpg',
#   'text': 'خداکرے مولاناواحدی صاحب کی مساعی حسنہ کامیاب ترین ثابت ہوں:',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_102.jpg',
#   'text': 'مضامین نثرونظم جوڈیڑھ سوصفحات پر مشتمل ہیں اپنی مخصوص شانِ متانت کے ساتھ شایع ہواہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_103.jpg',
#   'text': 'حاصل کیجاتی ہے۔ امسال بھی حسب سابق سیرتِ نبی اکرم صلعم کے متعددعنواناتِ مفیدہ کے ماتحت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_104.jpg',
#   'text': 'ضامن ہیں۔”رسول نمبر“ کی ابتدانظام المشایخ سے ہوئی اوراس اجتہادی عمل صالحہ میں ہر سال کامیابی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_105.jpg',
#   'text': 'متین روش اورمستقل سلامت ردی قابل ذکر ہے جوانداز وطرز ابتداسے اختیارکیاہے بدستوراسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_106.jpg',
#   'text': 'دہلی کے قدیم ترین رسالہ نظام المشایخ، کی اہم ترین خصوصیات میں اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_107.jpg',
#   'text': 'نظام المشایخ”رسول نمبر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_108.jpg',
#   'text': 'میں ہدیہ تبریک پیش کرتے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_109.jpg',
#   'text': 'ملک کے ہرپڑہے لکہے مردعورت کواس رسالہ کی معاونت کرناچاہئے۔ ہم لائق مدیر کی خدمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_110.jpg',
#   'text': 'مدیردمالک مولوی کی ادالعزمی اور حب رسول کاثبوت ہے۔ اس رسالہ کی علیحدہ قیمت ۲ ۱ رہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_111.jpg',
#   'text': 'کی ضخامت ایک روپیہ سالانہ چندہ میں خریداروں کومفت دیدیتامولوی عبدالحمیدخاں صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_112.jpg',
#   'text': 'صلعلم کی سیرتِ پاک پر مسلم اورمعتدغیر مسلم اہلِ قلم کے مفیدمضامین تقریباً ڈیرھ سوصفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_113.jpg',
#   'text': 'ونعتیہ نظموں کامتبرک مجموعہ ہے(اگرچہ اکثرنظمیں مطبوعہ ہیں،سرورق بلاک کارنگین ہے۔ سردرِ کائنات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_114.jpg',
#   'text': 'میں نہایت شان وعظت سے شائع ہواہے۔ جوتقریباً ڈیڑسوصفحات کے منتخب اورمقدس مضامین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_115.jpg',
#   'text': 'مذہبی رسالہ”مولوی“ کا”رسول نمبر“ حسب معمول عیدمیلادالنی صلعم کی تقریب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_116.jpg',
#   'text': 'مولویؔ ”رسول نمبر“۔دہلی کے سب سے سَستے اورہندوستان کے سب سے زیادہ کثیرالاشاعت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_117.jpg',
#   'text': '”نیرنگِ نظر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_118.jpg',
#   'text': 'قریب میں محاسن ومعائب پر ہرپہلوسے روشنی ڈالیں گے۔کہ اس عامیانہ ہڑبونگ کی قلعی کُہلے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_119.jpg',
#   'text': 'کامطمح نظر بھی یھی ہو۔بہرحال تفصیلات کیلئے سردست ہم اپنی رائے محفوظ رکہتے ہیں اورمستقل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_120.jpg',
#   'text': 'آزادخیال مولف کی حیثیت سے اپنی تالیف کی تدوین میں متین ثابت ہو۔ اورغالباً ڈاکٹر صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_121.jpg',
#   'text': 'فرض ہوتاہے کہ وہ”معمل“ میں ٹیہکرکسی مذہب وملّت سے متاثر نہو اور”سانٹیفک“ اصول سے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_122.jpg',
#   'text': 'رکہکر آزادانہ طورپر کسی خاص ”مذہبیت“ کی رعایت کئے بغیر تاریخ کومکمل کرے۔ کامیاب مورّخ کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_123.jpg',
#   'text': 'کے مطالعہ کی غرض سے ہے۔ اوراس لحاظ سے ایک مورّخ کافرض ہے کہ وہ فلسفہ- تاریخ کوسامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_124.jpg',
#   'text': 'ہیں کہ ڈاکٹر صاحب نے کسی خاص مذہب کیلئے یہ تاریخ مرتب نہیں کی ہے بلکہ ”ہندوستانی طلباء“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_125.jpg',
#   'text': 'ابھی بالاستیعاب نہیں پڑہاہے۔تاہم اسوقت عام غلط فہمی پہیلی ہوئی دیکہکریہ کہناضروری سمجہتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_126.jpg',
#   'text': 'مضر ہے۔ الزام یہ ہے کہ مسلمان بادشاہوں کااحترام ملحوظ نہیں رکہاگیاوغیرہ۔ ہم نے اس تاریخ کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_127.jpg',
#   'text': 'گذر کر ’ذات‘ پر بھی حملے شروع کردیئے ہیں۔ اوربتایاجارہاہے کہ یہ تاریخ مسلمان طلباء کیلئے نہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_128.jpg',
#   'text': 'کاشروع ہوئی ہے۔ ایک خاص طبقہ نے اس تاریخ کی تخریب شروع کرکے ڈاکٹر صاحب کی قابلیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_129.jpg',
#   'text': 'سلسلہ میں نہیں ہوئی۔ لیکن اب کچھ مدّت سے جب سے کہ یوپی کونسل کے مسئلہ انتخاب کی سلسلہ جنبانی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_130.jpg',
#   'text': '”تاریخِ ہند“ مرتب کی تھی۔ جس کی اشاعت کوبھی عرصہ ہوا۔ جب سے اب تک کوئی قابل ذکر رائے زنی اس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_131.jpg',
#   'text': '(فیلوالہ آبادیونیورسٹی) نے طلباء اسکول کے لئے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_132.jpg',
#   'text': 'یوپی کے مشہورفاضل مورّخ ڈاکٹر شفاعت احمدخانصاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_133.jpg',
#   'text': 'ڈاکٹر شفاعت احمدخاں کی ”تاریخ ہند',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_134.jpg',
#   'text': 'خواہ ہیں اور ارکین پریس و”نیرنگ“ احتیاط کے لئے متنبہ ہوچکے ہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_135.jpg',
#   'text': 'ہے۔اور ناظرین نیرنگ کے ’ذوق‘ کی اہانت ہے۔ اس لئے ہم اپنے معاونیں کرام سے خصوصاً عذر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_136.jpg',
#   'text': 'امرنہیں کیونکہ عموماً رسائل میں تصاویر کی اشاعت کامعیار بہی ہے۔لیکن نیرنگ کی روایات کے ضرور منافی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_137.jpg',
#   'text': 'کیا۔ اور اچہی خاصی تصاویر میں بے جوڑ چمک اورغیر متین بچپن نمایاں ہوگیا۔گوعام لحاظ سے یہ چنداں ناگوار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_138.jpg',
#   'text': 'غلط فہمی ہوئی۔ اور منیجرصاحب نے اس خیال سے کہ پرچہ وقت پرشائع کرسکیں دوبارہ صحیح طباعت سے گریز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_139.jpg',
#   'text': 'جوان ہوکر روزیٹیؔ نے فن مصوّری میں کمال حاصل کیا۔ ڈانٹے سے اکتساب کانتیجہ یہ تھاکہ ”روزیٹی ڈاناٹے“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_140.jpg',
#   'text': 'والہئ وشیداہوکر رہیگا۔ڈانٹے کی واجدانی شاعی کے اثرات اسکے دل پر نقش ہوکر رہ گئے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_141.jpg',
#   'text': 'ورشحاتِ لطیف نے روزیٹی کے قلب کوابتدائی عمر سے متاثر کرناشروع کیا۔اوروہ حسن فطرت کاپرستار اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_142.jpg',
#   'text': 'کی داستانیں اُس کے کانوں میں پڑیں۔جسکالازمی نتیجہ یہ تھاکہ وہ بھی شاعراعظم کے کمالات سے متکیف ہوااوراس کے خیالات جمیل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_143.jpg',
#   'text': 'ہوش سنبہال کر رویٹیؔ نے اپنے باپ کی زبان سے دن رات ڈانٹےؔ کے وجدآفریں اشعار سُنے اورتعریف وتوصیف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_144.jpg',
#   'text': 'باعث اُس نے اپنے بیٹے کانام”ڈانٹے جبرئیل روزیٹی“رکہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_145.jpg',
#   'text': 'روزمیٹیؔ کے باپ کومشہور ومعروف شاعراطالیہ ڈانٹے کے کمالات سے انتہائی شغف تھا۔اوراسی عقیدت کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_146.jpg',
#   'text': 'تہا۔مگر والدین ترک سکونت کرکے انگلستان آگئے تھے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_147.jpg',
#   'text': 'روزیٹیؔ ڈانٹے-- نوجوان اورکامیاب مصوّر انگلستان میں ۸۲۸۱ء میں پیداہوا۔اُسکاآبائی وطن اٹلی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_148.jpg',
#   'text': '(سرِورق کی تصویرکے ساتھ)',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_149.jpg',
#   'text': 'ڈانٹے کاخواب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_150.jpg',
#   'text': '(۶)ساریان:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_151.jpg',
#   'text': '(۵)نورِ ہدایت:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_152.jpg',
#   'text': '(۴)غزال:۔ " " " " " " " " " " قیمت۱۰',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_153.jpg',
#   'text': '(۳) بقائے دوام:۔ مصنفہ مسٹرایم اسلم لاہور طابع ناشر:۔ نسیم بکبڑ پوبار و دخانہ لاہور قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_154.jpg',
#   'text': '(۲)چینی اور جاپانی افسانے!۔ " " " " " " " " " " قیمت ۹',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_155.jpg',
#   'text': '(۱) قدیم افسانے (پہلاحصّہ)۔ طابع وناشر:۔انجمن امدادباہمی مکتبہ ابراہیّہ حیدرآباڈکن۔ قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_156.jpg',
#   'text': 'میں سے خصوصاً مندرجہ ذیل قابل ذکر ہیں:۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_157.jpg',
#   'text': 'رسیدکتب:۔ متعددکتب جوبغرض ریویوموصول ہوئی ہیں اُن پر آئندہ بالترتیب تبصرہ کیاجائیگاجن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_158.jpg',
#   'text': 'اہل نظر کودیکہناچاہیئے۔کاغذ کتاب طباعت اورضخامت”صبح لطافت“ کی مانندہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_159.jpg',
#   'text': 'معاشری پہلوؤں پر کامیاب روشنی ڈالی گئی ہے۔ بہ حیثیتِ مجموعی”ملّاصاحب کی شادی، قابل دیدہے۔ اورہر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_160.jpg',
#   'text': 'ہیں۔تفصیلاتِ تقریب پر جومباحث اس کتاب میں درج ہیں دلچسپ ہونیکے ساتھ ہی مفیداورسبق آموزہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_161.jpg',
#   'text': 'وبلند مقصد کی جس ناپاک اور گندہ طرز تحریر کے ذریے سے پامای کی گیی ہے وہ حردرجہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_162.jpg',
#   'text': 'حوادث سے کی جائے۔ لیکن افسوس ہے کہ گلکتہ یھی کے تماشاگا ہوں میں اس شریف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_163.jpg',
#   'text': 'ڈراما کا مقصد ہے، کہ مہیست اجتماعی کی اصلاح شخصی  واقعات اور روز مرہ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_164.jpg',
#   'text': 'قوّلوں کو کیا نثبت ہے؟',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_165.jpg',
#   'text': 'پڑھ کر شریف فن اور کون ہو سکتا ہے، لیکن اب امیر خسرو سے بہار وخیراباد کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_166.jpg',
#   'text': 'وہ فن ہے ، حالانکہ خودجماعت کا رتبہ فن کی حیثیت سے ہونا چاہیے تھا۔ موسیقی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_167.jpg',
#   'text': 'اصل یہ ہے کہ فن کامرتبہ اس جماعت سے کیا جارہا ہے، جبکے ہاتھ  میں اسوقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_168.jpg',
#   'text': 'افسانہ نگاری کے کاہل نامنہ ہیں ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_169.jpg',
#   'text': 'ہمرانی، حریری، زمخشری، اور سیوطی ، جن کا شمار اکابر علما میں ہے ، انکے مقامات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_170.jpg',
#   'text': 'ڈراما نویسی یا افسانہ نگاری آج فنون ادبیہ کی پست ترین سطح ہے۔ لیکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_171.jpg',
#   'text': 'ان کا تقوے کسی کو نہیں معلوم ، تا ہم وہ فن غنا کے ماہرین میں تھے ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_172.jpg',
#   'text': 'کوئی چیز عیب گیری کی مستحق نہ تھی۔ امام ملک اور حضرت عمربن عبد الغریزکا تقدس اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_173.jpg',
#   'text': 'سمجھے جاتے ہیں ، حالانکہ اس مد میں جبکہ قوم کے نام توے  مشتعل تھے۔ ان میں سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_174.jpg',
#   'text': 'ہے۔ شاعری کے سوا فنون لطیفہ کے تمام اقسام آج کل خالاف وقار وستانت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_175.jpg',
#   'text': 'بزا تہ دنیا میں کوئی شے خیر محض یا شر محض نہیں، اس کا موقع استعمال خیریا شرہوتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_176.jpg',
#   'text': '( ۲ ) مولانا سید سلیمان ندوی ناظم دارالمصنفین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_177.jpg',
#   'text': 'ارو بارونق عالیشان قصروایوان کو چھوڑ کے نہرم کھنڈروں اور عبرتناک ویرانوں  کی سیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_178.jpg',
#   'text': 'اس میں شک نہیں کہ ایک اثر پزیر دل حسرت و اندوہ کے واقعات کوزیادہ پسند کرتا ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_179.jpg',
#   'text': 'ہے کہ بجاے کا میڈمی کے حضرت "ناظر" نے اس ڈراما کا خاتمہ ٹریجڈی پر کیا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_180.jpg',
#   'text': 'لاٹ لٹریچرایک لطف   الان کے ساتھ گرانبار اور وقبق ہوگیا ہے ۔ اسی کا ایک نمونہ یہ بھی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_181.jpg',
#   'text': 'خوشی کی بات ہے کہ اس سے کسی قسم کی بدمزگی پیدا ہونے کے بجاے ڈرا ماکا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_182.jpg',
#   'text': 'اظہار کرتے وقت کی مقاموں پر وہ اپنے اصلی عالم فلسفہ میں واپس چلے گئے ہیں۔ مگر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_183.jpg',
#   'text': 'میں لائے ہیں ، جس میں علت و سبب پرغور کرنا جرم ہے۔ اسی وجہ سے جذبات کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_184.jpg',
#   'text': 'مگروہ اسے اس تصنیف میں اپنے عالم اسباب سے زبردستی کھینچ کرکے حسن و عشق کی دنیا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_185.jpg',
#   'text': 'لٹریچرمیں نظریات وقیق کا عادی ہے، اور ہرسلہ پراستدلال عنوان سے غور کرتا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_186.jpg',
#   'text': 'مصنف یعنی جناب "ناظر" کا مذاق بہت گہرا مالما نہ ہے ۔ ان کا دماغ ڈیپ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_187.jpg',
#   'text': 'حصہ اس مذاق سے اثنا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_188.jpg',
#   'text': 'نوجوان کے قلم سے کمل ہو کر اس پبلک کے سامنے پیش ہوتا ہے ، جس کا بہت ہی محدود',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_189.jpg',
#   'text': 'یہ اردو میں ایک نیا ڈر اما ہے، جو ایک فلسفیانہ دماغ والے فاضل وقابل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_190.jpg',
#   'text': '(۱) مولانا مولوی عبدالحلیم سحاب  شرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_191.jpg',
#   'text': 'تقریظات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_192.jpg',
#   'text': 'ہیں- اور اب تک من حیث المجموع انھوں نے اس حق کے استعمال میں ایسی نجیع غلطیاں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_193.jpg',
#   'text': "یا نہ دیا جائے ، اور دیاجائے توکسی حد تک ' والدین اس حق کو کس طرح استعمال کرتے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_194.jpg',
#   'text': 'اہم ترین مسائل میں سے ہے ۔ حق آنخاب ، مناکحت میں بالکل فریقین کو دیا جائے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_195.jpg',
#   'text': "انھوں نے موضوع تصنیف قرار دیا ہے' اس میں شک نہیں  کہ ہماری موجودہ سو سائٹی کے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_196.jpg',
#   'text': 'ادبی حیثیت کی تقیص کرتے ہیں ۔ ان اجزا میں جزواعظم  مسٹر بسیٹی ہیں- جس مسلے کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_197.jpg',
#   'text': 'بھی آج کل کی ناٹک کمپنی اسے اسٹیج پراجیکٹ کرسکے ایسے اجزا کو دخل دیا جو اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_198.jpg',
#   'text': 'انھوں نے ڈراما لکھتے وقت اس بات کوپیش نظر رکھکر کہ یہ ایسا ہوکہ کوئی کمپنی اور وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_199.jpg',
#   'text': "میرے نزدیک وہ یوسف کی تخلیق میں بہت زیادہ کامیاب ہوے ہیں' لیکن",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_200.jpg',
#   'text': 'نگاری کی حیثیت سے ایک تصنیف لطیف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_201.jpg',
#   'text': '" زدوپشیماں" ادبی حیثیت سے، اورنیز(میں انھیں کا لفظ استعمال کرتا ہوں) کیرمکیڑ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_202.jpg',
#   'text': "میں خوش ہوں کہ 'ناظر' نے اس طرف توجہ کی ۔ اور وہ ایک بڑی حد تک کامیاب بھی ہوئے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_203.jpg',
#   'text': 'بلکہ مے میشودازصحبت ناداں بدنام',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_204.jpg',
#   'text': 'سے کہ بدنام کنداہل خدود اغلط اسٹ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_205.jpg',
#   'text': 'میں نہیں لیتے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_206.jpg',
#   'text': 'صحیح مذاق غاٹرنظر رکھنے والوں سے اس کا گلۂ قریم ہے کہ وہ اسے اپنے ہاتھوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_207.jpg',
#   'text': "زیادہ اور کوئی کیا واقف ہوگا کہ یہ فن' نا اہل ہاتھوں میں پڑکرذلیل ہوا ہے ۔ اور",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_208.jpg',
#   'text': 'کی نگاہ میں بتذل قرار دیتے ہی۔ بہت کچھ عزرخواہی کے بہے میں ذکر کیا ہے۔ ان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_209.jpg',
#   'text': "نظر آتے ہیں ۔ کیونکہ اپنے دیباچے میں انھوں نے اس میدان میں آنے کا ' جسے وہ پبلک",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_210.jpg',
#   'text': 'سجاد حیدر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_211.jpg',
#   'text': 'لکھنؤ - ۲۸ مئی ۱۹۱۷',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_212.jpg',
#   'text': 'اور کہیں نہیں ہوسکتی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_213.jpg',
#   'text': 'اس میں شک نہیں کہ "زود پشیماں" کی ٹریجڈی ہواے ہماری سوسائٹی کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_214.jpg',
#   'text': 'دلچسپ اورنہایت موثرروشنی ڈالتا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_215.jpg',
#   'text': '"زود پشیماں" ان سائل کے تاریک وغیرمنکشف پہلووں میں سے ایک پہلوپرنہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_216.jpg',
#   'text': 'کے والدین کے سررہیں ۔ میری راے  میں: مسائل نہایت غور طلب ہیں ، اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_217.jpg',
#   'text': 'کے مصارف اوراز ویا دنسل کے علاوہ باقی تمام ذمہ داریاں ، نوجوان میں بیوی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_218.jpg',
#   'text': 'دست نگر رہتے ہیں ، آیا یہ جائز بھی ہے کہ حق انتخاب تونوجوان کو دیہ  جائے اور ازدواج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_219.jpg',
#   'text': 'کے نظام میں ، جس میں عمرطبیعی کے ایک طویل حصے تک مرد بھی، اپنے والدین کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_220.jpg',
#   'text': 'ہیں توڈالنے کی کوشش کرتے بھی ہیں یانہیں ۔ اور سب سے بڑھکریہ کہ ہماری سوسائٹی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_221.jpg',
#   'text': 'رفاقت یا دام الحیات کے تمام لوازمات پرایک دورہیں نظرڈال سکتے ہیں؛ اور اگرڈ ال سکتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_222.jpg',
#   'text': 'کی ہیں جیسی کہ نواب با قرحسین سے سرزد ہوئیں، اور آیا دو نوجون ، سودا زده دل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_223.jpg',
#   'text': 'اگر میں مذہبی ذہنیت کاانسان ہوتاتوشاید میں بھی اس منظرکودیکھ کر دعائیں پڑھنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_224.jpg',
#   'text': 'نظر ڈالی-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_225.jpg',
#   'text': 'میں نے دروازہ بندکرلیااورکمرے میں واپس چلاآیا۔ ایک بار پھر میں نے مکرجیؔ پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_226.jpg',
#   'text': 'پیچھے ہوگئے۔ جب وہ روانہ ہواتومیں نے دیکھاکہ وہ بڑی قوت کے ساتھ قدم اٹھارہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_227.jpg',
#   'text': 'کا ایک اور جوڑاباہر دہلیز پر اس کا منتظرتھا۔ وہ مستعدی و سرعت سے اسکے آگے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_228.jpg',
#   'text': 'اس نے گرمجوشی سے میرا ہاتھ دبایااورکمرے کادروازہ کھول دیا۔ مستعدوہوشیارمحافظین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_229.jpg',
#   'text': 'ملنے اور سوالات کرنے کی اجازت مرحمت فرمائیں“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_230.jpg',
#   'text': 'آئیں کہ وہ مکرجیؔ کے قریبی اعزاء ہیں تواس صورت میں بھی آپ میرے آدمیوں کوان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_231.jpg',
#   'text': 'زیادہ ہوں توآپ ایک بار صرف یاک ہی کو آنے دیں۔ اگرکچھ لوگ یہ دعویٰ لے کر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_232.jpg',
#   'text': 'تحقیق حال کے لئے آئیں توآپ ان کوآنے کی اجازت دیدیں لیکن اگر وہ ایک سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_233.jpg',
#   'text': 'آنے والوں میں سے کوئی آدمی ٹیلیفون پر بات کرلے گا۔ اگر کچھ لوگ بذات خود مکرجیؔ کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_234.jpg',
#   'text': 'کرے توآپ جواب نہ دیں۔ میرے ان دو موجودہ آدمیوں میں سے کوئی شخص یا ان کی جگہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_235.jpg',
#   'text': '”ایک بات اور عرض کرنی ہے۔ اگر کوئی شخص ٹیلیفون پر مکرجیؔ کی حالت دریافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_236.jpg',
#   'text': 'دروازہ کھولنے کے لئے اس نے ہاتھ بڑھایا----- اور رک گیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_237.jpg',
#   'text': 'سے اسی چیز کو بیان کردیاتھا جس کومیں خودمحسوس کرچکاتھا لیکن الفاظ میں ادا نہ کرسکاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_238.jpg',
#   'text': '”میں نے بے اختیار”ہوں“کہہ کر اس کی تائیدکردی۔ بات یہ ہے کہ اس نے بڑی خوبی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_239.jpg',
#   'text': 'کہ--- کہ جنم کانظارہ کروں!“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_240.jpg',
#   'text': 'ایک خوف محسوس ہورہاہے۔ میں نہیں چاہتاکہ دوسرا حملہ مجھ پر ہو----- میں نہیں چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_241.jpg',
#   'text': 'نظرڈالتاہوں اور زندگی میں پہلی مرتبہ مجھے----- جلال جیسے آہنی انسان کو-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_242.jpg',
#   'text': 'نے اپنی آنکھوں کوملااورپھر دیکھا۔اس کے بعدمیں نے ڈاکٹر اشوک کواپنے پاس بلاکر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_243.jpg',
#   'text': 'ادھر بدلنے سے کسی طرح بھی اس ننھے سے شرارے میں کوئی تبدیلی رونمانہ ہوئی۔ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_244.jpg',
#   'text': 'سب سے پہلے مجھے یہ خیال ہواکہ یہ کمرے کی روشنی کاتاثر ہے لیکن روشنی کوادھر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_245.jpg',
#   'text': 'کی مانندروشن نظر آتی تھی!',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_246.jpg',
#   'text': 'لیکن اس کے اندر فاسفورس کی سی کوئی چمک وار شے موجودتھی جوکہ ایک ننھے سے قمقمے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_247.jpg',
#   'text': 'کاایک سفید ذرہ میری نگاہ کی زدمیں آگیا----- یہ محض ایک سادہ سفید ذرہئ خون تھا---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_248.jpg',
#   'text': 'ایک ناقابل یقین چیز موجودہے۔میں نے پلیٹ کوخواہ مخواہ ادھر ادھر حرکت دی تو خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_249.jpg',
#   'text': 'میں شیشے کی چوتھی پلیٹ دیکھ رہاتھا جبکہ مجھے یہ محسوس ہواکہ میری نظر کے سامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_250.jpg',
#   'text': 'ہوا بریک ہٹ جائے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_251.jpg',
#   'text': 'چیز معلوم کرسکوں گابلکہ مقصدصرف یہ تھاکہ میرے دماغ کے ایک دوسرے حصّے پر لگا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_252.jpg',
#   'text': 'کے چند دھبے لیے اور ان کامطالعہ کرنے لگا۔ ایسا کرنے سے مجھے یہ توقع نہ تھی کہ کوئی نئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_253.jpg',
#   'text': 'پر زیادہ آزادی سے سوچنے کی اہلیت پیداہوجاتی ہے۔ لہٰذا میں نے مکرجیؔ کے خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_254.jpg',
#   'text': 'ہے۔ میں نے دیکھاہے کہ خوردبینی کام میں مصروف رہنے کے دوران میرے اندر مسایل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_255.jpg',
#   'text': 'ضروری ہے لیکن اس کی کنجی میرے پاس نہیں اور قفل کاسوراخ بھی مجھے نظر نہیں آرہا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_256.jpg',
#   'text': 'میں کسی بھیانک خواب میں ایک ایسے دروازے کے باہر کھڑاہواہوں جس کوکھولنا اشد',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_257.jpg',
#   'text': 'تھا۔ یہ پورامعاملہ مجھے پریشان کئے ہوئے تھااور مجھے ایسا محسوس ہورہاتھا گویا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_258.jpg',
#   'text': 'کرکچھ ایسا لڑکھڑاگیاتھاکہ دوسروں کے سامنے اس کااعتراف کرنے کودل نہ چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_259.jpg',
#   'text': 'چہرے اورآنکھوں میں ”شیطانی اشتیاق“ اور”شیطانی مسرت“ کی تبدیلیاں دیکھ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_260.jpg',
#   'text': 'موجودتھاکہ جانچ کے مزید نتائج سے بھی کچھ ثابت نہ ہوگا۔ اس کے علاوہ میں مکرجیؔ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_261.jpg',
#   'text': 'واپس آنے کاحکم ملاہو۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_262.jpg',
#   'text': 'معلوم ہوتی تھیں جس کواپنے محبوب وپسندیدہ جہنم سے ایک طویل جلاوطنی کے بعداچانک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_263.jpg',
#   'text': 'یہ مسرت دیوانگی آمیزنہ تھی۔ یہ شیطانی مسرت تھی۔ یہ نگاہیں اس شیطان کی مسرور نگاہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_264.jpg',
#   'text': 'شعور حاصل ہورہاہو--- ان آنکھوں میں ایک ناپاک مسرت کوندرہی تھی---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_265.jpg',
#   'text': 'تین آدمیوں کی قریبی موجودگی کااحساس کر رہاہو--- جیسے اس کوپورے کمرے کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_266.jpg',
#   'text': 'اچانک مکرجیؔ کی آنکھوں میں نگاہوں کے مرکوز ہونے کی کیفیت پیداہوئی جیسے وہ ہم',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_267.jpg',
#   'text': '--- ٹھیک اسی طرح جیسے میں نے کیاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_268.jpg',
#   'text': 'نے دیکھاکہ کمارؔ نے رخ بدل کر اپنے پیچھے کی طرف نظر ڈالی اور کمرے میں ادھر ادھر دیکھا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_269.jpg',
#   'text': 'آلوددلکشی و محویت کے ساتھ مکرجیؔ کے چہرے پر جمی ہوئی تھیں --- اسی وقت میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_270.jpg',
#   'text': 'ڈاکٹرکمارؔاور نرس شیلاؔ مریض کی چارپائی کی دوسری طرف تھے۔ان کی آنکھیں خوف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_271.jpg',
#   'text': 'دروازے پر جماہواتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_272.jpg',
#   'text': 'بیٹھاہواسامنے کلیسا کی چھت کی فصیلوں کوتک رہاتھا۔دوسراآدمی مستعدی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_273.jpg',
#   'text': 'لیکن وہاں کوئی چیز موجودنہ تھی۔جلالؔ کاایک آدمی کھڑکی کے گوشے کی تاریکی میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_274.jpg',
#   'text': 'سی ہیبت ناک شے میری طرف دبے پاؤں رینگتی آرہی ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_275.jpg',
#   'text': 'مڑ کر اپنے شانے کے اوپر سے یاک نظر ڈالی یہ معلوم کرنے کے لیے کہ پشت کیطرف سے کون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_276.jpg',
#   'text': 'کہاجاسکتاہے اور یہ کیفیت اس حدتک ”شیطانی“ محسوس ہوتی تھی کہ بے اختیار میں نے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_277.jpg',
#   'text': 'نظر آتاتھالیکن اب اس کی نظروں میں ایک ایسی کیفیت تھی جس کوایک ”شیطانی اشتیاق“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_278.jpg',
#   'text': 'بھی وہ میرے جسم کے اس پار اور خوداپنے جسم کے اندر کی طرف بہ یک وقت دیکھتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_279.jpg',
#   'text': 'لگتا۔ مکرمیؔ کے چہرے کاعالم تبدیل ہوگیاتھا۔دہشت و نفرت غائب ہوچکی تھی۔ اب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_280.jpg',
#   'text': 'یاشاید اس کی وجہ یہ ہوکہ اس کومجھ پر حملہ کرنے کاموقع حاصل نہ تھا۔ میں مکرجی کیطرف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_281.jpg',
# ...
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0506.png',
#   'text': 'مہا بھارت دنیا کی طویل ترین نظم سمجھی جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0507.png',
#   'text': 'چھٹی صدی ق م سے تیسری صدی ق م تک مہا جن پد کے عروج کا دور ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0508.png',
#   'text': 'قدیم بودھ گرنتھوں انگُتّر نکائے وغیرہ میں ان سولہ ریاستوں کا کثرت سے تذکرہ ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0509.png',
#   'text': 'وادی سندھ کی تہذیب کے خاتمہ کے بعد اسی عہد میں پہلی بار ہندوستان میں بڑے بڑے شہر بسائے گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0510.png',
#   'text': 'وجی مہا جن پد کے تخت اقتدار پر لچھوی سب سے معروف قبیلہ گذرا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0511.png',
#   'text': 'سیاہ قلعی دار شمالی برتنوں کی ثقافت کا زمانہ بھی یہی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0512.png',
#   'text': '500 یا 400 ق م یعنی گوتم بدھ کے عہد تک مذکورہ سولہ مہا جن پد چار بڑی ریاستوں میں ضم ہو گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0513.png',
#   'text': 'یہ چار ریاستیں تھیں: وَتس، اَوَنتی، کوشل اور مگدھ',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0514.png',
#   'text': 'گوتم بدھ کے حالات زندگی انھی چار ریاستوں کے گرد گھومتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0515.png',
#   'text': 'مگدھ کا دور اول',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0516.png',
#   'text': 'ابتدا میں راجگیر پایۂ تخت رہا لیکن بعد میں پاٹلی پتر (موجودہ پٹنہ) منتقل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0517.png',
#   'text': 'جین اور بودھ گرنتھوں میں مگدھ کی اس قدیم سلطنت کا بارہا ذکر آیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0518.png',
#   'text': 'نیز راماین، مہا بھارت اور پرانوں میں بھی اس کا مذکور ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0519.png',
#   'text': 'جین مت اور بدھ مت کے فروغ میں سلطنت مگدھ کا خاصا اہم کردار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0520.png',
#   'text': 'مگدھ کے دائرۂ اقتدار میں بعض جمہوری برادریاں مثلاً راج کمار برادری وغیرہ بھی شامل تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0521.png',
#   'text': 'سلطنت کا نظم و انصرام عاملہ، عدلیہ اور فوج کے شعبوں میں منقسم تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0522.png',
#   'text': 'انگ کا علاقہ اب مشرقی بہار اور مغربی بنگال میں پڑتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0523.png',
#   'text': 'یہی دور ہے جس میں گوتم بدھ نے اپنی زندگی کا بیشتر حصہ مگدھ سلطنت میں گذارا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0524.png',
#   'text': 'ہریک خانوادہ کے بعد شی شو ناگ خانوادہ تخت سلطنت پر متمکن ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0525.png',
#   'text': '345 ق م میں آخری شی شو ناگ بادشاہ کالا شوک مہا پدم نند کے ہاتھوں مارا گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0526.png',
#   'text': 'مہا پدم نند نو نندوں میں سے پہلا تھا اور اس کے بعد اسی کے آٹھ بیٹے نند کہلائے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0527.png',
#   'text': 'نند سلطنت اور سکندر کی مہم',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0528.png',
#   'text': 'نند سلطنت کی سرحدیں بنگال سے پنجاب تک اور جنوب میں وندھیاچل تک پھیلی ہوئی تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0529.png',
#   'text': 'یہ نند سلطنت کے عروج کا زمانہ تھا اور اس کی ثروت اور دولت مندی کے چرچے ہر طرف تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0530.png',
#   'text': 'چنانچہ سکندر کو پنجاب اور سندھ کے میدانوں سے واپس لوٹنا پڑا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0531.png',
#   'text': 'بر صغير سے سکندر اعظم کے جانے کے بعد نند سلطنت کی بساط الٹ گئی اور موريا دور کا آغاز ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0532.png',
#   'text': 'برصغیر کی تاریخ میں پہلی بار ایسی عظیم الشان اور مستحکم سلطنت قائم ہوئی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0533.png',
#   'text': 'اس جنگ میں فتح پانے کے بعد دریائے سندھ کا مغربی خطہ بھی اس کی حکومت میں شامل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0534.png',
#   'text': 'چندر گپت کے بعد اس کا بیٹا بندو سار 297 ق م کے آس پاس تخت سلطنت پر بیٹھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0535.png',
#   'text': 'البتہ کلنگ کا علاقہ (موجودہ اوڈیشا) اس کے دائرۂ اقتدار سے باہر رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0536.png',
#   'text': 'شاید اس کی وجہ یہ تھی کہ جنوب سے کلنگ کے تجارتی روابط مضبوط تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0537.png',
#   'text': 'بندو سار کے بعد سلطنت کی باگ ڈور اشوک کے ہاتھوں میں آئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0538.png',
#   'text': 'اشوک نے 232 ق م میں اپنی وفات تک تقریباً 37 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0539.png',
#   'text': 'اس منظر نے اشوک کے وجود کو اندر سے ہلا ڈالا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0540.png',
#   'text': 'بالآخر اس نے زور و تشدد کی راہ ترک کر دی اور بدھ مت قبول کرنے کا اعلان کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0541.png',
#   'text': 'اشوک کے عہد حکومت میں بدھ مت سارے ہندوستان میں پھیل چکا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0542.png',
#   'text': 'اس دوران میں اور اس کے بعد بھی يونانيوں اور کشانوں کا اثر برقرار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0543.png',
#   'text': 'اس کا دارالخلافہ قنوج تھا جس کے کھنڈر آج بھی شمالی بھارت میں پائےجاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0544.png',
#   'text': 'جنگ کلنگ کے بعد تقریباً نصف صدی تک سلطنت میں ہر طرف امن و امان کا راج رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0545.png',
#   'text': 'یہ عوام کی فلاح و بہبود، سماجی ہم آہنگی، مذہبی تبدیلی اور علوم و فنون کی ترقی کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0546.png',
#   'text': 'ارتھ شاستر اور اشوک کے کتبے موریا دور کے احوال و وقائع کے اولین مآخذ ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0547.png',
#   'text': 'اثریات کی رو سے یہ سیاہ قلعی دار شمالی برتنوں کی تہذیب کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0548.png',
#   'text': 'موریا سلطنت کی بنیادیں اپنے عہد کی ترقی یافتہ معیشت اور ہنر مند سماج پر استوار تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0549.png',
#   'text': 'یہ فولاد چین اور عرب تک جاتا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0550.png',
#   'text': 'تیسری صدی ق م سے چوتھی صدی عیسوی تک کا زمانہ سنگم عہد کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0551.png',
#   'text': 'یہ تینوں شاہی خانوادے تمل اکام کے تاجوران ثلاثہ کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0552.png',
#   'text': 'ان کے مسائل کا بچشم خود مشاہدہ کیا اور ان کے درد و کرب کو محسوس کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0553.png',
#   'text': 'ان کا دھرم مختلف اور پیشے جدا جدا تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0554.png',
#   'text': 'ان میں کاشت کار بھی تھے، دست کار بھی تھے، دکان دار، تاجر اور پروہت بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0555.png',
#   'text': 'ان میں عورتیں بھی تھیں اور شاہزادے بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0556.png',
#   'text': 'تقریباً 300 ق م سے 200 عیسوی تک پَتو پاٹّو، ایٹو توگئی اور پَتی نَینکل کنکّو لکھے جاتے رہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0557.png',
#   'text': 'پَتو پاٹّو اوسط لمبائی کی دس نظموں کا مجموعہ ہے اور سنگم ادب کا حصہ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0558.png',
#   'text': 'نیز تمل زبان کے گرامر کی قدیم ترین کتاب تولکا پیئم بھی اسی دوران میں تصنیف کی گئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0559.png',
#   'text': 'سیلاپتی کارم کو ایلانگو ادیگل نے لکھا جو ایک غیر مذہبی رزمیہ ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0560.png',
#   'text': 'اس ظلم پر کن نکی کا جذبۂ انتقام بیدار ہوتا ہے اور سلطنت سے بدلہ لینے کی ٹھان لیتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0561.png',
#   'text': 'سیتَلئی ساتّنار نے منی میکالئی تصنیف کی جو دراصل سیلاپتی کارم ہی کا تسلسل ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0562.png',
#   'text': 'اس میں کوولن کی بیٹی مادھوی کی کہانی نظم کی گئی ہے جو بودھ بھکشونی بن جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0563.png',
#   'text': 'کلاسیکی اور اوائل قرون وسطی کے ادوار (200 ق م تا 1200ء)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0564.png',
#   'text': 'تیسری صدی عیسوی سے چھٹی صدی عیسوی کا درمیانی عرصہ ہندوستان کا کلاسیکی دور کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0565.png',
#   'text': 'یہ عہد موریہ سلطنت کے زوال سے شروع ہو کر گپت سلطنت کے زوال تک جاری رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0566.png',
#   'text': 'اس دور کو مزید مختلف ذیلی ادوار میں تقسیم کیا گیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0567.png',
#   'text': 'یہی وہ دور ہے جس میں شونگ اور ساتواہن سلطنتوں کو عروج حاصل ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0568.png',
#   'text': 'چوتھی صدی عیسوی سے چھٹی صدی عیسوی تک گپت سلطنت قائم رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0569.png',
#   'text': 'گپت سلطنت کا یہ دور ہندومت کی تاریخ کا عہد زریں سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0570.png',
#   'text': 'ابتدائی کلاسیکی دور (تقریباً 200 ق م تا تقریباً 320 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0571.png',
#   'text': 'شونگ مگدھ سے اٹھے اور برصغیر ہند کے مشرقی اور وسطی علاقوں تک اپنی سلطنت قائم کر لی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0572.png',
#   'text': 'ان کا عہد سلطنت تقریباً 187 ق م سے 78 ق م تک رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0573.png',
#   'text': 'پشیہ متر شونگ نے 36 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0574.png',
#   'text': 'بعد ازاں اس کا بیٹا اگنی متر اس کا جانشین ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0575.png',
#   'text': 'کل دس شونگ بادشاہ گذرے ہیں لیکن اگنی متر کی وفات کے بعد سلطنت کا شیرازہ تیزی سے بکھرنے لگا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0576.png',
#   'text': 'شونگ سلطنت اپنے دور حکمرانی میں بیرونی اور اندرونی دونوں طاقتوں سے نبرد آزما رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0577.png',
#   'text': 'اس نے سلطنت کو پھلنے پھولنے اور اقتدار حاصل کرنے میں خاصی مدد کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0578.png',
#   'text': 'ساتواہن سلاطین اصلاً دکنی تھے، اسی بنا پر وہ "آندھرا سلاطین" بھی کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0579.png',
#   'text': 'ساتواہن سلاطین ہندومت اور بدھ مت کے بڑے سرپرست اور مربی گذرے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0580.png',
#   'text': 'ساتواہن ان اولین ہندوستانی ریاستوں میں سے ہے جنھوں نے اپنے سکوں پر سلاطین کی شبیہ بنائی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0581.png',
#   'text': 'بالخصوص مغربی شترپوں سے ان کی کشمکش طویل عرصہ تک جاری رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0582.png',
#   'text': 'ہندوستان کی تجارت اور سیاحت',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0583.png',
#   'text': 'کیرالا کی مسالوں کی تجارت قدیم دنیا کے تاجروں کو کھینچ کھینچ کر ہندوستان لا رہی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0584.png',
#   'text': 'پہلی صدی عیسوی کے آس پاس توما رسول بحری راستے سے ہندوستان پہنچا اور موزریز ساحل پر اترا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0585.png',
#   'text': 'یہاں پہنچ کر توما نے سات گرجا گھروں کی بنیاد رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0586.png',
#   'text': 'ہندوستان کی سیاحت کرنے والے چینیوں میں فاہیان، یی جنگ، سونگ یون اور ہیون سانگ قابل ذکر ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0587.png',
#   'text': 'روم و یونان نے شاہراہ بخور اور ہند رومی شاہراہوں کے ذریعہ اپنی تجارت جاری رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0588.png',
#   'text': 'کُجُل کڈفِسیس کشان سلطنت کا پہلا فرماں روا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0589.png',
#   'text': 'شہنشاہ کنشک بدھ مت کا بڑا مربی تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0590.png',
#   'text': 'اس کے باوصف بدھ مت کے استحکام میں کشانیوں کے غیر معمولی کردار کو فراموش نہیں جا سکتا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0591.png',
#   'text': 'مورخ ونسنٹ اسمتھ کنشک کے متعلق لکھتا ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0592.png',
#   'text': 'اس عہد میں گندھارا اور متھرا کے فنون بھی بہار دکھانے لگے تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0593.png',
#   'text': 'ان میں نئے شگوفے کھلے، نئے غنچے چٹخے، نئے رجحان سامنے آئے اور یہ فنون اپنی جوبن پر آگئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0594.png',
#   'text': 'ہیو جارج رالنسن رقم طراز ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0595.png',
#   'text': 'تیسری صدی عیسوی تک پہنچتے پہنچتے کشانوں کی سلطنت بکھرنے لگی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0596.png',
#   'text': 'ان کا آخری قابل ذکر بادشاہ واسو دیو اول تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0597.png',
#   'text': 'کلاسیکی دور (320 عیسوی - 650 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0598.png',
#   'text': 'انھی وجوہ سے گپت عہد کو ہندوستانی ثقافت کی تاریخ کا اہم ترین موڑ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0599.png',
#   'text': 'اس عہد میں علوم و فنون اور سیاسی انتظام و انصرام نے نئی چوٹیاں سر کیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0600.png',
#   'text': 'یہی وجہ ہے کہ تاریخ کے چہرے پر اس عہد کو گپت سلطنت کا بوسۂ امن قرار دیا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  ...]

# %% [markdown]
# ## 6. Source 4 — Books (Synthetic Book-Page Images)
#
# Same rendering (wrapped multi-line paragraphs, off-white background, light blur on
# half). **~150 real paragraph-length sentences from the Wikipedia pool**, instead of
# 8 hardcoded ones.
#
# > **Have real book photos instead?** Skip to the optional **Section 6a — Real Photos**
# > near the end, which extracts a ZIP of real photos into the correct folders.

# %%
BOOK_PARAGRAPHS = [s for s in URDU_SENTENCE_POOL if 60 <= len(s) <= 250][:TARGET_BOOK_PARAS]
print(f"Using {len(BOOK_PARAGRAPHS)} paragraph-length sentences for book-page images.")


def render_book_image(text, width=800):
    """
    Render a long Urdu paragraph as a book-page-style image:
    wrapped across multiple lines, right-aligned, off-white background.
    Returns the PIL Image object.
    """
    bg_color = random.choice([(245, 240, 230), (250, 247, 240), (240, 234, 214)])
    text_color = (26, 26, 26)
    font_obj = font_medium

    reshaped_lines = []
    for line in textwrap.wrap(text, width=28):
        reshaped = arabic_reshaper.reshape(line)
        reshaped_lines.append(get_display(reshaped))

    line_height = 45
    height = 80 + line_height * len(reshaped_lines)

    img = Image.new("RGB", (width, height), color=bg_color)
    draw = ImageDraw.Draw(img)

    for i, line in enumerate(reshaped_lines):
        bbox = draw.textbbox((0, 0), line, font=font_obj)
        line_w = bbox[2] - bbox[0]
        x = width - 50 - line_w   # right-aligned, RTL style
        y = 40 + i * line_height
        draw.text((x, y), line, fill=text_color, font=font_obj)

    # Light blur on half the images to mimic a scanned page
    if random.random() < 0.5:
        img = img.filter(ImageFilter.GaussianBlur(radius=0.4))

    return img
# Out:
# Using 150 paragraph-length sentences for book-page images.

# %%
def generate_book_images():
    """
    Render all BOOK_PARAGRAPHS into book-page-style images and
    save them to data/raw/books/. Returns a list of label row dicts.
    """
    rows = []
    count = 0

    for i, text in enumerate(BOOK_PARAGRAPHS):
        img = render_book_image(text)
        save_path = f"data/raw/books/book_{i+1:03d}.png"
        img.save(save_path)
        rows.append({
            'image': save_path, 'text': text,
            'source': 'books_synthetic', 'split': ''
        })
        count += 1

    print(f"Generated {count} book-page images -> data/raw/books/")
    return rows


book_rows = generate_book_images()
append_to_labels_csv(book_rows)
# Out:
# Generated 150 book-page images -> data/raw/books/
#   labels.csv: 2966 total entries (+150 new).
# [{'image': 'data/raw/other/utrset_001.jpg',
#   'text': 'اندراج و تحریر شرعاً صرف مستحب اور پسندیدہ ہے وہ واجب نہیں کہ کسی شرعی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_002.jpg',
#   'text': 'اور ہندوستان کی مسلم ریاستوں میں اس پر کم و بیش عمل درآمد بھی ہے، جہاں تک جبری',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_003.jpg',
#   'text': 'بلکہ اس کے نزدیک وہ پسندیدہ اور مستحسن بھی ہے، عملی پہلوکے لحاظ سے اسلامی سلطنتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_004.jpg',
#   'text': 'جہاں تک پہلی صورت کاتعلق ہے، شریعت اسلامیہ کی رو سے اس پر اعتراض جائز نہیں،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_005.jpg',
#   'text': 'ہے، اس لیے اس کولازمی طورپر جاری کردیاجائے، اس کانام جبر ی اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_006.jpg',
#   'text': 'مقدمات سے نجات مل سکتی ہے، نکاح کے ثبوت اورک دین مہر کے تعین میں سہولت ہوتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_007.jpg',
#   'text': 'دوسرا پہلو یہ ہے کہ چونکہ اس اندراج میں بہت سی مصلحتیں ہیں، اس سے بڑی حدتک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_008.jpg',
#   'text': 'جس قدر لوگ اس پر عمل کریں اتنا ہی فائدہ ہے، اس کانام اختیاری اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_009.jpg',
#   'text': 'ایک تویہ کہ اس قسم کااندراج مفید ونافع ہے، اوراس کا رواج دینا مناسب ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_010.jpg',
#   'text': 'کے لیے غیر ضروری تسلیم کرتے ہوئے اس حیثیت سے یہ مسئلہ زیر بحث آسکتاہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_011.jpg',
#   'text': 'اسلامی حکم کے خلاف ہوگا، ہاں نکاح وطلاق کے اندراج کوصحت نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_012.jpg',
#   'text': 'جو نکاح وطلاق کی اس حیثیت پر اثر انداز ہو، قبول نہیں کیاجاسکتا، کیونکہ وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_013.jpg',
#   'text': 'نہیں ہوئی، ناجائز اور قابل انکار نہیں قرار دی جاسکتی، اس لیے کوئی ایسا قانون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_014.jpg',
#   'text': 'اورکوئی طلاق صرف اس وجہ سے کہ وہ لکھی نہیں گئی یا سرکاری رجسٹر میں درج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_015.jpg',
#   'text': 'نکاح صرف اس وجہ سے وہ لکھا نہیں گیا یا سرکاری رجسٹرمیں درج نہیں ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_016.jpg',
#   'text': 'زبانی الفاظ طلاق (بشرائط مقررہ ومعتبرہ) و قوع طلاق کے لیے کافی ہیں، کوئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_017.jpg',
#   'text': 'نہیں، مذہبی طورپر زبانی ایجاب و قبول (بشرائط مقررہ و معتبرہ) نکاح کے لیے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_018.jpg',
#   'text': 'احکام کی بناء پر نکاح وطلاق کی صحت کے لیے کتاب اور رجسٹر میں اندراج کی ضرورت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_019.jpg',
#   'text': 'اس وقت مسئلہ یہ تھا کہ نکاح وطلاق کا اندراج سرکاری طورپر ایک رجسٹرمیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_020.jpg',
#   'text': 'اس لیے اس سے ان کے خیالات کااندازہ کیاجاسکتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_021.jpg',
#   'text': 'میں قابل قبول نہیں سمجھی گئی توپھر مولاناکفایت اللہ اور مولاناقطب الدین کی تائید سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_022.jpg',
#   'text': 'فرنگی محلی وغیرہ تھے، اس کمیٹی نے جو رپورٹ تیار کی وہ یوپی کی مجلس قانون ساز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_023.jpg',
#   'text': 'کے ساتھ مولاناکفایت اللہ دہلوی،مولوی نعیم الدین مرادآبادی اور مولانا قطب الدین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_024.jpg',
#   'text': 'الہ آباد ہائی کورٹ)تھے، اس کے ممبروں میں ڈاکٹر شفاعت احمدخاں کے علاوہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_025.jpg',
#   'text': 'کو رجسٹرڈ کرنے کے لیے ایک قانون بناناتھا، اس کمیٹی کے صدر سرشاہ سلیمان (جج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_026.jpg',
#   'text': 'تھا، اس کامقصد مسلمانوں کونکاح وطلاق کے معاملات پر غور اور نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_027.jpg',
#   'text': 'الہ آباد یونیورسٹی) کی تحریک سے ایک کمیٹی بنائی گئی تھی، جس کانام ”مسلم میرج سب کمیٹی“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_028.jpg',
#   'text': 'میں یوپی کی مجلس قانون ساز میں ڈاکٹرشفاعت احمدخاں (پروفیسر تاریخ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_029.jpg',
#   'text': 'میں بڑی ہمدردی سے دلچسپی لی، جیسا کہ حسبِ ذیل تفصیلات سے اندازہ ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_030.jpg',
#   'text': 'انھوں نے قرآن مجید، حدیث اور فقہ کے اپنے گہرے مطالعہ سے ان کو حل کرنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_031.jpg',
#   'text': 'اور وراثت کے مسائل میں بہت سے سوالات پیداہوتے رہے اس سلسلہ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_032.jpg',
#   'text': 'تو متعین کردیا ہے مگر جیسا کہ پہلے بھی کہا گیاہے، ہندوستان میں ان کے نکاح،طلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_033.jpg',
#   'text': 'غیر مسلم حاکم کافیصلہ جائز نہیں ہوسکتاہے اور نہ ایسے مسلمان حاکموں سے اس کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_034.jpg',
#   'text': 'اس مشکل اس لیے حل نہیں کرسکتی ہیں کہ ان مسائل میں شرع اسلامی کے رو سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_035.jpg',
#   'text': 'جائیں جو آنریری منصف کوحاصل ہیں، تاکہ وہ اپنے اختیارات سے ایسی مشکلوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_036.jpg',
#   'text': 'مشکل یک آسان صورت یہ ہے کہ قاضیوں کوان معاملات کے لیے وہ اختیارات دیئے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_037.jpg',
#   'text': 'رجسٹری آفس بھی نئی ذمہ داریوں سے محفوظ رہیں گے(۲) اگر بالفعل یہ ممکن نہ ہو تواس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_038.jpg',
#   'text': 'ساری مشکلات دور ہوجائیں گی، عدالتیں بھی بہت سی دقتوں سے محفوظ ہوجائیں گی،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_039.jpg',
#   'text': 'قائم کردیاجائے جس کوان معاملات میں فیصلہ کرنے کاپورااختیار ہو، اس طرح تو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_040.jpg',
#   'text': 'نظام میں لاکر پورے صوبہ میں مسلمانوں کے نکاح وطلاق کے لیے ایک علیحدہ محکمہئ قضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_041.jpg',
#   'text': 'کیں کہ (۱) مسلمانوں کے ان مسائل کے لیے قاضی مقرر کیے جائیں اوران کوایک مرکزی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_042.jpg',
#   'text': 'دونوں کے لیے مصیبت کاباعث ہوتے ہیں، مسلمان لڑکیاں مظلوم بنی رہتی ہیں، اس مصیبت کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_043.jpg',
#   'text': 'وجہ سے مقدمے دائر ہوجاتے ہیں، ایسی صورت میں یہ مقدمات، خاندانوں اور عدالتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_044.jpg',
#   'text': 'مختلف صورتوں،خلع، خیار اور تفریق کے مسائل، ولی ہونے کے باہمی فرق و مراتب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_045.jpg',
#   'text': 'ہے کہ ترک وراثت، رضاعت، رشتوں کے حلال و حرام ہونے، عدت اطلاق کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_046.jpg',
#   'text': 'اس لحاظ سے بے انصافی ہوتی ہے کہ ایسے لوگ بھی ان کا نکاح پڑھا دیتے ہیں جو ممکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_047.jpg',
#   'text': 'اور تحصیلوں میں قاضیوں اور نائب قاضیوں کاتقرر کرے تو تمام مشکلات کا حل ہوجاتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_048.jpg',
#   'text': 'اور یہ قاضی القضاۃ مسلمانوں کی رضامندی اور گورنمنٹ یک منظوری سے اضلاع',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_049.jpg',
#   'text': 'اگر صوبہ کے مسلمان ایک قاضی القضاۃ کا انتخاب کریں اور گورنمنٹ اس ک منظورکرے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_050.jpg',
#   'text': 'قوت حاصل ہونے کے لیے ضروری ہے کہ حکومت اس انتخاب کوقبول کرے، اس بناء پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_051.jpg',
#   'text': 'اپنی رضامندی سے ایک قاضی کاانتخاب کریں اوراس قاضی کوتنقیدکی طاقت اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_052.jpg',
#   'text': 'منظور کرنا تقریباً ناممکن ہے، اس بناء پر اگر کوئی صورت ممکن ہے تووہ یہ ہے کہ مسلمان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_053.jpg',
#   'text': 'مسلم حکومت کیلیے خاص طورسے مسلمانوں کی خاطر ایک مستقل مسلمان والی کے تصور کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_054.jpg',
#   'text': 'مختلف مذہبوں اور قوموں کی ایسی مخلوط آبادی ہے، جس کا لحاظ کرکے یہاں کی غیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_055.jpg',
#   'text': 'قضا کے لیے تینوں مذکورہئ بالاشکلوں میں ایک شکل اختیارکرنی پڑے گی، ہندوستان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_056.jpg',
#   'text': 'میں مسلمانوں کے ان شرعی معاملات کے نظم،نسق، ترتیب، ان احکام کے احیاء اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_057.jpg',
#   'text': 'مندی سے قاضی کاانتخاب کریں، یہ تینوں شکلیں فقہ کی کتابوں میں مذکور ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_058.jpg',
#   'text': 'کردے، یہ مسلمان والی پھر قاضی مقرر کرے (۳) یہ بھی ممکن نہ ہو تو مسلمان اپنی باہمی رضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_059.jpg',
#   'text': 'ہوسکے توغیر مسلم حکومت سے مطالبہ کیاجائے کہ وہی ان پر ایک مسلمان والی مقرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_060.jpg',
#   'text': 'انتخاب کریں اور وہ قاضیوں کا تقرر کرے جو نکاح وطلاق کے مسئلے کو طے کریں (۲)یہ نہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_061.jpg',
#   'text': 'ہیں، (۱) اگر ممکن ہو تومسلمان خود اپنی طرف سے متفق اور متحد ہوکر ایک.... والی کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_062.jpg',
#   'text': 'ہو، ایسے معاملات کے نظم ونسق و ترتیب واجماء کے لیے حسب ذیل تین شکلیں تجویز کی جاسکتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_063.jpg',
#   'text': 'قانون کوجواصل میں غیر واجب ہو، واجب قرار دے، لیکن جہاں غیر مسلم حکومت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_064.jpg',
#   'text': 'صرف اما مسلمین کو پہونچتا ہے کہ وہ مسلمانوں کی مصلحتوں کی بناء پر اپنے زمانہ میں کسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_065.jpg',
#   'text': 'اختیار کے بغیر کسی تبرع اور استجاب کو واجب میں نہیں بدلا جاسکتا، یہ شرعی اختیار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_066.jpg',
#   'text': 'مہدی صاحب(بھوپال)(۳) حضرت شریف فکری بھپوال،(۴) مولینافضل الرحمن صاحب باقیؔ(کلکتہ)(۵) حضرت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_067.jpg',
#   'text': 'فرمائی ہے انکی خدمت میں ہدیہئ تشکر وامتنان پیش ہے۔ امیدکہ دیگر معاونین بھی اولین فرصت میں توجہ فرمائینگے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_068.jpg',
#   'text': ':۔  نیرنگ کی پسندیدہ خدمات کے اعتراف میں جن حضرات نے توجہ والتفات فرماکر مخصوص معاونت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_069.jpg',
#   'text': 'شکریہئ التفات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_070.jpg',
#   'text': 'رہگیااورہمیشہ کے لئے ایک سکوت، سکوتِ مرگ عاری ہوگیا۔اورحسن صباخت ور آغوش،آغوشِ فنامیں روپوش یہ تھا”ڈاخ کاخواب“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_071.jpg',
#   'text': 'سامنے یہ کچھ ہوااوراس نے دیکہا۔ وہ آگے بڑہناچاہتاتھاکہ دوخواصوں نے بڑہ کر ایک چادر بیاٹرس پر ڈالدی۔ وہ دیکہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_072.jpg',
#   'text': 'پر بوسہ یدتاہے جن پر آج سے پہلے ڈانٹے کی جرائت نہوئی اوراسکے لب اُنہیں کبہی بھی”زحمت وصل نہ دے سکے۔ مگر آہ کہ آج اوراسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_073.jpg',
#   'text': 'بڑہتاہے۔ کہ”عشق“ کی ستم ظریفی میں اضافہ ہوتاہے اور”دیوتا“اسکی محبوبہ کے قوس گوں لبوں پر اُن مرمرین گلاب کی پتیوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_074.jpg',
#   'text': 'اور بے پناہ تیر اسکے۔ دل میں پیوست کردیتاہے دانٹے اس غیر متوقع،دلخراش اورناقابل دیدنظارے کی تاب نہ لاکر آگے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_075.jpg',
#   'text': 'موت کی دستبروسے مجبور ہوکر اس سے جداہوتی ہے۔ اورحسین غالب بے جان رہی ہے، ادھر عشق دیوتااپنا تیرزہریلا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_076.jpg',
#   'text': 'اُس نے دیکہاکہ:۔ وہ ایک تالاردلکشامیں اپنی حسین ومحبوب بیوی بیاٹرس کے ساتھ بیٹھاہے۔ ’بیاٹرس اسی وقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_077.jpg',
#   'text': '”زندہ“رہ سکا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_078.jpg',
#   'text': 'کے ذریعہ کی ہے جو تقریباً انیس سال کی طویل کاوش کانتیجہ ہے۔ اورغالباً داسی، کوشش وعمل کی مصروفیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_079.jpg',
#   'text': '”محبوبہ“ کی جدائی کے کچھ عرصہ بعد”روزیٹی“ نے ایک خواب دیکہا:۔ جس کی تشریح اسکی جنبشِ قلم نے اس تصویر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_080.jpg',
#   'text': 'جداکردیا۔اور وہ حیران وپریشان اس ”بے نیازی“ کاناقابلِ فہم مظاہرہ کرتاتنہاوبیکس رہگیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_081.jpg',
#   'text': 'کچھ ہی عرصہ بعدآبادگھربرباد ہوگیا۔یعنی”روزیٹی“ کی محبوب وجمیل بیوی“ کو”پنجہئ اجل“ نے ہمیشہ کیلئے اُس سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_082.jpg',
#   'text': 'حسین نقش ونگار کونمایاں کیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_083.jpg',
#   'text': 'دونوں ایک دوسرے کے والہ و شیداہوگئے۔ روز یٹنی نے اُسکے ’اعتراف جمال‘ کی سندمیں اکثر تصاویرمین اسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_084.jpg',
#   'text': 'یہاں تک وسعت اختیار کی کہ اس کو حسینہ سے ایک ”گہراقلبی تعلق“ہوگیا۔ محبت کے پینگ بڑہے اورایسے بڑہے کہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_085.jpg',
#   'text': 'سے ایک دوست مصوّر کے ذریعہ ایک خوش جمال حسینہ سے روزبیٹی کی ملاقات ہوگئی۔رسمی تعارف حدودنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_086.jpg',
#   'text': 'کی تصویریں بولتی تصویریں کہلائی جاتی ہیں اور اپنے عہدکاکامیاب ومقبول مصوّر ہوا۔حسن اتفاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_087.jpg',
#   'text': 'ملّاصاحب کی شادی کے حالات کی دلکش تفصیلات جوخودجناب موصوف نے انداز مخصوص میں تحریر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_088.jpg',
#   'text': 'شادی۔  طابع وناشر۔ عالمگیر بکڈپولاہور۔قیمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_089.jpg',
#   'text': 'شایقین ادب کیلئے اس کتاب کامطالعہ دلچسپی کاباعث ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_090.jpg',
#   'text': 'کتابت طباعت نفیس ہے۔ملّاصاحب کے تعارف کی کوشش کرنااُنکی توہین کے مرادف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_091.jpg',
#   'text': 'ضیاء الملک ملّا رموزیؔ کے اُن مزاحیہ مضامین کامجموعہ ہے جوموقت الشیوع رسائل میں شائع ہوچکے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_092.jpg',
#   'text': 'ضخامت ص۲٤٠ ۔قیمت عصر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_093.jpg',
#   'text': 'طابع وناشر:۔ عالمگیب بکڈپو۔لاہورسائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_094.jpg',
#   'text': 'صبح لطافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_095.jpg',
#   'text': 'اہل ذوق کلام برق سے محظوظ ہوں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_096.jpg',
#   'text': 'بعدازاں مصنف کافارسی دیباچہ اورغزلیات کاانتخاب ہے کاغذکتابت طباعت عمدہ ہے۔ سرورق آرت پیپر کاہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_097.jpg',
#   'text': 'قیمت ۲ ۱/-ضخامت دوسو صفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_098.jpg',
#   'text': 'ناشر:۔ارمغاں بکڈپو،دہلی۔ سائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_099.jpg',
#   'text': 'کتابیں۔ شرارؔ برقی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_100.jpg',
#   'text': 'یہ رسالہ مستقل خریداروں کومفت ملتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_101.jpg',
#   'text': 'خداکرے مولاناواحدی صاحب کی مساعی حسنہ کامیاب ترین ثابت ہوں:',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_102.jpg',
#   'text': 'مضامین نثرونظم جوڈیڑھ سوصفحات پر مشتمل ہیں اپنی مخصوص شانِ متانت کے ساتھ شایع ہواہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_103.jpg',
#   'text': 'حاصل کیجاتی ہے۔ امسال بھی حسب سابق سیرتِ نبی اکرم صلعم کے متعددعنواناتِ مفیدہ کے ماتحت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_104.jpg',
#   'text': 'ضامن ہیں۔”رسول نمبر“ کی ابتدانظام المشایخ سے ہوئی اوراس اجتہادی عمل صالحہ میں ہر سال کامیابی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_105.jpg',
#   'text': 'متین روش اورمستقل سلامت ردی قابل ذکر ہے جوانداز وطرز ابتداسے اختیارکیاہے بدستوراسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_106.jpg',
#   'text': 'دہلی کے قدیم ترین رسالہ نظام المشایخ، کی اہم ترین خصوصیات میں اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_107.jpg',
#   'text': 'نظام المشایخ”رسول نمبر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_108.jpg',
#   'text': 'میں ہدیہ تبریک پیش کرتے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_109.jpg',
#   'text': 'ملک کے ہرپڑہے لکہے مردعورت کواس رسالہ کی معاونت کرناچاہئے۔ ہم لائق مدیر کی خدمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_110.jpg',
#   'text': 'مدیردمالک مولوی کی ادالعزمی اور حب رسول کاثبوت ہے۔ اس رسالہ کی علیحدہ قیمت ۲ ۱ رہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_111.jpg',
#   'text': 'کی ضخامت ایک روپیہ سالانہ چندہ میں خریداروں کومفت دیدیتامولوی عبدالحمیدخاں صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_112.jpg',
#   'text': 'صلعلم کی سیرتِ پاک پر مسلم اورمعتدغیر مسلم اہلِ قلم کے مفیدمضامین تقریباً ڈیرھ سوصفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_113.jpg',
#   'text': 'ونعتیہ نظموں کامتبرک مجموعہ ہے(اگرچہ اکثرنظمیں مطبوعہ ہیں،سرورق بلاک کارنگین ہے۔ سردرِ کائنات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_114.jpg',
#   'text': 'میں نہایت شان وعظت سے شائع ہواہے۔ جوتقریباً ڈیڑسوصفحات کے منتخب اورمقدس مضامین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_115.jpg',
#   'text': 'مذہبی رسالہ”مولوی“ کا”رسول نمبر“ حسب معمول عیدمیلادالنی صلعم کی تقریب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_116.jpg',
#   'text': 'مولویؔ ”رسول نمبر“۔دہلی کے سب سے سَستے اورہندوستان کے سب سے زیادہ کثیرالاشاعت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_117.jpg',
#   'text': '”نیرنگِ نظر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_118.jpg',
#   'text': 'قریب میں محاسن ومعائب پر ہرپہلوسے روشنی ڈالیں گے۔کہ اس عامیانہ ہڑبونگ کی قلعی کُہلے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_119.jpg',
#   'text': 'کامطمح نظر بھی یھی ہو۔بہرحال تفصیلات کیلئے سردست ہم اپنی رائے محفوظ رکہتے ہیں اورمستقل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_120.jpg',
#   'text': 'آزادخیال مولف کی حیثیت سے اپنی تالیف کی تدوین میں متین ثابت ہو۔ اورغالباً ڈاکٹر صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_121.jpg',
#   'text': 'فرض ہوتاہے کہ وہ”معمل“ میں ٹیہکرکسی مذہب وملّت سے متاثر نہو اور”سانٹیفک“ اصول سے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_122.jpg',
#   'text': 'رکہکر آزادانہ طورپر کسی خاص ”مذہبیت“ کی رعایت کئے بغیر تاریخ کومکمل کرے۔ کامیاب مورّخ کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_123.jpg',
#   'text': 'کے مطالعہ کی غرض سے ہے۔ اوراس لحاظ سے ایک مورّخ کافرض ہے کہ وہ فلسفہ- تاریخ کوسامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_124.jpg',
#   'text': 'ہیں کہ ڈاکٹر صاحب نے کسی خاص مذہب کیلئے یہ تاریخ مرتب نہیں کی ہے بلکہ ”ہندوستانی طلباء“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_125.jpg',
#   'text': 'ابھی بالاستیعاب نہیں پڑہاہے۔تاہم اسوقت عام غلط فہمی پہیلی ہوئی دیکہکریہ کہناضروری سمجہتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_126.jpg',
#   'text': 'مضر ہے۔ الزام یہ ہے کہ مسلمان بادشاہوں کااحترام ملحوظ نہیں رکہاگیاوغیرہ۔ ہم نے اس تاریخ کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_127.jpg',
#   'text': 'گذر کر ’ذات‘ پر بھی حملے شروع کردیئے ہیں۔ اوربتایاجارہاہے کہ یہ تاریخ مسلمان طلباء کیلئے نہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_128.jpg',
#   'text': 'کاشروع ہوئی ہے۔ ایک خاص طبقہ نے اس تاریخ کی تخریب شروع کرکے ڈاکٹر صاحب کی قابلیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_129.jpg',
#   'text': 'سلسلہ میں نہیں ہوئی۔ لیکن اب کچھ مدّت سے جب سے کہ یوپی کونسل کے مسئلہ انتخاب کی سلسلہ جنبانی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_130.jpg',
#   'text': '”تاریخِ ہند“ مرتب کی تھی۔ جس کی اشاعت کوبھی عرصہ ہوا۔ جب سے اب تک کوئی قابل ذکر رائے زنی اس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_131.jpg',
#   'text': '(فیلوالہ آبادیونیورسٹی) نے طلباء اسکول کے لئے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_132.jpg',
#   'text': 'یوپی کے مشہورفاضل مورّخ ڈاکٹر شفاعت احمدخانصاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_133.jpg',
#   'text': 'ڈاکٹر شفاعت احمدخاں کی ”تاریخ ہند',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_134.jpg',
#   'text': 'خواہ ہیں اور ارکین پریس و”نیرنگ“ احتیاط کے لئے متنبہ ہوچکے ہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_135.jpg',
#   'text': 'ہے۔اور ناظرین نیرنگ کے ’ذوق‘ کی اہانت ہے۔ اس لئے ہم اپنے معاونیں کرام سے خصوصاً عذر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_136.jpg',
#   'text': 'امرنہیں کیونکہ عموماً رسائل میں تصاویر کی اشاعت کامعیار بہی ہے۔لیکن نیرنگ کی روایات کے ضرور منافی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_137.jpg',
#   'text': 'کیا۔ اور اچہی خاصی تصاویر میں بے جوڑ چمک اورغیر متین بچپن نمایاں ہوگیا۔گوعام لحاظ سے یہ چنداں ناگوار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_138.jpg',
#   'text': 'غلط فہمی ہوئی۔ اور منیجرصاحب نے اس خیال سے کہ پرچہ وقت پرشائع کرسکیں دوبارہ صحیح طباعت سے گریز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_139.jpg',
#   'text': 'جوان ہوکر روزیٹیؔ نے فن مصوّری میں کمال حاصل کیا۔ ڈانٹے سے اکتساب کانتیجہ یہ تھاکہ ”روزیٹی ڈاناٹے“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_140.jpg',
#   'text': 'والہئ وشیداہوکر رہیگا۔ڈانٹے کی واجدانی شاعی کے اثرات اسکے دل پر نقش ہوکر رہ گئے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_141.jpg',
#   'text': 'ورشحاتِ لطیف نے روزیٹی کے قلب کوابتدائی عمر سے متاثر کرناشروع کیا۔اوروہ حسن فطرت کاپرستار اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_142.jpg',
#   'text': 'کی داستانیں اُس کے کانوں میں پڑیں۔جسکالازمی نتیجہ یہ تھاکہ وہ بھی شاعراعظم کے کمالات سے متکیف ہوااوراس کے خیالات جمیل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_143.jpg',
#   'text': 'ہوش سنبہال کر رویٹیؔ نے اپنے باپ کی زبان سے دن رات ڈانٹےؔ کے وجدآفریں اشعار سُنے اورتعریف وتوصیف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_144.jpg',
#   'text': 'باعث اُس نے اپنے بیٹے کانام”ڈانٹے جبرئیل روزیٹی“رکہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_145.jpg',
#   'text': 'روزمیٹیؔ کے باپ کومشہور ومعروف شاعراطالیہ ڈانٹے کے کمالات سے انتہائی شغف تھا۔اوراسی عقیدت کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_146.jpg',
#   'text': 'تہا۔مگر والدین ترک سکونت کرکے انگلستان آگئے تھے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_147.jpg',
#   'text': 'روزیٹیؔ ڈانٹے-- نوجوان اورکامیاب مصوّر انگلستان میں ۸۲۸۱ء میں پیداہوا۔اُسکاآبائی وطن اٹلی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_148.jpg',
#   'text': '(سرِورق کی تصویرکے ساتھ)',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_149.jpg',
#   'text': 'ڈانٹے کاخواب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_150.jpg',
#   'text': '(۶)ساریان:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_151.jpg',
#   'text': '(۵)نورِ ہدایت:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_152.jpg',
#   'text': '(۴)غزال:۔ " " " " " " " " " " قیمت۱۰',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_153.jpg',
#   'text': '(۳) بقائے دوام:۔ مصنفہ مسٹرایم اسلم لاہور طابع ناشر:۔ نسیم بکبڑ پوبار و دخانہ لاہور قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_154.jpg',
#   'text': '(۲)چینی اور جاپانی افسانے!۔ " " " " " " " " " " قیمت ۹',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_155.jpg',
#   'text': '(۱) قدیم افسانے (پہلاحصّہ)۔ طابع وناشر:۔انجمن امدادباہمی مکتبہ ابراہیّہ حیدرآباڈکن۔ قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_156.jpg',
#   'text': 'میں سے خصوصاً مندرجہ ذیل قابل ذکر ہیں:۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_157.jpg',
#   'text': 'رسیدکتب:۔ متعددکتب جوبغرض ریویوموصول ہوئی ہیں اُن پر آئندہ بالترتیب تبصرہ کیاجائیگاجن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_158.jpg',
#   'text': 'اہل نظر کودیکہناچاہیئے۔کاغذ کتاب طباعت اورضخامت”صبح لطافت“ کی مانندہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_159.jpg',
#   'text': 'معاشری پہلوؤں پر کامیاب روشنی ڈالی گئی ہے۔ بہ حیثیتِ مجموعی”ملّاصاحب کی شادی، قابل دیدہے۔ اورہر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_160.jpg',
#   'text': 'ہیں۔تفصیلاتِ تقریب پر جومباحث اس کتاب میں درج ہیں دلچسپ ہونیکے ساتھ ہی مفیداورسبق آموزہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_161.jpg',
#   'text': 'وبلند مقصد کی جس ناپاک اور گندہ طرز تحریر کے ذریے سے پامای کی گیی ہے وہ حردرجہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_162.jpg',
#   'text': 'حوادث سے کی جائے۔ لیکن افسوس ہے کہ گلکتہ یھی کے تماشاگا ہوں میں اس شریف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_163.jpg',
#   'text': 'ڈراما کا مقصد ہے، کہ مہیست اجتماعی کی اصلاح شخصی  واقعات اور روز مرہ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_164.jpg',
#   'text': 'قوّلوں کو کیا نثبت ہے؟',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_165.jpg',
#   'text': 'پڑھ کر شریف فن اور کون ہو سکتا ہے، لیکن اب امیر خسرو سے بہار وخیراباد کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_166.jpg',
#   'text': 'وہ فن ہے ، حالانکہ خودجماعت کا رتبہ فن کی حیثیت سے ہونا چاہیے تھا۔ موسیقی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_167.jpg',
#   'text': 'اصل یہ ہے کہ فن کامرتبہ اس جماعت سے کیا جارہا ہے، جبکے ہاتھ  میں اسوقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_168.jpg',
#   'text': 'افسانہ نگاری کے کاہل نامنہ ہیں ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_169.jpg',
#   'text': 'ہمرانی، حریری، زمخشری، اور سیوطی ، جن کا شمار اکابر علما میں ہے ، انکے مقامات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_170.jpg',
#   'text': 'ڈراما نویسی یا افسانہ نگاری آج فنون ادبیہ کی پست ترین سطح ہے۔ لیکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_171.jpg',
#   'text': 'ان کا تقوے کسی کو نہیں معلوم ، تا ہم وہ فن غنا کے ماہرین میں تھے ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_172.jpg',
#   'text': 'کوئی چیز عیب گیری کی مستحق نہ تھی۔ امام ملک اور حضرت عمربن عبد الغریزکا تقدس اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_173.jpg',
#   'text': 'سمجھے جاتے ہیں ، حالانکہ اس مد میں جبکہ قوم کے نام توے  مشتعل تھے۔ ان میں سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_174.jpg',
#   'text': 'ہے۔ شاعری کے سوا فنون لطیفہ کے تمام اقسام آج کل خالاف وقار وستانت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_175.jpg',
#   'text': 'بزا تہ دنیا میں کوئی شے خیر محض یا شر محض نہیں، اس کا موقع استعمال خیریا شرہوتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_176.jpg',
#   'text': '( ۲ ) مولانا سید سلیمان ندوی ناظم دارالمصنفین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_177.jpg',
#   'text': 'ارو بارونق عالیشان قصروایوان کو چھوڑ کے نہرم کھنڈروں اور عبرتناک ویرانوں  کی سیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_178.jpg',
#   'text': 'اس میں شک نہیں کہ ایک اثر پزیر دل حسرت و اندوہ کے واقعات کوزیادہ پسند کرتا ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_179.jpg',
#   'text': 'ہے کہ بجاے کا میڈمی کے حضرت "ناظر" نے اس ڈراما کا خاتمہ ٹریجڈی پر کیا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_180.jpg',
#   'text': 'لاٹ لٹریچرایک لطف   الان کے ساتھ گرانبار اور وقبق ہوگیا ہے ۔ اسی کا ایک نمونہ یہ بھی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_181.jpg',
#   'text': 'خوشی کی بات ہے کہ اس سے کسی قسم کی بدمزگی پیدا ہونے کے بجاے ڈرا ماکا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_182.jpg',
#   'text': 'اظہار کرتے وقت کی مقاموں پر وہ اپنے اصلی عالم فلسفہ میں واپس چلے گئے ہیں۔ مگر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_183.jpg',
#   'text': 'میں لائے ہیں ، جس میں علت و سبب پرغور کرنا جرم ہے۔ اسی وجہ سے جذبات کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_184.jpg',
#   'text': 'مگروہ اسے اس تصنیف میں اپنے عالم اسباب سے زبردستی کھینچ کرکے حسن و عشق کی دنیا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_185.jpg',
#   'text': 'لٹریچرمیں نظریات وقیق کا عادی ہے، اور ہرسلہ پراستدلال عنوان سے غور کرتا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_186.jpg',
#   'text': 'مصنف یعنی جناب "ناظر" کا مذاق بہت گہرا مالما نہ ہے ۔ ان کا دماغ ڈیپ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_187.jpg',
#   'text': 'حصہ اس مذاق سے اثنا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_188.jpg',
#   'text': 'نوجوان کے قلم سے کمل ہو کر اس پبلک کے سامنے پیش ہوتا ہے ، جس کا بہت ہی محدود',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_189.jpg',
#   'text': 'یہ اردو میں ایک نیا ڈر اما ہے، جو ایک فلسفیانہ دماغ والے فاضل وقابل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_190.jpg',
#   'text': '(۱) مولانا مولوی عبدالحلیم سحاب  شرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_191.jpg',
#   'text': 'تقریظات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_192.jpg',
#   'text': 'ہیں- اور اب تک من حیث المجموع انھوں نے اس حق کے استعمال میں ایسی نجیع غلطیاں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_193.jpg',
#   'text': "یا نہ دیا جائے ، اور دیاجائے توکسی حد تک ' والدین اس حق کو کس طرح استعمال کرتے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_194.jpg',
#   'text': 'اہم ترین مسائل میں سے ہے ۔ حق آنخاب ، مناکحت میں بالکل فریقین کو دیا جائے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_195.jpg',
#   'text': "انھوں نے موضوع تصنیف قرار دیا ہے' اس میں شک نہیں  کہ ہماری موجودہ سو سائٹی کے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_196.jpg',
#   'text': 'ادبی حیثیت کی تقیص کرتے ہیں ۔ ان اجزا میں جزواعظم  مسٹر بسیٹی ہیں- جس مسلے کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_197.jpg',
#   'text': 'بھی آج کل کی ناٹک کمپنی اسے اسٹیج پراجیکٹ کرسکے ایسے اجزا کو دخل دیا جو اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_198.jpg',
#   'text': 'انھوں نے ڈراما لکھتے وقت اس بات کوپیش نظر رکھکر کہ یہ ایسا ہوکہ کوئی کمپنی اور وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_199.jpg',
#   'text': "میرے نزدیک وہ یوسف کی تخلیق میں بہت زیادہ کامیاب ہوے ہیں' لیکن",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_200.jpg',
#   'text': 'نگاری کی حیثیت سے ایک تصنیف لطیف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_201.jpg',
#   'text': '" زدوپشیماں" ادبی حیثیت سے، اورنیز(میں انھیں کا لفظ استعمال کرتا ہوں) کیرمکیڑ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_202.jpg',
#   'text': "میں خوش ہوں کہ 'ناظر' نے اس طرف توجہ کی ۔ اور وہ ایک بڑی حد تک کامیاب بھی ہوئے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_203.jpg',
#   'text': 'بلکہ مے میشودازصحبت ناداں بدنام',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_204.jpg',
#   'text': 'سے کہ بدنام کنداہل خدود اغلط اسٹ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_205.jpg',
#   'text': 'میں نہیں لیتے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_206.jpg',
#   'text': 'صحیح مذاق غاٹرنظر رکھنے والوں سے اس کا گلۂ قریم ہے کہ وہ اسے اپنے ہاتھوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_207.jpg',
#   'text': "زیادہ اور کوئی کیا واقف ہوگا کہ یہ فن' نا اہل ہاتھوں میں پڑکرذلیل ہوا ہے ۔ اور",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_208.jpg',
#   'text': 'کی نگاہ میں بتذل قرار دیتے ہی۔ بہت کچھ عزرخواہی کے بہے میں ذکر کیا ہے۔ ان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_209.jpg',
#   'text': "نظر آتے ہیں ۔ کیونکہ اپنے دیباچے میں انھوں نے اس میدان میں آنے کا ' جسے وہ پبلک",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_210.jpg',
#   'text': 'سجاد حیدر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_211.jpg',
#   'text': 'لکھنؤ - ۲۸ مئی ۱۹۱۷',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_212.jpg',
#   'text': 'اور کہیں نہیں ہوسکتی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_213.jpg',
#   'text': 'اس میں شک نہیں کہ "زود پشیماں" کی ٹریجڈی ہواے ہماری سوسائٹی کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_214.jpg',
#   'text': 'دلچسپ اورنہایت موثرروشنی ڈالتا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_215.jpg',
#   'text': '"زود پشیماں" ان سائل کے تاریک وغیرمنکشف پہلووں میں سے ایک پہلوپرنہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_216.jpg',
#   'text': 'کے والدین کے سررہیں ۔ میری راے  میں: مسائل نہایت غور طلب ہیں ، اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_217.jpg',
#   'text': 'کے مصارف اوراز ویا دنسل کے علاوہ باقی تمام ذمہ داریاں ، نوجوان میں بیوی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_218.jpg',
#   'text': 'دست نگر رہتے ہیں ، آیا یہ جائز بھی ہے کہ حق انتخاب تونوجوان کو دیہ  جائے اور ازدواج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_219.jpg',
#   'text': 'کے نظام میں ، جس میں عمرطبیعی کے ایک طویل حصے تک مرد بھی، اپنے والدین کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_220.jpg',
#   'text': 'ہیں توڈالنے کی کوشش کرتے بھی ہیں یانہیں ۔ اور سب سے بڑھکریہ کہ ہماری سوسائٹی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_221.jpg',
#   'text': 'رفاقت یا دام الحیات کے تمام لوازمات پرایک دورہیں نظرڈال سکتے ہیں؛ اور اگرڈ ال سکتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_222.jpg',
#   'text': 'کی ہیں جیسی کہ نواب با قرحسین سے سرزد ہوئیں، اور آیا دو نوجون ، سودا زده دل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_223.jpg',
#   'text': 'اگر میں مذہبی ذہنیت کاانسان ہوتاتوشاید میں بھی اس منظرکودیکھ کر دعائیں پڑھنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_224.jpg',
#   'text': 'نظر ڈالی-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_225.jpg',
#   'text': 'میں نے دروازہ بندکرلیااورکمرے میں واپس چلاآیا۔ ایک بار پھر میں نے مکرجیؔ پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_226.jpg',
#   'text': 'پیچھے ہوگئے۔ جب وہ روانہ ہواتومیں نے دیکھاکہ وہ بڑی قوت کے ساتھ قدم اٹھارہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_227.jpg',
#   'text': 'کا ایک اور جوڑاباہر دہلیز پر اس کا منتظرتھا۔ وہ مستعدی و سرعت سے اسکے آگے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_228.jpg',
#   'text': 'اس نے گرمجوشی سے میرا ہاتھ دبایااورکمرے کادروازہ کھول دیا۔ مستعدوہوشیارمحافظین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_229.jpg',
#   'text': 'ملنے اور سوالات کرنے کی اجازت مرحمت فرمائیں“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_230.jpg',
#   'text': 'آئیں کہ وہ مکرجیؔ کے قریبی اعزاء ہیں تواس صورت میں بھی آپ میرے آدمیوں کوان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_231.jpg',
#   'text': 'زیادہ ہوں توآپ ایک بار صرف یاک ہی کو آنے دیں۔ اگرکچھ لوگ یہ دعویٰ لے کر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_232.jpg',
#   'text': 'تحقیق حال کے لئے آئیں توآپ ان کوآنے کی اجازت دیدیں لیکن اگر وہ ایک سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_233.jpg',
#   'text': 'آنے والوں میں سے کوئی آدمی ٹیلیفون پر بات کرلے گا۔ اگر کچھ لوگ بذات خود مکرجیؔ کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_234.jpg',
#   'text': 'کرے توآپ جواب نہ دیں۔ میرے ان دو موجودہ آدمیوں میں سے کوئی شخص یا ان کی جگہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_235.jpg',
#   'text': '”ایک بات اور عرض کرنی ہے۔ اگر کوئی شخص ٹیلیفون پر مکرجیؔ کی حالت دریافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_236.jpg',
#   'text': 'دروازہ کھولنے کے لئے اس نے ہاتھ بڑھایا----- اور رک گیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_237.jpg',
#   'text': 'سے اسی چیز کو بیان کردیاتھا جس کومیں خودمحسوس کرچکاتھا لیکن الفاظ میں ادا نہ کرسکاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_238.jpg',
#   'text': '”میں نے بے اختیار”ہوں“کہہ کر اس کی تائیدکردی۔ بات یہ ہے کہ اس نے بڑی خوبی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_239.jpg',
#   'text': 'کہ--- کہ جنم کانظارہ کروں!“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_240.jpg',
#   'text': 'ایک خوف محسوس ہورہاہے۔ میں نہیں چاہتاکہ دوسرا حملہ مجھ پر ہو----- میں نہیں چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_241.jpg',
#   'text': 'نظرڈالتاہوں اور زندگی میں پہلی مرتبہ مجھے----- جلال جیسے آہنی انسان کو-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_242.jpg',
#   'text': 'نے اپنی آنکھوں کوملااورپھر دیکھا۔اس کے بعدمیں نے ڈاکٹر اشوک کواپنے پاس بلاکر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_243.jpg',
#   'text': 'ادھر بدلنے سے کسی طرح بھی اس ننھے سے شرارے میں کوئی تبدیلی رونمانہ ہوئی۔ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_244.jpg',
#   'text': 'سب سے پہلے مجھے یہ خیال ہواکہ یہ کمرے کی روشنی کاتاثر ہے لیکن روشنی کوادھر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_245.jpg',
#   'text': 'کی مانندروشن نظر آتی تھی!',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_246.jpg',
#   'text': 'لیکن اس کے اندر فاسفورس کی سی کوئی چمک وار شے موجودتھی جوکہ ایک ننھے سے قمقمے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_247.jpg',
#   'text': 'کاایک سفید ذرہ میری نگاہ کی زدمیں آگیا----- یہ محض ایک سادہ سفید ذرہئ خون تھا---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_248.jpg',
#   'text': 'ایک ناقابل یقین چیز موجودہے۔میں نے پلیٹ کوخواہ مخواہ ادھر ادھر حرکت دی تو خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_249.jpg',
#   'text': 'میں شیشے کی چوتھی پلیٹ دیکھ رہاتھا جبکہ مجھے یہ محسوس ہواکہ میری نظر کے سامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_250.jpg',
#   'text': 'ہوا بریک ہٹ جائے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_251.jpg',
#   'text': 'چیز معلوم کرسکوں گابلکہ مقصدصرف یہ تھاکہ میرے دماغ کے ایک دوسرے حصّے پر لگا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_252.jpg',
#   'text': 'کے چند دھبے لیے اور ان کامطالعہ کرنے لگا۔ ایسا کرنے سے مجھے یہ توقع نہ تھی کہ کوئی نئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_253.jpg',
#   'text': 'پر زیادہ آزادی سے سوچنے کی اہلیت پیداہوجاتی ہے۔ لہٰذا میں نے مکرجیؔ کے خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_254.jpg',
#   'text': 'ہے۔ میں نے دیکھاہے کہ خوردبینی کام میں مصروف رہنے کے دوران میرے اندر مسایل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_255.jpg',
#   'text': 'ضروری ہے لیکن اس کی کنجی میرے پاس نہیں اور قفل کاسوراخ بھی مجھے نظر نہیں آرہا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_256.jpg',
#   'text': 'میں کسی بھیانک خواب میں ایک ایسے دروازے کے باہر کھڑاہواہوں جس کوکھولنا اشد',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_257.jpg',
#   'text': 'تھا۔ یہ پورامعاملہ مجھے پریشان کئے ہوئے تھااور مجھے ایسا محسوس ہورہاتھا گویا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_258.jpg',
#   'text': 'کرکچھ ایسا لڑکھڑاگیاتھاکہ دوسروں کے سامنے اس کااعتراف کرنے کودل نہ چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_259.jpg',
#   'text': 'چہرے اورآنکھوں میں ”شیطانی اشتیاق“ اور”شیطانی مسرت“ کی تبدیلیاں دیکھ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_260.jpg',
#   'text': 'موجودتھاکہ جانچ کے مزید نتائج سے بھی کچھ ثابت نہ ہوگا۔ اس کے علاوہ میں مکرجیؔ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_261.jpg',
#   'text': 'واپس آنے کاحکم ملاہو۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_262.jpg',
#   'text': 'معلوم ہوتی تھیں جس کواپنے محبوب وپسندیدہ جہنم سے ایک طویل جلاوطنی کے بعداچانک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_263.jpg',
#   'text': 'یہ مسرت دیوانگی آمیزنہ تھی۔ یہ شیطانی مسرت تھی۔ یہ نگاہیں اس شیطان کی مسرور نگاہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_264.jpg',
#   'text': 'شعور حاصل ہورہاہو--- ان آنکھوں میں ایک ناپاک مسرت کوندرہی تھی---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_265.jpg',
#   'text': 'تین آدمیوں کی قریبی موجودگی کااحساس کر رہاہو--- جیسے اس کوپورے کمرے کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_266.jpg',
#   'text': 'اچانک مکرجیؔ کی آنکھوں میں نگاہوں کے مرکوز ہونے کی کیفیت پیداہوئی جیسے وہ ہم',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_267.jpg',
#   'text': '--- ٹھیک اسی طرح جیسے میں نے کیاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_268.jpg',
#   'text': 'نے دیکھاکہ کمارؔ نے رخ بدل کر اپنے پیچھے کی طرف نظر ڈالی اور کمرے میں ادھر ادھر دیکھا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_269.jpg',
#   'text': 'آلوددلکشی و محویت کے ساتھ مکرجیؔ کے چہرے پر جمی ہوئی تھیں --- اسی وقت میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_270.jpg',
#   'text': 'ڈاکٹرکمارؔاور نرس شیلاؔ مریض کی چارپائی کی دوسری طرف تھے۔ان کی آنکھیں خوف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_271.jpg',
#   'text': 'دروازے پر جماہواتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_272.jpg',
#   'text': 'بیٹھاہواسامنے کلیسا کی چھت کی فصیلوں کوتک رہاتھا۔دوسراآدمی مستعدی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_273.jpg',
#   'text': 'لیکن وہاں کوئی چیز موجودنہ تھی۔جلالؔ کاایک آدمی کھڑکی کے گوشے کی تاریکی میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_274.jpg',
#   'text': 'سی ہیبت ناک شے میری طرف دبے پاؤں رینگتی آرہی ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_275.jpg',
#   'text': 'مڑ کر اپنے شانے کے اوپر سے یاک نظر ڈالی یہ معلوم کرنے کے لیے کہ پشت کیطرف سے کون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_276.jpg',
#   'text': 'کہاجاسکتاہے اور یہ کیفیت اس حدتک ”شیطانی“ محسوس ہوتی تھی کہ بے اختیار میں نے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_277.jpg',
#   'text': 'نظر آتاتھالیکن اب اس کی نظروں میں ایک ایسی کیفیت تھی جس کوایک ”شیطانی اشتیاق“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_278.jpg',
#   'text': 'بھی وہ میرے جسم کے اس پار اور خوداپنے جسم کے اندر کی طرف بہ یک وقت دیکھتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_279.jpg',
#   'text': 'لگتا۔ مکرمیؔ کے چہرے کاعالم تبدیل ہوگیاتھا۔دہشت و نفرت غائب ہوچکی تھی۔ اب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_280.jpg',
#   'text': 'یاشاید اس کی وجہ یہ ہوکہ اس کومجھ پر حملہ کرنے کاموقع حاصل نہ تھا۔ میں مکرجی کیطرف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_281.jpg',
# ...
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0506.png',
#   'text': 'مہا بھارت دنیا کی طویل ترین نظم سمجھی جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0507.png',
#   'text': 'چھٹی صدی ق م سے تیسری صدی ق م تک مہا جن پد کے عروج کا دور ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0508.png',
#   'text': 'قدیم بودھ گرنتھوں انگُتّر نکائے وغیرہ میں ان سولہ ریاستوں کا کثرت سے تذکرہ ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0509.png',
#   'text': 'وادی سندھ کی تہذیب کے خاتمہ کے بعد اسی عہد میں پہلی بار ہندوستان میں بڑے بڑے شہر بسائے گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0510.png',
#   'text': 'وجی مہا جن پد کے تخت اقتدار پر لچھوی سب سے معروف قبیلہ گذرا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0511.png',
#   'text': 'سیاہ قلعی دار شمالی برتنوں کی ثقافت کا زمانہ بھی یہی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0512.png',
#   'text': '500 یا 400 ق م یعنی گوتم بدھ کے عہد تک مذکورہ سولہ مہا جن پد چار بڑی ریاستوں میں ضم ہو گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0513.png',
#   'text': 'یہ چار ریاستیں تھیں: وَتس، اَوَنتی، کوشل اور مگدھ',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0514.png',
#   'text': 'گوتم بدھ کے حالات زندگی انھی چار ریاستوں کے گرد گھومتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0515.png',
#   'text': 'مگدھ کا دور اول',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0516.png',
#   'text': 'ابتدا میں راجگیر پایۂ تخت رہا لیکن بعد میں پاٹلی پتر (موجودہ پٹنہ) منتقل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0517.png',
#   'text': 'جین اور بودھ گرنتھوں میں مگدھ کی اس قدیم سلطنت کا بارہا ذکر آیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0518.png',
#   'text': 'نیز راماین، مہا بھارت اور پرانوں میں بھی اس کا مذکور ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0519.png',
#   'text': 'جین مت اور بدھ مت کے فروغ میں سلطنت مگدھ کا خاصا اہم کردار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0520.png',
#   'text': 'مگدھ کے دائرۂ اقتدار میں بعض جمہوری برادریاں مثلاً راج کمار برادری وغیرہ بھی شامل تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0521.png',
#   'text': 'سلطنت کا نظم و انصرام عاملہ، عدلیہ اور فوج کے شعبوں میں منقسم تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0522.png',
#   'text': 'انگ کا علاقہ اب مشرقی بہار اور مغربی بنگال میں پڑتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0523.png',
#   'text': 'یہی دور ہے جس میں گوتم بدھ نے اپنی زندگی کا بیشتر حصہ مگدھ سلطنت میں گذارا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0524.png',
#   'text': 'ہریک خانوادہ کے بعد شی شو ناگ خانوادہ تخت سلطنت پر متمکن ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0525.png',
#   'text': '345 ق م میں آخری شی شو ناگ بادشاہ کالا شوک مہا پدم نند کے ہاتھوں مارا گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0526.png',
#   'text': 'مہا پدم نند نو نندوں میں سے پہلا تھا اور اس کے بعد اسی کے آٹھ بیٹے نند کہلائے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0527.png',
#   'text': 'نند سلطنت اور سکندر کی مہم',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0528.png',
#   'text': 'نند سلطنت کی سرحدیں بنگال سے پنجاب تک اور جنوب میں وندھیاچل تک پھیلی ہوئی تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0529.png',
#   'text': 'یہ نند سلطنت کے عروج کا زمانہ تھا اور اس کی ثروت اور دولت مندی کے چرچے ہر طرف تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0530.png',
#   'text': 'چنانچہ سکندر کو پنجاب اور سندھ کے میدانوں سے واپس لوٹنا پڑا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0531.png',
#   'text': 'بر صغير سے سکندر اعظم کے جانے کے بعد نند سلطنت کی بساط الٹ گئی اور موريا دور کا آغاز ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0532.png',
#   'text': 'برصغیر کی تاریخ میں پہلی بار ایسی عظیم الشان اور مستحکم سلطنت قائم ہوئی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0533.png',
#   'text': 'اس جنگ میں فتح پانے کے بعد دریائے سندھ کا مغربی خطہ بھی اس کی حکومت میں شامل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0534.png',
#   'text': 'چندر گپت کے بعد اس کا بیٹا بندو سار 297 ق م کے آس پاس تخت سلطنت پر بیٹھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0535.png',
#   'text': 'البتہ کلنگ کا علاقہ (موجودہ اوڈیشا) اس کے دائرۂ اقتدار سے باہر رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0536.png',
#   'text': 'شاید اس کی وجہ یہ تھی کہ جنوب سے کلنگ کے تجارتی روابط مضبوط تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0537.png',
#   'text': 'بندو سار کے بعد سلطنت کی باگ ڈور اشوک کے ہاتھوں میں آئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0538.png',
#   'text': 'اشوک نے 232 ق م میں اپنی وفات تک تقریباً 37 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0539.png',
#   'text': 'اس منظر نے اشوک کے وجود کو اندر سے ہلا ڈالا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0540.png',
#   'text': 'بالآخر اس نے زور و تشدد کی راہ ترک کر دی اور بدھ مت قبول کرنے کا اعلان کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0541.png',
#   'text': 'اشوک کے عہد حکومت میں بدھ مت سارے ہندوستان میں پھیل چکا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0542.png',
#   'text': 'اس دوران میں اور اس کے بعد بھی يونانيوں اور کشانوں کا اثر برقرار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0543.png',
#   'text': 'اس کا دارالخلافہ قنوج تھا جس کے کھنڈر آج بھی شمالی بھارت میں پائےجاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0544.png',
#   'text': 'جنگ کلنگ کے بعد تقریباً نصف صدی تک سلطنت میں ہر طرف امن و امان کا راج رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0545.png',
#   'text': 'یہ عوام کی فلاح و بہبود، سماجی ہم آہنگی، مذہبی تبدیلی اور علوم و فنون کی ترقی کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0546.png',
#   'text': 'ارتھ شاستر اور اشوک کے کتبے موریا دور کے احوال و وقائع کے اولین مآخذ ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0547.png',
#   'text': 'اثریات کی رو سے یہ سیاہ قلعی دار شمالی برتنوں کی تہذیب کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0548.png',
#   'text': 'موریا سلطنت کی بنیادیں اپنے عہد کی ترقی یافتہ معیشت اور ہنر مند سماج پر استوار تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0549.png',
#   'text': 'یہ فولاد چین اور عرب تک جاتا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0550.png',
#   'text': 'تیسری صدی ق م سے چوتھی صدی عیسوی تک کا زمانہ سنگم عہد کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0551.png',
#   'text': 'یہ تینوں شاہی خانوادے تمل اکام کے تاجوران ثلاثہ کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0552.png',
#   'text': 'ان کے مسائل کا بچشم خود مشاہدہ کیا اور ان کے درد و کرب کو محسوس کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0553.png',
#   'text': 'ان کا دھرم مختلف اور پیشے جدا جدا تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0554.png',
#   'text': 'ان میں کاشت کار بھی تھے، دست کار بھی تھے، دکان دار، تاجر اور پروہت بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0555.png',
#   'text': 'ان میں عورتیں بھی تھیں اور شاہزادے بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0556.png',
#   'text': 'تقریباً 300 ق م سے 200 عیسوی تک پَتو پاٹّو، ایٹو توگئی اور پَتی نَینکل کنکّو لکھے جاتے رہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0557.png',
#   'text': 'پَتو پاٹّو اوسط لمبائی کی دس نظموں کا مجموعہ ہے اور سنگم ادب کا حصہ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0558.png',
#   'text': 'نیز تمل زبان کے گرامر کی قدیم ترین کتاب تولکا پیئم بھی اسی دوران میں تصنیف کی گئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0559.png',
#   'text': 'سیلاپتی کارم کو ایلانگو ادیگل نے لکھا جو ایک غیر مذہبی رزمیہ ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0560.png',
#   'text': 'اس ظلم پر کن نکی کا جذبۂ انتقام بیدار ہوتا ہے اور سلطنت سے بدلہ لینے کی ٹھان لیتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0561.png',
#   'text': 'سیتَلئی ساتّنار نے منی میکالئی تصنیف کی جو دراصل سیلاپتی کارم ہی کا تسلسل ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0562.png',
#   'text': 'اس میں کوولن کی بیٹی مادھوی کی کہانی نظم کی گئی ہے جو بودھ بھکشونی بن جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0563.png',
#   'text': 'کلاسیکی اور اوائل قرون وسطی کے ادوار (200 ق م تا 1200ء)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0564.png',
#   'text': 'تیسری صدی عیسوی سے چھٹی صدی عیسوی کا درمیانی عرصہ ہندوستان کا کلاسیکی دور کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0565.png',
#   'text': 'یہ عہد موریہ سلطنت کے زوال سے شروع ہو کر گپت سلطنت کے زوال تک جاری رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0566.png',
#   'text': 'اس دور کو مزید مختلف ذیلی ادوار میں تقسیم کیا گیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0567.png',
#   'text': 'یہی وہ دور ہے جس میں شونگ اور ساتواہن سلطنتوں کو عروج حاصل ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0568.png',
#   'text': 'چوتھی صدی عیسوی سے چھٹی صدی عیسوی تک گپت سلطنت قائم رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0569.png',
#   'text': 'گپت سلطنت کا یہ دور ہندومت کی تاریخ کا عہد زریں سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0570.png',
#   'text': 'ابتدائی کلاسیکی دور (تقریباً 200 ق م تا تقریباً 320 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0571.png',
#   'text': 'شونگ مگدھ سے اٹھے اور برصغیر ہند کے مشرقی اور وسطی علاقوں تک اپنی سلطنت قائم کر لی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0572.png',
#   'text': 'ان کا عہد سلطنت تقریباً 187 ق م سے 78 ق م تک رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0573.png',
#   'text': 'پشیہ متر شونگ نے 36 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0574.png',
#   'text': 'بعد ازاں اس کا بیٹا اگنی متر اس کا جانشین ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0575.png',
#   'text': 'کل دس شونگ بادشاہ گذرے ہیں لیکن اگنی متر کی وفات کے بعد سلطنت کا شیرازہ تیزی سے بکھرنے لگا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0576.png',
#   'text': 'شونگ سلطنت اپنے دور حکمرانی میں بیرونی اور اندرونی دونوں طاقتوں سے نبرد آزما رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0577.png',
#   'text': 'اس نے سلطنت کو پھلنے پھولنے اور اقتدار حاصل کرنے میں خاصی مدد کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0578.png',
#   'text': 'ساتواہن سلاطین اصلاً دکنی تھے، اسی بنا پر وہ "آندھرا سلاطین" بھی کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0579.png',
#   'text': 'ساتواہن سلاطین ہندومت اور بدھ مت کے بڑے سرپرست اور مربی گذرے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0580.png',
#   'text': 'ساتواہن ان اولین ہندوستانی ریاستوں میں سے ہے جنھوں نے اپنے سکوں پر سلاطین کی شبیہ بنائی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0581.png',
#   'text': 'بالخصوص مغربی شترپوں سے ان کی کشمکش طویل عرصہ تک جاری رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0582.png',
#   'text': 'ہندوستان کی تجارت اور سیاحت',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0583.png',
#   'text': 'کیرالا کی مسالوں کی تجارت قدیم دنیا کے تاجروں کو کھینچ کھینچ کر ہندوستان لا رہی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0584.png',
#   'text': 'پہلی صدی عیسوی کے آس پاس توما رسول بحری راستے سے ہندوستان پہنچا اور موزریز ساحل پر اترا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0585.png',
#   'text': 'یہاں پہنچ کر توما نے سات گرجا گھروں کی بنیاد رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0586.png',
#   'text': 'ہندوستان کی سیاحت کرنے والے چینیوں میں فاہیان، یی جنگ، سونگ یون اور ہیون سانگ قابل ذکر ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0587.png',
#   'text': 'روم و یونان نے شاہراہ بخور اور ہند رومی شاہراہوں کے ذریعہ اپنی تجارت جاری رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0588.png',
#   'text': 'کُجُل کڈفِسیس کشان سلطنت کا پہلا فرماں روا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0589.png',
#   'text': 'شہنشاہ کنشک بدھ مت کا بڑا مربی تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0590.png',
#   'text': 'اس کے باوصف بدھ مت کے استحکام میں کشانیوں کے غیر معمولی کردار کو فراموش نہیں جا سکتا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0591.png',
#   'text': 'مورخ ونسنٹ اسمتھ کنشک کے متعلق لکھتا ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0592.png',
#   'text': 'اس عہد میں گندھارا اور متھرا کے فنون بھی بہار دکھانے لگے تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0593.png',
#   'text': 'ان میں نئے شگوفے کھلے، نئے غنچے چٹخے، نئے رجحان سامنے آئے اور یہ فنون اپنی جوبن پر آگئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0594.png',
#   'text': 'ہیو جارج رالنسن رقم طراز ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0595.png',
#   'text': 'تیسری صدی عیسوی تک پہنچتے پہنچتے کشانوں کی سلطنت بکھرنے لگی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0596.png',
#   'text': 'ان کا آخری قابل ذکر بادشاہ واسو دیو اول تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0597.png',
#   'text': 'کلاسیکی دور (320 عیسوی - 650 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0598.png',
#   'text': 'انھی وجوہ سے گپت عہد کو ہندوستانی ثقافت کی تاریخ کا اہم ترین موڑ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0599.png',
#   'text': 'اس عہد میں علوم و فنون اور سیاسی انتظام و انصرام نے نئی چوٹیاں سر کیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0600.png',
#   'text': 'یہی وجہ ہے کہ تاریخ کے چہرے پر اس عہد کو گپت سلطنت کا بوسۂ امن قرار دیا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  ...]

# %% [markdown]
# ## 7. Source 5 — Signboards (Synthetic Signboard Images)
#
# Same rendering (bold colored background, centered, framed border). Your original 12
# hand-written signboard phrases are **kept and merged in** alongside ~150 additional
# short real phrases from the Wikipedia pool.

# %%
SIGNBOARD_PHRASES_ORIGINAL = [
    "خوش آمدید",
    "یہاں پارکنگ منع ہے",
    "براہ کرم قطار میں کھڑے ہوں",
    "جنرل اسٹور",
    "میڈیکل سٹور",
    "برائے فروخت",
    "داخلہ بند ہے",
    "باہر نکلنے کا راستہ",
    "ٹی سٹال",
    "الحمد للہ بیکری",
    "سگریٹ نوشی منع ہے",
    "احتیاط: تعمیراتی کام جاری ہے",
]

SIGNBOARD_PHRASES_FROM_WIKI = [s for s in URDU_SENTENCE_POOL if 8 <= len(s) <= 30][:TARGET_SIGNBOARDS]

SIGNBOARD_PHRASES = SIGNBOARD_PHRASES_ORIGINAL + SIGNBOARD_PHRASES_FROM_WIKI
print(f"Using {len(SIGNBOARD_PHRASES)} phrases for signboard images "
      f"({len(SIGNBOARD_PHRASES_ORIGINAL)} original + {len(SIGNBOARD_PHRASES_FROM_WIKI)} from Wikipedia).")


def render_signboard_image(text, size=(600, 250)):
    """
    Render a short Urdu phrase as a signboard-style image:
    bold color background, centered text, framed border.
    Returns the PIL Image object.
    """
    bg_color = random.choice([(11, 83, 148), (56, 118, 29), (153, 0, 0), (180, 95, 6), (28, 28, 28)])
    text_color = random.choice([(255, 255, 255), (255, 255, 0), (244, 244, 244)])
    font_obj = font_large

    reshaped = arabic_reshaper.reshape(text)
    bidi_text = get_display(reshaped)

    img = Image.new("RGB", size, color=bg_color)
    draw = ImageDraw.Draw(img)

    bbox = draw.textbbox((0, 0), bidi_text, font=font_obj)
    w, h = bbox[2] - bbox[0], bbox[3] - bbox[1]
    x = (size[0] - w) // 2 - bbox[0]
    y = (size[1] - h) // 2 - bbox[1]
    draw.text((x, y), bidi_text, fill=text_color, font=font_obj)

    # Frame border, like a real signboard
    border_color = random.choice([(255, 255, 255), (244, 208, 63)])
    draw.rectangle([5, 5, size[0] - 5, size[1] - 5], outline=border_color, width=6)

    if random.random() < 0.4:
        img = img.filter(ImageFilter.GaussianBlur(radius=0.3))

    return img
# Out:
# Using 162 phrases for signboard images (12 original + 150 from Wikipedia).

# %%
def generate_signboard_images():
    """
    Render all SIGNBOARD_PHRASES into signboard-style images and
    save them to data/raw/signboards/. Returns a list of label row dicts.
    """
    rows = []
    count = 0

    for i, text in enumerate(SIGNBOARD_PHRASES):
        try:
            img = render_signboard_image(text)
        except Exception:
            continue
        save_path = f"data/raw/signboards/sign_{i+1:03d}.png"
        img.save(save_path)
        rows.append({
            'image': save_path, 'text': text,
            'source': 'signboards_synthetic', 'split': ''
        })
        count += 1

    print(f"Generated {count} signboard images -> data/raw/signboards/")
    return rows


signboard_rows = generate_signboard_images()
append_to_labels_csv(signboard_rows)
# Out:
# Generated 162 signboard images -> data/raw/signboards/
#   labels.csv: 3128 total entries (+162 new).
# [{'image': 'data/raw/other/utrset_001.jpg',
#   'text': 'اندراج و تحریر شرعاً صرف مستحب اور پسندیدہ ہے وہ واجب نہیں کہ کسی شرعی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_002.jpg',
#   'text': 'اور ہندوستان کی مسلم ریاستوں میں اس پر کم و بیش عمل درآمد بھی ہے، جہاں تک جبری',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_003.jpg',
#   'text': 'بلکہ اس کے نزدیک وہ پسندیدہ اور مستحسن بھی ہے، عملی پہلوکے لحاظ سے اسلامی سلطنتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_004.jpg',
#   'text': 'جہاں تک پہلی صورت کاتعلق ہے، شریعت اسلامیہ کی رو سے اس پر اعتراض جائز نہیں،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_005.jpg',
#   'text': 'ہے، اس لیے اس کولازمی طورپر جاری کردیاجائے، اس کانام جبر ی اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_006.jpg',
#   'text': 'مقدمات سے نجات مل سکتی ہے، نکاح کے ثبوت اورک دین مہر کے تعین میں سہولت ہوتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_007.jpg',
#   'text': 'دوسرا پہلو یہ ہے کہ چونکہ اس اندراج میں بہت سی مصلحتیں ہیں، اس سے بڑی حدتک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_008.jpg',
#   'text': 'جس قدر لوگ اس پر عمل کریں اتنا ہی فائدہ ہے، اس کانام اختیاری اندراج ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_009.jpg',
#   'text': 'ایک تویہ کہ اس قسم کااندراج مفید ونافع ہے، اوراس کا رواج دینا مناسب ہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_010.jpg',
#   'text': 'کے لیے غیر ضروری تسلیم کرتے ہوئے اس حیثیت سے یہ مسئلہ زیر بحث آسکتاہے،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_011.jpg',
#   'text': 'اسلامی حکم کے خلاف ہوگا، ہاں نکاح وطلاق کے اندراج کوصحت نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_012.jpg',
#   'text': 'جو نکاح وطلاق کی اس حیثیت پر اثر انداز ہو، قبول نہیں کیاجاسکتا، کیونکہ وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_013.jpg',
#   'text': 'نہیں ہوئی، ناجائز اور قابل انکار نہیں قرار دی جاسکتی، اس لیے کوئی ایسا قانون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_014.jpg',
#   'text': 'اورکوئی طلاق صرف اس وجہ سے کہ وہ لکھی نہیں گئی یا سرکاری رجسٹر میں درج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_015.jpg',
#   'text': 'نکاح صرف اس وجہ سے وہ لکھا نہیں گیا یا سرکاری رجسٹرمیں درج نہیں ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_016.jpg',
#   'text': 'زبانی الفاظ طلاق (بشرائط مقررہ ومعتبرہ) و قوع طلاق کے لیے کافی ہیں، کوئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_017.jpg',
#   'text': 'نہیں، مذہبی طورپر زبانی ایجاب و قبول (بشرائط مقررہ و معتبرہ) نکاح کے لیے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_018.jpg',
#   'text': 'احکام کی بناء پر نکاح وطلاق کی صحت کے لیے کتاب اور رجسٹر میں اندراج کی ضرورت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_019.jpg',
#   'text': 'اس وقت مسئلہ یہ تھا کہ نکاح وطلاق کا اندراج سرکاری طورپر ایک رجسٹرمیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_020.jpg',
#   'text': 'اس لیے اس سے ان کے خیالات کااندازہ کیاجاسکتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_021.jpg',
#   'text': 'میں قابل قبول نہیں سمجھی گئی توپھر مولاناکفایت اللہ اور مولاناقطب الدین کی تائید سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_022.jpg',
#   'text': 'فرنگی محلی وغیرہ تھے، اس کمیٹی نے جو رپورٹ تیار کی وہ یوپی کی مجلس قانون ساز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_023.jpg',
#   'text': 'کے ساتھ مولاناکفایت اللہ دہلوی،مولوی نعیم الدین مرادآبادی اور مولانا قطب الدین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_024.jpg',
#   'text': 'الہ آباد ہائی کورٹ)تھے، اس کے ممبروں میں ڈاکٹر شفاعت احمدخاں کے علاوہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_025.jpg',
#   'text': 'کو رجسٹرڈ کرنے کے لیے ایک قانون بناناتھا، اس کمیٹی کے صدر سرشاہ سلیمان (جج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_026.jpg',
#   'text': 'تھا، اس کامقصد مسلمانوں کونکاح وطلاق کے معاملات پر غور اور نکاح وطلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_027.jpg',
#   'text': 'الہ آباد یونیورسٹی) کی تحریک سے ایک کمیٹی بنائی گئی تھی، جس کانام ”مسلم میرج سب کمیٹی“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_028.jpg',
#   'text': 'میں یوپی کی مجلس قانون ساز میں ڈاکٹرشفاعت احمدخاں (پروفیسر تاریخ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_029.jpg',
#   'text': 'میں بڑی ہمدردی سے دلچسپی لی، جیسا کہ حسبِ ذیل تفصیلات سے اندازہ ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_030.jpg',
#   'text': 'انھوں نے قرآن مجید، حدیث اور فقہ کے اپنے گہرے مطالعہ سے ان کو حل کرنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_031.jpg',
#   'text': 'اور وراثت کے مسائل میں بہت سے سوالات پیداہوتے رہے اس سلسلہ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_032.jpg',
#   'text': 'تو متعین کردیا ہے مگر جیسا کہ پہلے بھی کہا گیاہے، ہندوستان میں ان کے نکاح،طلاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_033.jpg',
#   'text': 'غیر مسلم حاکم کافیصلہ جائز نہیں ہوسکتاہے اور نہ ایسے مسلمان حاکموں سے اس کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_034.jpg',
#   'text': 'اس مشکل اس لیے حل نہیں کرسکتی ہیں کہ ان مسائل میں شرع اسلامی کے رو سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_035.jpg',
#   'text': 'جائیں جو آنریری منصف کوحاصل ہیں، تاکہ وہ اپنے اختیارات سے ایسی مشکلوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_036.jpg',
#   'text': 'مشکل یک آسان صورت یہ ہے کہ قاضیوں کوان معاملات کے لیے وہ اختیارات دیئے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_037.jpg',
#   'text': 'رجسٹری آفس بھی نئی ذمہ داریوں سے محفوظ رہیں گے(۲) اگر بالفعل یہ ممکن نہ ہو تواس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_038.jpg',
#   'text': 'ساری مشکلات دور ہوجائیں گی، عدالتیں بھی بہت سی دقتوں سے محفوظ ہوجائیں گی،',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_039.jpg',
#   'text': 'قائم کردیاجائے جس کوان معاملات میں فیصلہ کرنے کاپورااختیار ہو، اس طرح تو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_040.jpg',
#   'text': 'نظام میں لاکر پورے صوبہ میں مسلمانوں کے نکاح وطلاق کے لیے ایک علیحدہ محکمہئ قضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_041.jpg',
#   'text': 'کیں کہ (۱) مسلمانوں کے ان مسائل کے لیے قاضی مقرر کیے جائیں اوران کوایک مرکزی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_042.jpg',
#   'text': 'دونوں کے لیے مصیبت کاباعث ہوتے ہیں، مسلمان لڑکیاں مظلوم بنی رہتی ہیں، اس مصیبت کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_043.jpg',
#   'text': 'وجہ سے مقدمے دائر ہوجاتے ہیں، ایسی صورت میں یہ مقدمات، خاندانوں اور عدالتوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_044.jpg',
#   'text': 'مختلف صورتوں،خلع، خیار اور تفریق کے مسائل، ولی ہونے کے باہمی فرق و مراتب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_045.jpg',
#   'text': 'ہے کہ ترک وراثت، رضاعت، رشتوں کے حلال و حرام ہونے، عدت اطلاق کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_046.jpg',
#   'text': 'اس لحاظ سے بے انصافی ہوتی ہے کہ ایسے لوگ بھی ان کا نکاح پڑھا دیتے ہیں جو ممکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_047.jpg',
#   'text': 'اور تحصیلوں میں قاضیوں اور نائب قاضیوں کاتقرر کرے تو تمام مشکلات کا حل ہوجاتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_048.jpg',
#   'text': 'اور یہ قاضی القضاۃ مسلمانوں کی رضامندی اور گورنمنٹ یک منظوری سے اضلاع',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_049.jpg',
#   'text': 'اگر صوبہ کے مسلمان ایک قاضی القضاۃ کا انتخاب کریں اور گورنمنٹ اس ک منظورکرے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_050.jpg',
#   'text': 'قوت حاصل ہونے کے لیے ضروری ہے کہ حکومت اس انتخاب کوقبول کرے، اس بناء پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_051.jpg',
#   'text': 'اپنی رضامندی سے ایک قاضی کاانتخاب کریں اوراس قاضی کوتنقیدکی طاقت اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_052.jpg',
#   'text': 'منظور کرنا تقریباً ناممکن ہے، اس بناء پر اگر کوئی صورت ممکن ہے تووہ یہ ہے کہ مسلمان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_053.jpg',
#   'text': 'مسلم حکومت کیلیے خاص طورسے مسلمانوں کی خاطر ایک مستقل مسلمان والی کے تصور کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_054.jpg',
#   'text': 'مختلف مذہبوں اور قوموں کی ایسی مخلوط آبادی ہے، جس کا لحاظ کرکے یہاں کی غیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_055.jpg',
#   'text': 'قضا کے لیے تینوں مذکورہئ بالاشکلوں میں ایک شکل اختیارکرنی پڑے گی، ہندوستان',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_056.jpg',
#   'text': 'میں مسلمانوں کے ان شرعی معاملات کے نظم،نسق، ترتیب، ان احکام کے احیاء اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_057.jpg',
#   'text': 'مندی سے قاضی کاانتخاب کریں، یہ تینوں شکلیں فقہ کی کتابوں میں مذکور ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_058.jpg',
#   'text': 'کردے، یہ مسلمان والی پھر قاضی مقرر کرے (۳) یہ بھی ممکن نہ ہو تو مسلمان اپنی باہمی رضا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_059.jpg',
#   'text': 'ہوسکے توغیر مسلم حکومت سے مطالبہ کیاجائے کہ وہی ان پر ایک مسلمان والی مقرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_060.jpg',
#   'text': 'انتخاب کریں اور وہ قاضیوں کا تقرر کرے جو نکاح وطلاق کے مسئلے کو طے کریں (۲)یہ نہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_061.jpg',
#   'text': 'ہیں، (۱) اگر ممکن ہو تومسلمان خود اپنی طرف سے متفق اور متحد ہوکر ایک.... والی کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_062.jpg',
#   'text': 'ہو، ایسے معاملات کے نظم ونسق و ترتیب واجماء کے لیے حسب ذیل تین شکلیں تجویز کی جاسکتی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_063.jpg',
#   'text': 'قانون کوجواصل میں غیر واجب ہو، واجب قرار دے، لیکن جہاں غیر مسلم حکومت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_064.jpg',
#   'text': 'صرف اما مسلمین کو پہونچتا ہے کہ وہ مسلمانوں کی مصلحتوں کی بناء پر اپنے زمانہ میں کسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_065.jpg',
#   'text': 'اختیار کے بغیر کسی تبرع اور استجاب کو واجب میں نہیں بدلا جاسکتا، یہ شرعی اختیار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_066.jpg',
#   'text': 'مہدی صاحب(بھوپال)(۳) حضرت شریف فکری بھپوال،(۴) مولینافضل الرحمن صاحب باقیؔ(کلکتہ)(۵) حضرت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_067.jpg',
#   'text': 'فرمائی ہے انکی خدمت میں ہدیہئ تشکر وامتنان پیش ہے۔ امیدکہ دیگر معاونین بھی اولین فرصت میں توجہ فرمائینگے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_068.jpg',
#   'text': ':۔  نیرنگ کی پسندیدہ خدمات کے اعتراف میں جن حضرات نے توجہ والتفات فرماکر مخصوص معاونت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_069.jpg',
#   'text': 'شکریہئ التفات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_070.jpg',
#   'text': 'رہگیااورہمیشہ کے لئے ایک سکوت، سکوتِ مرگ عاری ہوگیا۔اورحسن صباخت ور آغوش،آغوشِ فنامیں روپوش یہ تھا”ڈاخ کاخواب“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_071.jpg',
#   'text': 'سامنے یہ کچھ ہوااوراس نے دیکہا۔ وہ آگے بڑہناچاہتاتھاکہ دوخواصوں نے بڑہ کر ایک چادر بیاٹرس پر ڈالدی۔ وہ دیکہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_072.jpg',
#   'text': 'پر بوسہ یدتاہے جن پر آج سے پہلے ڈانٹے کی جرائت نہوئی اوراسکے لب اُنہیں کبہی بھی”زحمت وصل نہ دے سکے۔ مگر آہ کہ آج اوراسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_073.jpg',
#   'text': 'بڑہتاہے۔ کہ”عشق“ کی ستم ظریفی میں اضافہ ہوتاہے اور”دیوتا“اسکی محبوبہ کے قوس گوں لبوں پر اُن مرمرین گلاب کی پتیوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_074.jpg',
#   'text': 'اور بے پناہ تیر اسکے۔ دل میں پیوست کردیتاہے دانٹے اس غیر متوقع،دلخراش اورناقابل دیدنظارے کی تاب نہ لاکر آگے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_075.jpg',
#   'text': 'موت کی دستبروسے مجبور ہوکر اس سے جداہوتی ہے۔ اورحسین غالب بے جان رہی ہے، ادھر عشق دیوتااپنا تیرزہریلا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_076.jpg',
#   'text': 'اُس نے دیکہاکہ:۔ وہ ایک تالاردلکشامیں اپنی حسین ومحبوب بیوی بیاٹرس کے ساتھ بیٹھاہے۔ ’بیاٹرس اسی وقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_077.jpg',
#   'text': '”زندہ“رہ سکا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_078.jpg',
#   'text': 'کے ذریعہ کی ہے جو تقریباً انیس سال کی طویل کاوش کانتیجہ ہے۔ اورغالباً داسی، کوشش وعمل کی مصروفیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_079.jpg',
#   'text': '”محبوبہ“ کی جدائی کے کچھ عرصہ بعد”روزیٹی“ نے ایک خواب دیکہا:۔ جس کی تشریح اسکی جنبشِ قلم نے اس تصویر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_080.jpg',
#   'text': 'جداکردیا۔اور وہ حیران وپریشان اس ”بے نیازی“ کاناقابلِ فہم مظاہرہ کرتاتنہاوبیکس رہگیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_081.jpg',
#   'text': 'کچھ ہی عرصہ بعدآبادگھربرباد ہوگیا۔یعنی”روزیٹی“ کی محبوب وجمیل بیوی“ کو”پنجہئ اجل“ نے ہمیشہ کیلئے اُس سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_082.jpg',
#   'text': 'حسین نقش ونگار کونمایاں کیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_083.jpg',
#   'text': 'دونوں ایک دوسرے کے والہ و شیداہوگئے۔ روز یٹنی نے اُسکے ’اعتراف جمال‘ کی سندمیں اکثر تصاویرمین اسکے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_084.jpg',
#   'text': 'یہاں تک وسعت اختیار کی کہ اس کو حسینہ سے ایک ”گہراقلبی تعلق“ہوگیا۔ محبت کے پینگ بڑہے اورایسے بڑہے کہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_085.jpg',
#   'text': 'سے ایک دوست مصوّر کے ذریعہ ایک خوش جمال حسینہ سے روزبیٹی کی ملاقات ہوگئی۔رسمی تعارف حدودنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_086.jpg',
#   'text': 'کی تصویریں بولتی تصویریں کہلائی جاتی ہیں اور اپنے عہدکاکامیاب ومقبول مصوّر ہوا۔حسن اتفاق',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_087.jpg',
#   'text': 'ملّاصاحب کی شادی کے حالات کی دلکش تفصیلات جوخودجناب موصوف نے انداز مخصوص میں تحریر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_088.jpg',
#   'text': 'شادی۔  طابع وناشر۔ عالمگیر بکڈپولاہور۔قیمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_089.jpg',
#   'text': 'شایقین ادب کیلئے اس کتاب کامطالعہ دلچسپی کاباعث ہوگا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_090.jpg',
#   'text': 'کتابت طباعت نفیس ہے۔ملّاصاحب کے تعارف کی کوشش کرنااُنکی توہین کے مرادف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_091.jpg',
#   'text': 'ضیاء الملک ملّا رموزیؔ کے اُن مزاحیہ مضامین کامجموعہ ہے جوموقت الشیوع رسائل میں شائع ہوچکے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_092.jpg',
#   'text': 'ضخامت ص۲٤٠ ۔قیمت عصر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_093.jpg',
#   'text': 'طابع وناشر:۔ عالمگیب بکڈپو۔لاہورسائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_094.jpg',
#   'text': 'صبح لطافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_095.jpg',
#   'text': 'اہل ذوق کلام برق سے محظوظ ہوں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_096.jpg',
#   'text': 'بعدازاں مصنف کافارسی دیباچہ اورغزلیات کاانتخاب ہے کاغذکتابت طباعت عمدہ ہے۔ سرورق آرت پیپر کاہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_097.jpg',
#   'text': 'قیمت ۲ ۱/-ضخامت دوسو صفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_098.jpg',
#   'text': 'ناشر:۔ارمغاں بکڈپو،دہلی۔ سائز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_099.jpg',
#   'text': 'کتابیں۔ شرارؔ برقی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_100.jpg',
#   'text': 'یہ رسالہ مستقل خریداروں کومفت ملتاہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_101.jpg',
#   'text': 'خداکرے مولاناواحدی صاحب کی مساعی حسنہ کامیاب ترین ثابت ہوں:',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_102.jpg',
#   'text': 'مضامین نثرونظم جوڈیڑھ سوصفحات پر مشتمل ہیں اپنی مخصوص شانِ متانت کے ساتھ شایع ہواہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_103.jpg',
#   'text': 'حاصل کیجاتی ہے۔ امسال بھی حسب سابق سیرتِ نبی اکرم صلعم کے متعددعنواناتِ مفیدہ کے ماتحت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_104.jpg',
#   'text': 'ضامن ہیں۔”رسول نمبر“ کی ابتدانظام المشایخ سے ہوئی اوراس اجتہادی عمل صالحہ میں ہر سال کامیابی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_105.jpg',
#   'text': 'متین روش اورمستقل سلامت ردی قابل ذکر ہے جوانداز وطرز ابتداسے اختیارکیاہے بدستوراسی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_106.jpg',
#   'text': 'دہلی کے قدیم ترین رسالہ نظام المشایخ، کی اہم ترین خصوصیات میں اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_107.jpg',
#   'text': 'نظام المشایخ”رسول نمبر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_108.jpg',
#   'text': 'میں ہدیہ تبریک پیش کرتے ہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_109.jpg',
#   'text': 'ملک کے ہرپڑہے لکہے مردعورت کواس رسالہ کی معاونت کرناچاہئے۔ ہم لائق مدیر کی خدمت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_110.jpg',
#   'text': 'مدیردمالک مولوی کی ادالعزمی اور حب رسول کاثبوت ہے۔ اس رسالہ کی علیحدہ قیمت ۲ ۱ رہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_111.jpg',
#   'text': 'کی ضخامت ایک روپیہ سالانہ چندہ میں خریداروں کومفت دیدیتامولوی عبدالحمیدخاں صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_112.jpg',
#   'text': 'صلعلم کی سیرتِ پاک پر مسلم اورمعتدغیر مسلم اہلِ قلم کے مفیدمضامین تقریباً ڈیرھ سوصفحات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_113.jpg',
#   'text': 'ونعتیہ نظموں کامتبرک مجموعہ ہے(اگرچہ اکثرنظمیں مطبوعہ ہیں،سرورق بلاک کارنگین ہے۔ سردرِ کائنات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_114.jpg',
#   'text': 'میں نہایت شان وعظت سے شائع ہواہے۔ جوتقریباً ڈیڑسوصفحات کے منتخب اورمقدس مضامین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_115.jpg',
#   'text': 'مذہبی رسالہ”مولوی“ کا”رسول نمبر“ حسب معمول عیدمیلادالنی صلعم کی تقریب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_116.jpg',
#   'text': 'مولویؔ ”رسول نمبر“۔دہلی کے سب سے سَستے اورہندوستان کے سب سے زیادہ کثیرالاشاعت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_117.jpg',
#   'text': '”نیرنگِ نظر“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_118.jpg',
#   'text': 'قریب میں محاسن ومعائب پر ہرپہلوسے روشنی ڈالیں گے۔کہ اس عامیانہ ہڑبونگ کی قلعی کُہلے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_119.jpg',
#   'text': 'کامطمح نظر بھی یھی ہو۔بہرحال تفصیلات کیلئے سردست ہم اپنی رائے محفوظ رکہتے ہیں اورمستقل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_120.jpg',
#   'text': 'آزادخیال مولف کی حیثیت سے اپنی تالیف کی تدوین میں متین ثابت ہو۔ اورغالباً ڈاکٹر صاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_121.jpg',
#   'text': 'فرض ہوتاہے کہ وہ”معمل“ میں ٹیہکرکسی مذہب وملّت سے متاثر نہو اور”سانٹیفک“ اصول سے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_122.jpg',
#   'text': 'رکہکر آزادانہ طورپر کسی خاص ”مذہبیت“ کی رعایت کئے بغیر تاریخ کومکمل کرے۔ کامیاب مورّخ کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_123.jpg',
#   'text': 'کے مطالعہ کی غرض سے ہے۔ اوراس لحاظ سے ایک مورّخ کافرض ہے کہ وہ فلسفہ- تاریخ کوسامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_124.jpg',
#   'text': 'ہیں کہ ڈاکٹر صاحب نے کسی خاص مذہب کیلئے یہ تاریخ مرتب نہیں کی ہے بلکہ ”ہندوستانی طلباء“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_125.jpg',
#   'text': 'ابھی بالاستیعاب نہیں پڑہاہے۔تاہم اسوقت عام غلط فہمی پہیلی ہوئی دیکہکریہ کہناضروری سمجہتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_126.jpg',
#   'text': 'مضر ہے۔ الزام یہ ہے کہ مسلمان بادشاہوں کااحترام ملحوظ نہیں رکہاگیاوغیرہ۔ ہم نے اس تاریخ کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_127.jpg',
#   'text': 'گذر کر ’ذات‘ پر بھی حملے شروع کردیئے ہیں۔ اوربتایاجارہاہے کہ یہ تاریخ مسلمان طلباء کیلئے نہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_128.jpg',
#   'text': 'کاشروع ہوئی ہے۔ ایک خاص طبقہ نے اس تاریخ کی تخریب شروع کرکے ڈاکٹر صاحب کی قابلیت سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_129.jpg',
#   'text': 'سلسلہ میں نہیں ہوئی۔ لیکن اب کچھ مدّت سے جب سے کہ یوپی کونسل کے مسئلہ انتخاب کی سلسلہ جنبانی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_130.jpg',
#   'text': '”تاریخِ ہند“ مرتب کی تھی۔ جس کی اشاعت کوبھی عرصہ ہوا۔ جب سے اب تک کوئی قابل ذکر رائے زنی اس',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_131.jpg',
#   'text': '(فیلوالہ آبادیونیورسٹی) نے طلباء اسکول کے لئے ایک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_132.jpg',
#   'text': 'یوپی کے مشہورفاضل مورّخ ڈاکٹر شفاعت احمدخانصاحب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_133.jpg',
#   'text': 'ڈاکٹر شفاعت احمدخاں کی ”تاریخ ہند',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_134.jpg',
#   'text': 'خواہ ہیں اور ارکین پریس و”نیرنگ“ احتیاط کے لئے متنبہ ہوچکے ہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_135.jpg',
#   'text': 'ہے۔اور ناظرین نیرنگ کے ’ذوق‘ کی اہانت ہے۔ اس لئے ہم اپنے معاونیں کرام سے خصوصاً عذر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_136.jpg',
#   'text': 'امرنہیں کیونکہ عموماً رسائل میں تصاویر کی اشاعت کامعیار بہی ہے۔لیکن نیرنگ کی روایات کے ضرور منافی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_137.jpg',
#   'text': 'کیا۔ اور اچہی خاصی تصاویر میں بے جوڑ چمک اورغیر متین بچپن نمایاں ہوگیا۔گوعام لحاظ سے یہ چنداں ناگوار',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_138.jpg',
#   'text': 'غلط فہمی ہوئی۔ اور منیجرصاحب نے اس خیال سے کہ پرچہ وقت پرشائع کرسکیں دوبارہ صحیح طباعت سے گریز',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_139.jpg',
#   'text': 'جوان ہوکر روزیٹیؔ نے فن مصوّری میں کمال حاصل کیا۔ ڈانٹے سے اکتساب کانتیجہ یہ تھاکہ ”روزیٹی ڈاناٹے“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_140.jpg',
#   'text': 'والہئ وشیداہوکر رہیگا۔ڈانٹے کی واجدانی شاعی کے اثرات اسکے دل پر نقش ہوکر رہ گئے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_141.jpg',
#   'text': 'ورشحاتِ لطیف نے روزیٹی کے قلب کوابتدائی عمر سے متاثر کرناشروع کیا۔اوروہ حسن فطرت کاپرستار اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_142.jpg',
#   'text': 'کی داستانیں اُس کے کانوں میں پڑیں۔جسکالازمی نتیجہ یہ تھاکہ وہ بھی شاعراعظم کے کمالات سے متکیف ہوااوراس کے خیالات جمیل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_143.jpg',
#   'text': 'ہوش سنبہال کر رویٹیؔ نے اپنے باپ کی زبان سے دن رات ڈانٹےؔ کے وجدآفریں اشعار سُنے اورتعریف وتوصیف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_144.jpg',
#   'text': 'باعث اُس نے اپنے بیٹے کانام”ڈانٹے جبرئیل روزیٹی“رکہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_145.jpg',
#   'text': 'روزمیٹیؔ کے باپ کومشہور ومعروف شاعراطالیہ ڈانٹے کے کمالات سے انتہائی شغف تھا۔اوراسی عقیدت کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_146.jpg',
#   'text': 'تہا۔مگر والدین ترک سکونت کرکے انگلستان آگئے تھے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_147.jpg',
#   'text': 'روزیٹیؔ ڈانٹے-- نوجوان اورکامیاب مصوّر انگلستان میں ۸۲۸۱ء میں پیداہوا۔اُسکاآبائی وطن اٹلی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_148.jpg',
#   'text': '(سرِورق کی تصویرکے ساتھ)',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_149.jpg',
#   'text': 'ڈانٹے کاخواب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_150.jpg',
#   'text': '(۶)ساریان:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_151.jpg',
#   'text': '(۵)نورِ ہدایت:۔ " " " " " " " " " " قیمت۱۴',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_152.jpg',
#   'text': '(۴)غزال:۔ " " " " " " " " " " قیمت۱۰',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_153.jpg',
#   'text': '(۳) بقائے دوام:۔ مصنفہ مسٹرایم اسلم لاہور طابع ناشر:۔ نسیم بکبڑ پوبار و دخانہ لاہور قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_154.jpg',
#   'text': '(۲)چینی اور جاپانی افسانے!۔ " " " " " " " " " " قیمت ۹',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_155.jpg',
#   'text': '(۱) قدیم افسانے (پہلاحصّہ)۔ طابع وناشر:۔انجمن امدادباہمی مکتبہ ابراہیّہ حیدرآباڈکن۔ قیمت ء',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_156.jpg',
#   'text': 'میں سے خصوصاً مندرجہ ذیل قابل ذکر ہیں:۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_157.jpg',
#   'text': 'رسیدکتب:۔ متعددکتب جوبغرض ریویوموصول ہوئی ہیں اُن پر آئندہ بالترتیب تبصرہ کیاجائیگاجن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_158.jpg',
#   'text': 'اہل نظر کودیکہناچاہیئے۔کاغذ کتاب طباعت اورضخامت”صبح لطافت“ کی مانندہیں۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_159.jpg',
#   'text': 'معاشری پہلوؤں پر کامیاب روشنی ڈالی گئی ہے۔ بہ حیثیتِ مجموعی”ملّاصاحب کی شادی، قابل دیدہے۔ اورہر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_160.jpg',
#   'text': 'ہیں۔تفصیلاتِ تقریب پر جومباحث اس کتاب میں درج ہیں دلچسپ ہونیکے ساتھ ہی مفیداورسبق آموزہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_161.jpg',
#   'text': 'وبلند مقصد کی جس ناپاک اور گندہ طرز تحریر کے ذریے سے پامای کی گیی ہے وہ حردرجہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_162.jpg',
#   'text': 'حوادث سے کی جائے۔ لیکن افسوس ہے کہ گلکتہ یھی کے تماشاگا ہوں میں اس شریف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_163.jpg',
#   'text': 'ڈراما کا مقصد ہے، کہ مہیست اجتماعی کی اصلاح شخصی  واقعات اور روز مرہ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_164.jpg',
#   'text': 'قوّلوں کو کیا نثبت ہے؟',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_165.jpg',
#   'text': 'پڑھ کر شریف فن اور کون ہو سکتا ہے، لیکن اب امیر خسرو سے بہار وخیراباد کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_166.jpg',
#   'text': 'وہ فن ہے ، حالانکہ خودجماعت کا رتبہ فن کی حیثیت سے ہونا چاہیے تھا۔ موسیقی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_167.jpg',
#   'text': 'اصل یہ ہے کہ فن کامرتبہ اس جماعت سے کیا جارہا ہے، جبکے ہاتھ  میں اسوقت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_168.jpg',
#   'text': 'افسانہ نگاری کے کاہل نامنہ ہیں ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_169.jpg',
#   'text': 'ہمرانی، حریری، زمخشری، اور سیوطی ، جن کا شمار اکابر علما میں ہے ، انکے مقامات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_170.jpg',
#   'text': 'ڈراما نویسی یا افسانہ نگاری آج فنون ادبیہ کی پست ترین سطح ہے۔ لیکن',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_171.jpg',
#   'text': 'ان کا تقوے کسی کو نہیں معلوم ، تا ہم وہ فن غنا کے ماہرین میں تھے ۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_172.jpg',
#   'text': 'کوئی چیز عیب گیری کی مستحق نہ تھی۔ امام ملک اور حضرت عمربن عبد الغریزکا تقدس اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_173.jpg',
#   'text': 'سمجھے جاتے ہیں ، حالانکہ اس مد میں جبکہ قوم کے نام توے  مشتعل تھے۔ ان میں سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_174.jpg',
#   'text': 'ہے۔ شاعری کے سوا فنون لطیفہ کے تمام اقسام آج کل خالاف وقار وستانت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_175.jpg',
#   'text': 'بزا تہ دنیا میں کوئی شے خیر محض یا شر محض نہیں، اس کا موقع استعمال خیریا شرہوتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_176.jpg',
#   'text': '( ۲ ) مولانا سید سلیمان ندوی ناظم دارالمصنفین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_177.jpg',
#   'text': 'ارو بارونق عالیشان قصروایوان کو چھوڑ کے نہرم کھنڈروں اور عبرتناک ویرانوں  کی سیر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_178.jpg',
#   'text': 'اس میں شک نہیں کہ ایک اثر پزیر دل حسرت و اندوہ کے واقعات کوزیادہ پسند کرتا ہے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_179.jpg',
#   'text': 'ہے کہ بجاے کا میڈمی کے حضرت "ناظر" نے اس ڈراما کا خاتمہ ٹریجڈی پر کیا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_180.jpg',
#   'text': 'لاٹ لٹریچرایک لطف   الان کے ساتھ گرانبار اور وقبق ہوگیا ہے ۔ اسی کا ایک نمونہ یہ بھی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_181.jpg',
#   'text': 'خوشی کی بات ہے کہ اس سے کسی قسم کی بدمزگی پیدا ہونے کے بجاے ڈرا ماکا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_182.jpg',
#   'text': 'اظہار کرتے وقت کی مقاموں پر وہ اپنے اصلی عالم فلسفہ میں واپس چلے گئے ہیں۔ مگر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_183.jpg',
#   'text': 'میں لائے ہیں ، جس میں علت و سبب پرغور کرنا جرم ہے۔ اسی وجہ سے جذبات کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_184.jpg',
#   'text': 'مگروہ اسے اس تصنیف میں اپنے عالم اسباب سے زبردستی کھینچ کرکے حسن و عشق کی دنیا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_185.jpg',
#   'text': 'لٹریچرمیں نظریات وقیق کا عادی ہے، اور ہرسلہ پراستدلال عنوان سے غور کرتا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_186.jpg',
#   'text': 'مصنف یعنی جناب "ناظر" کا مذاق بہت گہرا مالما نہ ہے ۔ ان کا دماغ ڈیپ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_187.jpg',
#   'text': 'حصہ اس مذاق سے اثنا ہے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_188.jpg',
#   'text': 'نوجوان کے قلم سے کمل ہو کر اس پبلک کے سامنے پیش ہوتا ہے ، جس کا بہت ہی محدود',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_189.jpg',
#   'text': 'یہ اردو میں ایک نیا ڈر اما ہے، جو ایک فلسفیانہ دماغ والے فاضل وقابل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_190.jpg',
#   'text': '(۱) مولانا مولوی عبدالحلیم سحاب  شرر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_191.jpg',
#   'text': 'تقریظات',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_192.jpg',
#   'text': 'ہیں- اور اب تک من حیث المجموع انھوں نے اس حق کے استعمال میں ایسی نجیع غلطیاں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_193.jpg',
#   'text': "یا نہ دیا جائے ، اور دیاجائے توکسی حد تک ' والدین اس حق کو کس طرح استعمال کرتے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_194.jpg',
#   'text': 'اہم ترین مسائل میں سے ہے ۔ حق آنخاب ، مناکحت میں بالکل فریقین کو دیا جائے-',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_195.jpg',
#   'text': "انھوں نے موضوع تصنیف قرار دیا ہے' اس میں شک نہیں  کہ ہماری موجودہ سو سائٹی کے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_196.jpg',
#   'text': 'ادبی حیثیت کی تقیص کرتے ہیں ۔ ان اجزا میں جزواعظم  مسٹر بسیٹی ہیں- جس مسلے کو',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_197.jpg',
#   'text': 'بھی آج کل کی ناٹک کمپنی اسے اسٹیج پراجیکٹ کرسکے ایسے اجزا کو دخل دیا جو اسکی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_198.jpg',
#   'text': 'انھوں نے ڈراما لکھتے وقت اس بات کوپیش نظر رکھکر کہ یہ ایسا ہوکہ کوئی کمپنی اور وہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_199.jpg',
#   'text': "میرے نزدیک وہ یوسف کی تخلیق میں بہت زیادہ کامیاب ہوے ہیں' لیکن",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_200.jpg',
#   'text': 'نگاری کی حیثیت سے ایک تصنیف لطیف ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_201.jpg',
#   'text': '" زدوپشیماں" ادبی حیثیت سے، اورنیز(میں انھیں کا لفظ استعمال کرتا ہوں) کیرمکیڑ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_202.jpg',
#   'text': "میں خوش ہوں کہ 'ناظر' نے اس طرف توجہ کی ۔ اور وہ ایک بڑی حد تک کامیاب بھی ہوئے",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_203.jpg',
#   'text': 'بلکہ مے میشودازصحبت ناداں بدنام',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_204.jpg',
#   'text': 'سے کہ بدنام کنداہل خدود اغلط اسٹ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_205.jpg',
#   'text': 'میں نہیں لیتے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_206.jpg',
#   'text': 'صحیح مذاق غاٹرنظر رکھنے والوں سے اس کا گلۂ قریم ہے کہ وہ اسے اپنے ہاتھوں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_207.jpg',
#   'text': "زیادہ اور کوئی کیا واقف ہوگا کہ یہ فن' نا اہل ہاتھوں میں پڑکرذلیل ہوا ہے ۔ اور",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_208.jpg',
#   'text': 'کی نگاہ میں بتذل قرار دیتے ہی۔ بہت کچھ عزرخواہی کے بہے میں ذکر کیا ہے۔ ان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_209.jpg',
#   'text': "نظر آتے ہیں ۔ کیونکہ اپنے دیباچے میں انھوں نے اس میدان میں آنے کا ' جسے وہ پبلک",
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_210.jpg',
#   'text': 'سجاد حیدر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_211.jpg',
#   'text': 'لکھنؤ - ۲۸ مئی ۱۹۱۷',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_212.jpg',
#   'text': 'اور کہیں نہیں ہوسکتی۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_213.jpg',
#   'text': 'اس میں شک نہیں کہ "زود پشیماں" کی ٹریجڈی ہواے ہماری سوسائٹی کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_214.jpg',
#   'text': 'دلچسپ اورنہایت موثرروشنی ڈالتا ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_215.jpg',
#   'text': '"زود پشیماں" ان سائل کے تاریک وغیرمنکشف پہلووں میں سے ایک پہلوپرنہایت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_216.jpg',
#   'text': 'کے والدین کے سررہیں ۔ میری راے  میں: مسائل نہایت غور طلب ہیں ، اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_217.jpg',
#   'text': 'کے مصارف اوراز ویا دنسل کے علاوہ باقی تمام ذمہ داریاں ، نوجوان میں بیوی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_218.jpg',
#   'text': 'دست نگر رہتے ہیں ، آیا یہ جائز بھی ہے کہ حق انتخاب تونوجوان کو دیہ  جائے اور ازدواج',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_219.jpg',
#   'text': 'کے نظام میں ، جس میں عمرطبیعی کے ایک طویل حصے تک مرد بھی، اپنے والدین کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_220.jpg',
#   'text': 'ہیں توڈالنے کی کوشش کرتے بھی ہیں یانہیں ۔ اور سب سے بڑھکریہ کہ ہماری سوسائٹی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_221.jpg',
#   'text': 'رفاقت یا دام الحیات کے تمام لوازمات پرایک دورہیں نظرڈال سکتے ہیں؛ اور اگرڈ ال سکتے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_222.jpg',
#   'text': 'کی ہیں جیسی کہ نواب با قرحسین سے سرزد ہوئیں، اور آیا دو نوجون ، سودا زده دل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_223.jpg',
#   'text': 'اگر میں مذہبی ذہنیت کاانسان ہوتاتوشاید میں بھی اس منظرکودیکھ کر دعائیں پڑھنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_224.jpg',
#   'text': 'نظر ڈالی-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_225.jpg',
#   'text': 'میں نے دروازہ بندکرلیااورکمرے میں واپس چلاآیا۔ ایک بار پھر میں نے مکرجیؔ پر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_226.jpg',
#   'text': 'پیچھے ہوگئے۔ جب وہ روانہ ہواتومیں نے دیکھاکہ وہ بڑی قوت کے ساتھ قدم اٹھارہاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_227.jpg',
#   'text': 'کا ایک اور جوڑاباہر دہلیز پر اس کا منتظرتھا۔ وہ مستعدی و سرعت سے اسکے آگے اور',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_228.jpg',
#   'text': 'اس نے گرمجوشی سے میرا ہاتھ دبایااورکمرے کادروازہ کھول دیا۔ مستعدوہوشیارمحافظین',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_229.jpg',
#   'text': 'ملنے اور سوالات کرنے کی اجازت مرحمت فرمائیں“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_230.jpg',
#   'text': 'آئیں کہ وہ مکرجیؔ کے قریبی اعزاء ہیں تواس صورت میں بھی آپ میرے آدمیوں کوان سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_231.jpg',
#   'text': 'زیادہ ہوں توآپ ایک بار صرف یاک ہی کو آنے دیں۔ اگرکچھ لوگ یہ دعویٰ لے کر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_232.jpg',
#   'text': 'تحقیق حال کے لئے آئیں توآپ ان کوآنے کی اجازت دیدیں لیکن اگر وہ ایک سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_233.jpg',
#   'text': 'آنے والوں میں سے کوئی آدمی ٹیلیفون پر بات کرلے گا۔ اگر کچھ لوگ بذات خود مکرجیؔ کی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_234.jpg',
#   'text': 'کرے توآپ جواب نہ دیں۔ میرے ان دو موجودہ آدمیوں میں سے کوئی شخص یا ان کی جگہ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_235.jpg',
#   'text': '”ایک بات اور عرض کرنی ہے۔ اگر کوئی شخص ٹیلیفون پر مکرجیؔ کی حالت دریافت',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_236.jpg',
#   'text': 'دروازہ کھولنے کے لئے اس نے ہاتھ بڑھایا----- اور رک گیا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_237.jpg',
#   'text': 'سے اسی چیز کو بیان کردیاتھا جس کومیں خودمحسوس کرچکاتھا لیکن الفاظ میں ادا نہ کرسکاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_238.jpg',
#   'text': '”میں نے بے اختیار”ہوں“کہہ کر اس کی تائیدکردی۔ بات یہ ہے کہ اس نے بڑی خوبی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_239.jpg',
#   'text': 'کہ--- کہ جنم کانظارہ کروں!“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_240.jpg',
#   'text': 'ایک خوف محسوس ہورہاہے۔ میں نہیں چاہتاکہ دوسرا حملہ مجھ پر ہو----- میں نہیں چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_241.jpg',
#   'text': 'نظرڈالتاہوں اور زندگی میں پہلی مرتبہ مجھے----- جلال جیسے آہنی انسان کو-----',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_242.jpg',
#   'text': 'نے اپنی آنکھوں کوملااورپھر دیکھا۔اس کے بعدمیں نے ڈاکٹر اشوک کواپنے پاس بلاکر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_243.jpg',
#   'text': 'ادھر بدلنے سے کسی طرح بھی اس ننھے سے شرارے میں کوئی تبدیلی رونمانہ ہوئی۔ میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_244.jpg',
#   'text': 'سب سے پہلے مجھے یہ خیال ہواکہ یہ کمرے کی روشنی کاتاثر ہے لیکن روشنی کوادھر',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_245.jpg',
#   'text': 'کی مانندروشن نظر آتی تھی!',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_246.jpg',
#   'text': 'لیکن اس کے اندر فاسفورس کی سی کوئی چمک وار شے موجودتھی جوکہ ایک ننھے سے قمقمے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_247.jpg',
#   'text': 'کاایک سفید ذرہ میری نگاہ کی زدمیں آگیا----- یہ محض ایک سادہ سفید ذرہئ خون تھا---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_248.jpg',
#   'text': 'ایک ناقابل یقین چیز موجودہے۔میں نے پلیٹ کوخواہ مخواہ ادھر ادھر حرکت دی تو خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_249.jpg',
#   'text': 'میں شیشے کی چوتھی پلیٹ دیکھ رہاتھا جبکہ مجھے یہ محسوس ہواکہ میری نظر کے سامنے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_250.jpg',
#   'text': 'ہوا بریک ہٹ جائے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_251.jpg',
#   'text': 'چیز معلوم کرسکوں گابلکہ مقصدصرف یہ تھاکہ میرے دماغ کے ایک دوسرے حصّے پر لگا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_252.jpg',
#   'text': 'کے چند دھبے لیے اور ان کامطالعہ کرنے لگا۔ ایسا کرنے سے مجھے یہ توقع نہ تھی کہ کوئی نئی',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_253.jpg',
#   'text': 'پر زیادہ آزادی سے سوچنے کی اہلیت پیداہوجاتی ہے۔ لہٰذا میں نے مکرجیؔ کے خون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_254.jpg',
#   'text': 'ہے۔ میں نے دیکھاہے کہ خوردبینی کام میں مصروف رہنے کے دوران میرے اندر مسایل',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_255.jpg',
#   'text': 'ضروری ہے لیکن اس کی کنجی میرے پاس نہیں اور قفل کاسوراخ بھی مجھے نظر نہیں آرہا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_256.jpg',
#   'text': 'میں کسی بھیانک خواب میں ایک ایسے دروازے کے باہر کھڑاہواہوں جس کوکھولنا اشد',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_257.jpg',
#   'text': 'تھا۔ یہ پورامعاملہ مجھے پریشان کئے ہوئے تھااور مجھے ایسا محسوس ہورہاتھا گویا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_258.jpg',
#   'text': 'کرکچھ ایسا لڑکھڑاگیاتھاکہ دوسروں کے سامنے اس کااعتراف کرنے کودل نہ چاہتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_259.jpg',
#   'text': 'چہرے اورآنکھوں میں ”شیطانی اشتیاق“ اور”شیطانی مسرت“ کی تبدیلیاں دیکھ',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_260.jpg',
#   'text': 'موجودتھاکہ جانچ کے مزید نتائج سے بھی کچھ ثابت نہ ہوگا۔ اس کے علاوہ میں مکرجیؔ کے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_261.jpg',
#   'text': 'واپس آنے کاحکم ملاہو۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_262.jpg',
#   'text': 'معلوم ہوتی تھیں جس کواپنے محبوب وپسندیدہ جہنم سے ایک طویل جلاوطنی کے بعداچانک',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_263.jpg',
#   'text': 'یہ مسرت دیوانگی آمیزنہ تھی۔ یہ شیطانی مسرت تھی۔ یہ نگاہیں اس شیطان کی مسرور نگاہیں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_264.jpg',
#   'text': 'شعور حاصل ہورہاہو--- ان آنکھوں میں ایک ناپاک مسرت کوندرہی تھی---',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_265.jpg',
#   'text': 'تین آدمیوں کی قریبی موجودگی کااحساس کر رہاہو--- جیسے اس کوپورے کمرے کا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_266.jpg',
#   'text': 'اچانک مکرجیؔ کی آنکھوں میں نگاہوں کے مرکوز ہونے کی کیفیت پیداہوئی جیسے وہ ہم',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_267.jpg',
#   'text': '--- ٹھیک اسی طرح جیسے میں نے کیاتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_268.jpg',
#   'text': 'نے دیکھاکہ کمارؔ نے رخ بدل کر اپنے پیچھے کی طرف نظر ڈالی اور کمرے میں ادھر ادھر دیکھا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_269.jpg',
#   'text': 'آلوددلکشی و محویت کے ساتھ مکرجیؔ کے چہرے پر جمی ہوئی تھیں --- اسی وقت میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_270.jpg',
#   'text': 'ڈاکٹرکمارؔاور نرس شیلاؔ مریض کی چارپائی کی دوسری طرف تھے۔ان کی آنکھیں خوف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_271.jpg',
#   'text': 'دروازے پر جماہواتھا۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_272.jpg',
#   'text': 'بیٹھاہواسامنے کلیسا کی چھت کی فصیلوں کوتک رہاتھا۔دوسراآدمی مستعدی سے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_273.jpg',
#   'text': 'لیکن وہاں کوئی چیز موجودنہ تھی۔جلالؔ کاایک آدمی کھڑکی کے گوشے کی تاریکی میں',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_274.jpg',
#   'text': 'سی ہیبت ناک شے میری طرف دبے پاؤں رینگتی آرہی ہے۔',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_275.jpg',
#   'text': 'مڑ کر اپنے شانے کے اوپر سے یاک نظر ڈالی یہ معلوم کرنے کے لیے کہ پشت کیطرف سے کون',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_276.jpg',
#   'text': 'کہاجاسکتاہے اور یہ کیفیت اس حدتک ”شیطانی“ محسوس ہوتی تھی کہ بے اختیار میں نے',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_277.jpg',
#   'text': 'نظر آتاتھالیکن اب اس کی نظروں میں ایک ایسی کیفیت تھی جس کوایک ”شیطانی اشتیاق“',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_278.jpg',
#   'text': 'بھی وہ میرے جسم کے اس پار اور خوداپنے جسم کے اندر کی طرف بہ یک وقت دیکھتا',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_279.jpg',
#   'text': 'لگتا۔ مکرمیؔ کے چہرے کاعالم تبدیل ہوگیاتھا۔دہشت و نفرت غائب ہوچکی تھی۔ اب',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_280.jpg',
#   'text': 'یاشاید اس کی وجہ یہ ہوکہ اس کومجھ پر حملہ کرنے کاموقع حاصل نہ تھا۔ میں مکرجی کیطرف',
#   'source': 'utrset_real',
#   'split': ''},
#  {'image': 'data/raw/other/utrset_281.jpg',
# ...
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0506.png',
#   'text': 'مہا بھارت دنیا کی طویل ترین نظم سمجھی جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0507.png',
#   'text': 'چھٹی صدی ق م سے تیسری صدی ق م تک مہا جن پد کے عروج کا دور ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0508.png',
#   'text': 'قدیم بودھ گرنتھوں انگُتّر نکائے وغیرہ میں ان سولہ ریاستوں کا کثرت سے تذکرہ ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0509.png',
#   'text': 'وادی سندھ کی تہذیب کے خاتمہ کے بعد اسی عہد میں پہلی بار ہندوستان میں بڑے بڑے شہر بسائے گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0510.png',
#   'text': 'وجی مہا جن پد کے تخت اقتدار پر لچھوی سب سے معروف قبیلہ گذرا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0511.png',
#   'text': 'سیاہ قلعی دار شمالی برتنوں کی ثقافت کا زمانہ بھی یہی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0512.png',
#   'text': '500 یا 400 ق م یعنی گوتم بدھ کے عہد تک مذکورہ سولہ مہا جن پد چار بڑی ریاستوں میں ضم ہو گئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0513.png',
#   'text': 'یہ چار ریاستیں تھیں: وَتس، اَوَنتی، کوشل اور مگدھ',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0514.png',
#   'text': 'گوتم بدھ کے حالات زندگی انھی چار ریاستوں کے گرد گھومتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0515.png',
#   'text': 'مگدھ کا دور اول',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0516.png',
#   'text': 'ابتدا میں راجگیر پایۂ تخت رہا لیکن بعد میں پاٹلی پتر (موجودہ پٹنہ) منتقل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0517.png',
#   'text': 'جین اور بودھ گرنتھوں میں مگدھ کی اس قدیم سلطنت کا بارہا ذکر آیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0518.png',
#   'text': 'نیز راماین، مہا بھارت اور پرانوں میں بھی اس کا مذکور ملتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0519.png',
#   'text': 'جین مت اور بدھ مت کے فروغ میں سلطنت مگدھ کا خاصا اہم کردار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0520.png',
#   'text': 'مگدھ کے دائرۂ اقتدار میں بعض جمہوری برادریاں مثلاً راج کمار برادری وغیرہ بھی شامل تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0521.png',
#   'text': 'سلطنت کا نظم و انصرام عاملہ، عدلیہ اور فوج کے شعبوں میں منقسم تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0522.png',
#   'text': 'انگ کا علاقہ اب مشرقی بہار اور مغربی بنگال میں پڑتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0523.png',
#   'text': 'یہی دور ہے جس میں گوتم بدھ نے اپنی زندگی کا بیشتر حصہ مگدھ سلطنت میں گذارا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0524.png',
#   'text': 'ہریک خانوادہ کے بعد شی شو ناگ خانوادہ تخت سلطنت پر متمکن ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0525.png',
#   'text': '345 ق م میں آخری شی شو ناگ بادشاہ کالا شوک مہا پدم نند کے ہاتھوں مارا گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0526.png',
#   'text': 'مہا پدم نند نو نندوں میں سے پہلا تھا اور اس کے بعد اسی کے آٹھ بیٹے نند کہلائے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0527.png',
#   'text': 'نند سلطنت اور سکندر کی مہم',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0528.png',
#   'text': 'نند سلطنت کی سرحدیں بنگال سے پنجاب تک اور جنوب میں وندھیاچل تک پھیلی ہوئی تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0529.png',
#   'text': 'یہ نند سلطنت کے عروج کا زمانہ تھا اور اس کی ثروت اور دولت مندی کے چرچے ہر طرف تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0530.png',
#   'text': 'چنانچہ سکندر کو پنجاب اور سندھ کے میدانوں سے واپس لوٹنا پڑا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0531.png',
#   'text': 'بر صغير سے سکندر اعظم کے جانے کے بعد نند سلطنت کی بساط الٹ گئی اور موريا دور کا آغاز ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0532.png',
#   'text': 'برصغیر کی تاریخ میں پہلی بار ایسی عظیم الشان اور مستحکم سلطنت قائم ہوئی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0533.png',
#   'text': 'اس جنگ میں فتح پانے کے بعد دریائے سندھ کا مغربی خطہ بھی اس کی حکومت میں شامل ہو گیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0534.png',
#   'text': 'چندر گپت کے بعد اس کا بیٹا بندو سار 297 ق م کے آس پاس تخت سلطنت پر بیٹھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0535.png',
#   'text': 'البتہ کلنگ کا علاقہ (موجودہ اوڈیشا) اس کے دائرۂ اقتدار سے باہر رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0536.png',
#   'text': 'شاید اس کی وجہ یہ تھی کہ جنوب سے کلنگ کے تجارتی روابط مضبوط تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0537.png',
#   'text': 'بندو سار کے بعد سلطنت کی باگ ڈور اشوک کے ہاتھوں میں آئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0538.png',
#   'text': 'اشوک نے 232 ق م میں اپنی وفات تک تقریباً 37 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0539.png',
#   'text': 'اس منظر نے اشوک کے وجود کو اندر سے ہلا ڈالا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0540.png',
#   'text': 'بالآخر اس نے زور و تشدد کی راہ ترک کر دی اور بدھ مت قبول کرنے کا اعلان کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0541.png',
#   'text': 'اشوک کے عہد حکومت میں بدھ مت سارے ہندوستان میں پھیل چکا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0542.png',
#   'text': 'اس دوران میں اور اس کے بعد بھی يونانيوں اور کشانوں کا اثر برقرار رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0543.png',
#   'text': 'اس کا دارالخلافہ قنوج تھا جس کے کھنڈر آج بھی شمالی بھارت میں پائےجاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0544.png',
#   'text': 'جنگ کلنگ کے بعد تقریباً نصف صدی تک سلطنت میں ہر طرف امن و امان کا راج رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0545.png',
#   'text': 'یہ عوام کی فلاح و بہبود، سماجی ہم آہنگی، مذہبی تبدیلی اور علوم و فنون کی ترقی کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0546.png',
#   'text': 'ارتھ شاستر اور اشوک کے کتبے موریا دور کے احوال و وقائع کے اولین مآخذ ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0547.png',
#   'text': 'اثریات کی رو سے یہ سیاہ قلعی دار شمالی برتنوں کی تہذیب کا زمانہ تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0548.png',
#   'text': 'موریا سلطنت کی بنیادیں اپنے عہد کی ترقی یافتہ معیشت اور ہنر مند سماج پر استوار تھیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0549.png',
#   'text': 'یہ فولاد چین اور عرب تک جاتا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0550.png',
#   'text': 'تیسری صدی ق م سے چوتھی صدی عیسوی تک کا زمانہ سنگم عہد کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0551.png',
#   'text': 'یہ تینوں شاہی خانوادے تمل اکام کے تاجوران ثلاثہ کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0552.png',
#   'text': 'ان کے مسائل کا بچشم خود مشاہدہ کیا اور ان کے درد و کرب کو محسوس کیا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0553.png',
#   'text': 'ان کا دھرم مختلف اور پیشے جدا جدا تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0554.png',
#   'text': 'ان میں کاشت کار بھی تھے، دست کار بھی تھے، دکان دار، تاجر اور پروہت بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0555.png',
#   'text': 'ان میں عورتیں بھی تھیں اور شاہزادے بھی تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0556.png',
#   'text': 'تقریباً 300 ق م سے 200 عیسوی تک پَتو پاٹّو، ایٹو توگئی اور پَتی نَینکل کنکّو لکھے جاتے رہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0557.png',
#   'text': 'پَتو پاٹّو اوسط لمبائی کی دس نظموں کا مجموعہ ہے اور سنگم ادب کا حصہ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0558.png',
#   'text': 'نیز تمل زبان کے گرامر کی قدیم ترین کتاب تولکا پیئم بھی اسی دوران میں تصنیف کی گئی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0559.png',
#   'text': 'سیلاپتی کارم کو ایلانگو ادیگل نے لکھا جو ایک غیر مذہبی رزمیہ ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0560.png',
#   'text': 'اس ظلم پر کن نکی کا جذبۂ انتقام بیدار ہوتا ہے اور سلطنت سے بدلہ لینے کی ٹھان لیتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0561.png',
#   'text': 'سیتَلئی ساتّنار نے منی میکالئی تصنیف کی جو دراصل سیلاپتی کارم ہی کا تسلسل ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0562.png',
#   'text': 'اس میں کوولن کی بیٹی مادھوی کی کہانی نظم کی گئی ہے جو بودھ بھکشونی بن جاتی ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0563.png',
#   'text': 'کلاسیکی اور اوائل قرون وسطی کے ادوار (200 ق م تا 1200ء)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0564.png',
#   'text': 'تیسری صدی عیسوی سے چھٹی صدی عیسوی کا درمیانی عرصہ ہندوستان کا کلاسیکی دور کہلاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0565.png',
#   'text': 'یہ عہد موریہ سلطنت کے زوال سے شروع ہو کر گپت سلطنت کے زوال تک جاری رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0566.png',
#   'text': 'اس دور کو مزید مختلف ذیلی ادوار میں تقسیم کیا گیا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0567.png',
#   'text': 'یہی وہ دور ہے جس میں شونگ اور ساتواہن سلطنتوں کو عروج حاصل ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0568.png',
#   'text': 'چوتھی صدی عیسوی سے چھٹی صدی عیسوی تک گپت سلطنت قائم رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0569.png',
#   'text': 'گپت سلطنت کا یہ دور ہندومت کی تاریخ کا عہد زریں سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0570.png',
#   'text': 'ابتدائی کلاسیکی دور (تقریباً 200 ق م تا تقریباً 320 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0571.png',
#   'text': 'شونگ مگدھ سے اٹھے اور برصغیر ہند کے مشرقی اور وسطی علاقوں تک اپنی سلطنت قائم کر لی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0572.png',
#   'text': 'ان کا عہد سلطنت تقریباً 187 ق م سے 78 ق م تک رہا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0573.png',
#   'text': 'پشیہ متر شونگ نے 36 برس حکومت کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0574.png',
#   'text': 'بعد ازاں اس کا بیٹا اگنی متر اس کا جانشین ہوا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0575.png',
#   'text': 'کل دس شونگ بادشاہ گذرے ہیں لیکن اگنی متر کی وفات کے بعد سلطنت کا شیرازہ تیزی سے بکھرنے لگا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0576.png',
#   'text': 'شونگ سلطنت اپنے دور حکمرانی میں بیرونی اور اندرونی دونوں طاقتوں سے نبرد آزما رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0577.png',
#   'text': 'اس نے سلطنت کو پھلنے پھولنے اور اقتدار حاصل کرنے میں خاصی مدد کی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0578.png',
#   'text': 'ساتواہن سلاطین اصلاً دکنی تھے، اسی بنا پر وہ "آندھرا سلاطین" بھی کہلاتے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0579.png',
#   'text': 'ساتواہن سلاطین ہندومت اور بدھ مت کے بڑے سرپرست اور مربی گذرے ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0580.png',
#   'text': 'ساتواہن ان اولین ہندوستانی ریاستوں میں سے ہے جنھوں نے اپنے سکوں پر سلاطین کی شبیہ بنائی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0581.png',
#   'text': 'بالخصوص مغربی شترپوں سے ان کی کشمکش طویل عرصہ تک جاری رہی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0582.png',
#   'text': 'ہندوستان کی تجارت اور سیاحت',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0583.png',
#   'text': 'کیرالا کی مسالوں کی تجارت قدیم دنیا کے تاجروں کو کھینچ کھینچ کر ہندوستان لا رہی تھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0584.png',
#   'text': 'پہلی صدی عیسوی کے آس پاس توما رسول بحری راستے سے ہندوستان پہنچا اور موزریز ساحل پر اترا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0585.png',
#   'text': 'یہاں پہنچ کر توما نے سات گرجا گھروں کی بنیاد رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0586.png',
#   'text': 'ہندوستان کی سیاحت کرنے والے چینیوں میں فاہیان، یی جنگ، سونگ یون اور ہیون سانگ قابل ذکر ہیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0587.png',
#   'text': 'روم و یونان نے شاہراہ بخور اور ہند رومی شاہراہوں کے ذریعہ اپنی تجارت جاری رکھی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0588.png',
#   'text': 'کُجُل کڈفِسیس کشان سلطنت کا پہلا فرماں روا تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0589.png',
#   'text': 'شہنشاہ کنشک بدھ مت کا بڑا مربی تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0590.png',
#   'text': 'اس کے باوصف بدھ مت کے استحکام میں کشانیوں کے غیر معمولی کردار کو فراموش نہیں جا سکتا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0591.png',
#   'text': 'مورخ ونسنٹ اسمتھ کنشک کے متعلق لکھتا ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0592.png',
#   'text': 'اس عہد میں گندھارا اور متھرا کے فنون بھی بہار دکھانے لگے تھے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0593.png',
#   'text': 'ان میں نئے شگوفے کھلے، نئے غنچے چٹخے، نئے رجحان سامنے آئے اور یہ فنون اپنی جوبن پر آگئے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0594.png',
#   'text': 'ہیو جارج رالنسن رقم طراز ہے:',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0595.png',
#   'text': 'تیسری صدی عیسوی تک پہنچتے پہنچتے کشانوں کی سلطنت بکھرنے لگی',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0596.png',
#   'text': 'ان کا آخری قابل ذکر بادشاہ واسو دیو اول تھا',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0597.png',
#   'text': 'کلاسیکی دور (320 عیسوی - 650 عیسوی)',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0598.png',
#   'text': 'انھی وجوہ سے گپت عہد کو ہندوستانی ثقافت کی تاریخ کا اہم ترین موڑ سمجھا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0599.png',
#   'text': 'اس عہد میں علوم و فنون اور سیاسی انتظام و انصرام نے نئی چوٹیاں سر کیں',
#   'source': 'synthetic',
#   'split': ''},
#  {'image': 'data/raw/synthetic/urdu_0600.png',
#   'text': 'یہی وجہ ہے کہ تاریخ کے چہرے پر اس عہد کو گپت سلطنت کا بوسۂ امن قرار دیا جاتا ہے',
#   'source': 'synthetic',
#   'split': ''},
#  ...]

# %% [markdown]
# ## 8. Source 6 — Newspaper (Manual Screenshots + Automatic OCR)
#
# **Unchanged — still manual, by design.** Take 30+ screenshots of real Urdu
# newspaper/magazine text and upload them into `data/raw/newspaper/` in the Colab file
# panel. The cell below runs OCR automatically to draft the transcription — always
# **proofread the OCR output** before trusting it as ground truth. Skip this section
# entirely if you don't have screenshots to add; the dataset works fine without it.

# %%
import glob

# Step 1: find every image already uploaded into the newspaper folder
image_folder = 'data/raw/newspaper/'
all_images = sorted(
    glob.glob(image_folder + '*.png') +
    glob.glob(image_folder + '*.jpg') +
    glob.glob(image_folder + '*.jpeg')
)

print(f"Total images found: {len(all_images)}")
for i, img in enumerate(all_images):
    print(f"{i+1}. {os.path.basename(img)}")

if not all_images:
    print("\nNo images found yet. Upload screenshots to data/raw/newspaper/ "
          "in the Colab file panel, then re-run this cell. Safe to skip otherwise.")
# Out:
# Total images found: 32
# 1. Screenshot 2026-07-01 151343.png
# 2. Screenshot 2026-07-01 151408.png
# 3. Screenshot 2026-07-01 151453.png
# 4. Screenshot 2026-07-01 151535.png
# 5. Screenshot 2026-07-01 152101.png
# 6. Screenshot 2026-07-01 152119.png
# 7. Screenshot 2026-07-01 152146.png
# 8. Screenshot 2026-07-01 181314.png
# 9. Screenshot 2026-07-01 181421.png
# 10. Screenshot 2026-07-01 181430.png
# 11. Screenshot 2026-07-01 181452.png
# 12. Screenshot 2026-07-01 181504.png
# 13. Screenshot 2026-07-01 181513.png
# 14. Screenshot 2026-07-01 181521.png
# 15. Screenshot 2026-07-01 181531.png
# 16. Screenshot 2026-07-01 181605.png
# 17. Screenshot 2026-07-01 181614.png
# 18. Screenshot 2026-07-01 181623.png
# 19. Screenshot 2026-07-01 181632.png
# 20. Screenshot 2026-07-01 181650.png
# 21. Screenshot 2026-07-01 181711.png
# 22. Screenshot 2026-07-01 181718.png
# 23. Screenshot 2026-07-01 181727.png
# 24. Screenshot 2026-07-01 182025.png
# 25. Screenshot 2026-07-01 182033.png
# 26. Screenshot 2026-07-01 182040.png
# 27. Screenshot 2026-07-01 182048.png
# 28. Screenshot 2026-07-01 182103.png
# 29. Screenshot 2026-07-01 182111.png
# 30. Screenshot 2026-07-01 182120.png
# 31. Screenshot 2026-07-01 182129.png
# 32. Screenshot 2026-07-01 182139.png

# %%
# Step 2: run OCR automatically on every newspaper image (skips cleanly if none uploaded)
newspaper_rows = []

if all_images:
    import easyocr
    reader = easyocr.Reader(['ar', 'en'], gpu=False)
    print("OCR reader ready.")

    for img_path in all_images:
        try:
            result = reader.readtext(img_path, detail=0, paragraph=True)
            extracted_text = ' '.join(result).strip()

            if extracted_text:
                newspaper_rows.append({
                    'image': img_path,
                    'text': extracted_text,
                    'source': 'manual_screenshot',
                    'split': ''
                })
                print(f"OK   {os.path.basename(img_path)}")
            else:
                print(f"SKIP {os.path.basename(img_path)} (no text detected)")
        except Exception as e:
            print(f"FAIL {os.path.basename(img_path)}: {e}")

    append_to_labels_csv(newspaper_rows)
    print("\nIMPORTANT: proofread the OCR text in labels.csv before trusting it as ground truth.")
else:
    print("No newspaper screenshots to process -- skipping (this is fine).")
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteOCR reader ready.
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 151343.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 151408.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 151453.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 151535.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 152101.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 152119.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 152146.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181314.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181421.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181430.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181452.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181504.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181513.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181521.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181531.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181605.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181614.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181623.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181632.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181650.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181711.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181718.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 181727.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182025.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182033.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182040.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182048.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182103.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182111.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182120.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182129.png
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# OK   Screenshot 2026-07-01 182139.png
#   labels.csv: 3160 total entries (+32 new).
#
# IMPORTANT: proofread the OCR text in labels.csv before trusting it as ground truth.

# %% [markdown]
# ## 6a. OPTIONAL — Real Photos for Books / Signboards / Newspaper
#
# **Skip this section if you're happy with the synthetic books/signboards images
# generated above.** Unchanged from the original notebook.

# %%
def replace_with_real_photos(zip_name, category_folder):
    """
    Extracts a ZIP of real photos into data/raw/<category_folder>/,
    replacing any synthetic images that were there, and clears the
    matching rows from labels.csv so nothing stale lingers.

    zip_name: path to the uploaded ZIP, e.g. "Books.zip"
    category_folder: one of "books", "signboards", "newspaper", "other"
    """
    out_dir = f"data/raw/{category_folder}"

    if not os.path.exists(zip_name):
        print(f"'{zip_name}' not found. Upload it to the Colab file panel first.")
        return []

    # 1. Wipe old images in this category folder
    if os.path.exists(out_dir):
        shutil.rmtree(out_dir)
    os.makedirs(out_dir, exist_ok=True)

    # 2. Remove old rows for this folder from labels.csv
    if os.path.exists(LABELS_CSV):
        with open(LABELS_CSV, "r", encoding="utf-8") as f:
            rows = list(csv.DictReader(f))
        rows = [r for r in rows if not r["image"].startswith(out_dir)]
        with open(LABELS_CSV, "w", newline="", encoding="utf-8") as f:
            writer = csv.DictWriter(f, fieldnames=["image", "text", "source", "split"])
            writer.writeheader()
            writer.writerows(rows)

    # 3. Extract the ZIP
    extract_to = f"{category_folder}_extract_tmp"
    with zipfile.ZipFile(zip_name, "r") as zf:
        zf.extractall(extract_to)

    # 4. Find all images inside (any nested folder)
    images = []
    for root, _, files in os.walk(extract_to):
        for f in sorted(files):
            if f.lower().endswith((".png", ".jpg", ".jpeg")):
                images.append(os.path.join(root, f))

    # 5. Copy and rename sequentially, add placeholder rows
    new_rows = []
    for i, src in enumerate(sorted(images), start=1):
        ext = os.path.splitext(src)[1].lower()
        new_name = f"{category_folder[:-1] if category_folder.endswith('s') else category_folder}_{i:03d}{ext}"
        dst = os.path.join(out_dir, new_name)
        shutil.copy(src, dst)
        new_rows.append({
            'image': dst, 'text': 'FILL_IN_URDU_TEXT_HERE',
            'source': f'{category_folder}_real', 'split': ''
        })

    shutil.rmtree(extract_to)
    append_to_labels_csv(new_rows)
    print(f"Copied {len(images)} real photos into {out_dir}.")
    print("Now use the manual labeling widget below to fill in the Urdu text.")
    return new_rows


# ── Example usage (uncomment and edit to use) ──────────────────────────
# real_book_rows = replace_with_real_photos("Books.zip", "books")
# real_signboard_rows = replace_with_real_photos("Signboards.zip", "signboards")

# %% [markdown]
# ## 9. Package the Dataset

# %%
shutil.make_archive('my_dataset_final', 'zip', 'data')
print("ZIP ready: my_dataset_final.zip")
# Out:
# ZIP ready: my_dataset_final.zip

# %% [markdown]
# ## 9a. NEW — Save Everything to Google Drive
#
# Your Week 3, 4, and 5 notebooks all search Google Drive for `labels.csv` and for the
# trained model. The original notebook only saved a local zip, so this section mounts
# Drive and copies the whole `data/` folder there automatically — no manual upload
# needed.

# %%
from google.colab import drive
drive.mount('/content/drive')

PROJECT_DIR = "/content/drive/MyDrive/Urdu_OCR_Project_v2"
os.makedirs(PROJECT_DIR, exist_ok=True)

# Copy the entire data/ folder (images + CSVs) to Drive
drive_data_dir = os.path.join(PROJECT_DIR, "data_copy_in_progress")
if os.path.exists(drive_data_dir):
    shutil.rmtree(drive_data_dir)
shutil.copytree("data", drive_data_dir)

final_data_dir = os.path.join(PROJECT_DIR, "data")
if os.path.exists(final_data_dir):
    shutil.rmtree(final_data_dir)
os.rename(drive_data_dir, final_data_dir)

# Also place labels.csv directly under PROJECT_DIR (matches Week 2/3/4's expected path)
shutil.copy2(os.path.join(final_data_dir, "labels.csv"), os.path.join(PROJECT_DIR, "labels.csv"))

print("Copied to Drive:", final_data_dir)
print("labels.csv also copied to:", os.path.join(PROJECT_DIR, "labels.csv"))
print("This PROJECT_DIR path is what Week 2, 3, and 4 (v2) notebooks expect.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Copied to Drive: /content/drive/MyDrive/Urdu_OCR_Project_v2/data
# labels.csv also copied to: /content/drive/MyDrive/Urdu_OCR_Project_v2/labels.csv
# This PROJECT_DIR path is what Week 2, 3, and 4 (v2) notebooks expect.

# %% [markdown]
# ## 10. Dataset Validation
#
# Unchanged — validates every row before splitting and analyzing.

# %%
def validate_dataset(labels_csv=LABELS_CSV):
    """
    Read labels.csv, check each row, and return (valid_rows, invalid_rows).
    Prints a summary.
    """
    with open(labels_csv, 'r', encoding='utf-8') as f:
        all_rows = list(csv.DictReader(f))

    valid, invalid = [], []
    for row in all_rows:
        if not os.path.exists(row['image']):
            row['_reason'] = 'file_not_found'
            invalid.append(row)
            continue
        if not is_valid_image(row['image']):
            row['_reason'] = 'blank_or_corrupt_image'
            invalid.append(row)
            continue
        if not row.get('text', '').strip() or row['text'] == 'FILL_IN_URDU_TEXT_HERE':
            row['_reason'] = 'empty_or_unlabeled'
            invalid.append(row)
            continue
        valid.append(row)

    print(f"Validation complete:")
    print(f"  Valid rows   : {len(valid)}")
    print(f"  Invalid rows : {len(invalid)}")
    if invalid:
        print("  Invalid entries:")
        for r in invalid[:10]:
            print(f"    [{r['_reason']}] {r['image']}")
    return valid, invalid

valid_rows, invalid_rows = validate_dataset()
# Out:
# Validation complete:
#   Valid rows   : 3160
#   Invalid rows : 0

# %% [markdown]
# ## 11. Train / Test Split
#
# Unchanged — 80% train / 20% test, same random seed for reproducibility.

# %%
def create_train_test_split(valid_rows, train_ratio=0.8, seed=42):
    """
    Shuffle valid_rows and split into train/test.
    Writes train.csv, test.csv, and updates labels.csv with the split column.
    """
    random.seed(seed)
    shuffled = valid_rows[:]
    random.shuffle(shuffled)

    cut   = int(len(shuffled) * train_ratio)
    train = shuffled[:cut]
    test  = shuffled[cut:]

    for r in train:
        r['split'] = 'train'
    for r in test:
        r['split'] = 'test'

    fieldnames = ['image', 'text', 'source', 'split']

    with open(TRAIN_CSV, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=fieldnames)
        w.writeheader()
        w.writerows(train)

    with open(TEST_CSV, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=fieldnames)
        w.writeheader()
        w.writerows(test)

    all_labeled = train + test
    with open(LABELS_CSV, 'w', newline='', encoding='utf-8') as f:
        w = csv.DictWriter(f, fieldnames=fieldnames)
        w.writeheader()
        w.writerows(all_labeled)

    print(f"Train: {len(train)} rows  ->  {TRAIN_CSV}")
    print(f"Test : {len(test)} rows  ->  {TEST_CSV}")
    return train, test

train_rows, test_rows = create_train_test_split(valid_rows)

# Re-sync the copy on Drive with the final split labels.csv/train.csv/test.csv
for fname in ["labels.csv", "train.csv", "test.csv"]:
    shutil.copy2(os.path.join("data", fname), os.path.join(PROJECT_DIR, "data", fname))
shutil.copy2(os.path.join("data", "labels.csv"), os.path.join(PROJECT_DIR, "labels.csv"))
print("Drive copy re-synced with final split.")
# Out:
# Train: 2528 rows  ->  data/train.csv
# Test : 632 rows  ->  data/test.csv
# Drive copy re-synced with final split.

# %% [markdown]
# ## 12. Dataset Statistics & Visualizations
#
# Unchanged — same three plots (images per source, text length distribution, train/test
# split), just with much bigger numbers now.

# %%
def plot_dataset_stats(rows):
    """Generate three visualization plots for the dataset."""

    source_counts = {}
    for r in rows:
        src = r.get('source', 'unknown')
        source_counts[src] = source_counts.get(src, 0) + 1

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    fig.suptitle("Urdu OCR Dataset -- Statistics", fontsize=14, fontweight='bold')

    ax = axes[0]
    sources = list(source_counts.keys())
    counts  = [source_counts[s] for s in sources]
    colors  = ['#4C72B0', '#DD8452', '#55A868', '#C44E52', '#8172B2', '#937860', '#DA8BC3', '#8C8C8C']
    bars    = ax.bar(sources, counts, color=colors[:len(sources)], edgecolor='white')
    ax.set_title("Images per Source")
    ax.set_xlabel("Source")
    ax.set_ylabel("Count")
    ax.tick_params(axis='x', rotation=30)
    for bar, cnt in zip(bars, counts):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.3,
                str(cnt), ha='center', va='bottom', fontsize=9)

    ax = axes[1]
    lengths = [len(r['text']) for r in rows if r.get('text')]
    ax.hist(lengths, bins=20, color='#4C72B0', edgecolor='white', alpha=0.85)
    if lengths:
        ax.axvline(sum(lengths)/len(lengths), color='red', linestyle='--',
                   linewidth=1.5, label=f"Mean={sum(lengths)//len(lengths)} chars")
    ax.set_title("Urdu Text Length Distribution")
    ax.set_xlabel("Characters per label")
    ax.set_ylabel("Frequency")
    ax.legend()

    ax = axes[2]
    split_counts = {'train': 0, 'test': 0}
    for r in rows:
        if r.get('split') in split_counts:
            split_counts[r['split']] += 1
    ax.pie(
        split_counts.values(),
        labels=[f"Train ({split_counts['train']})", f"Test ({split_counts['test']})"],
        colors=['#4C72B0', '#DD8452'],
        autopct='%1.1f%%',
        startangle=90,
        wedgeprops={'edgecolor': 'white'}
    )
    ax.set_title("Train / Test Split")

    plt.tight_layout()
    plt.savefig("data/dataset_stats.png", dpi=120, bbox_inches='tight')
    plt.show()
    print("Plot saved: data/dataset_stats.png")

plot_dataset_stats(valid_rows)
# Out:
# Plot saved: data/dataset_stats.png

# %%
def plot_sample_grid(rows, n=12):
    """Show a grid of n randomly sampled images from the dataset."""
    sample = random.sample([r for r in rows if is_valid_image(r['image'])],
                           min(n, len(rows)))

    cols = 4
    rows_count = (len(sample) + cols - 1) // cols
    fig, axes = plt.subplots(rows_count, cols,
                             figsize=(cols * 3.5, rows_count * 2.5))
    axes = axes.flatten()

    for i, row in enumerate(sample):
        img = Image.open(row['image'])
        axes[i].imshow(img, cmap='gray' if img.mode == 'L' else None)
        axes[i].set_title(
            row['text'][:20] + ('...' if len(row['text']) > 20 else ''),
            fontsize=7
        )
        axes[i].axis('off')

    for j in range(len(sample), len(axes)):
        axes[j].axis('off')

    fig.suptitle(f"Dataset Sample Preview ({len(sample)} images)", fontsize=12)
    plt.tight_layout()
    plt.savefig("data/sample_grid.png", dpi=120, bbox_inches='tight')
    plt.show()
    print("Grid saved: data/sample_grid.png")

plot_sample_grid(valid_rows, n=12)
# Out:
# /tmp/ipykernel_771/2127771623.py:25: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_771/2127771623.py:25: UserWarning: Matplotlib currently does not support Arabic natively.
#   plt.tight_layout()
# /tmp/ipykernel_771/2127771623.py:25: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /tmp/ipykernel_771/2127771623.py:26: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   plt.savefig("data/sample_grid.png", dpi=120, bbox_inches='tight')
# /tmp/ipykernel_771/2127771623.py:26: UserWarning: Matplotlib currently does not support Arabic natively.
#   plt.savefig("data/sample_grid.png", dpi=120, bbox_inches='tight')
# /tmp/ipykernel_771/2127771623.py:26: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   plt.savefig("data/sample_grid.png", dpi=120, bbox_inches='tight')
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Grid saved: data/sample_grid.png

# %% [markdown]
# ## 13. Final Summary

# %%
with open(LABELS_CSV, 'r', encoding='utf-8') as f:
    all_final = list(csv.DictReader(f))

with open(TRAIN_CSV, 'r', encoding='utf-8') as f:
    train_final = list(csv.DictReader(f))

with open(TEST_CSV, 'r', encoding='utf-8') as f:
    test_final = list(csv.DictReader(f))

source_summary = {}
for r in all_final:
    src = r.get('source', 'unknown')
    source_summary[src] = source_summary.get(src, 0) + 1

print("=" * 50)
print("  URDU OCR DATASET (v2) -- FINAL SUMMARY")
print("=" * 50)
print(f"  Total labeled images : {len(all_final)}")
print(f"  Training set         : {len(train_final)}")
print(f"  Test set             : {len(test_final)}")
print()
print("  Breakdown by source:")
for src, cnt in source_summary.items():
    print(f"    {src:<25} {cnt}")
print()
print("  Output files (local):")
print(f"    {LABELS_CSV}")
print(f"    {TRAIN_CSV}")
print(f"    {TEST_CSV}")
print(f"    data/dataset_stats.png")
print(f"    data/sample_grid.png")
print()
print("  Output files (Drive, used by Week 2/3/4/5 v2 notebooks):")
print(f"    {PROJECT_DIR}/labels.csv")
print(f"    {PROJECT_DIR}/data/")
print("=" * 50)
# Out:
# ==================================================
#   URDU OCR DATASET (v2) -- FINAL SUMMARY
# ==================================================
#   Total labeled images : 3160
#   Training set         : 2528
#   Test set             : 632
#
#   Breakdown by source:
#     augmented_brightness      598
#     augmented_blur            618
#     utrset_real               400
#     augmented_rotation        596
#     synthetic                 604
#     signboards_synthetic      162
#     books_synthetic           150
#     manual_screenshot         32
#
#   Output files (local):
#     data/labels.csv
#     data/train.csv
#     data/test.csv
#     data/dataset_stats.png
#     data/sample_grid.png
#
#   Output files (Drive, used by Week 2/3/4/5 v2 notebooks):
#     /content/drive/MyDrive/Urdu_OCR_Project_v2/labels.csv
#     /content/drive/MyDrive/Urdu_OCR_Project_v2/data/
# ==================================================

# %%
# Print complete folder structure with file counts
for root, dirs, files in os.walk('data'):
    level = root.replace('data', '').count(os.sep)
    indent = '    ' * level
    folder_name = os.path.basename(root)
    file_count = len([f for f in files if f.endswith(('.png', '.jpg', '.jpeg', '.csv'))])
    print(f'{indent}[DIR] {folder_name}/ ({file_count} files)')

    if level < 2:
        subindent = '    ' * (level + 1)
        for file in files:
            if file.endswith('.csv'):
                print(f'{subindent}[FILE] {file}')
# Out:
# [DIR] data/ (5 files)
#     [FILE] test.csv
#     [FILE] train.csv
#     [FILE] labels.csv
#     [DIR] raw/ (0 files)
#         [DIR] other/ (400 files)
#         [DIR] newspaper/ (32 files)
#         [DIR] synthetic/ (604 files)
#         [DIR] augmented/ (1812 files)
#         [DIR] books/ (150 files)
#         [DIR] signboards/ (162 files)
